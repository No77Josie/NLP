# %% [markdown]
# # House price prediction for Denver Dataset
#
# In this case (Part II), there are two main tasks:
#
# - First, you will need to split the train data into train and validate data and tune the model hyperparameters to choose the best model. Submit the predicted prices for test data to Kaggle to compete for Prof. X's Prize!
#
# - Then you will examine the profit of the iBuyer business model based on the predicted price on the valid data.

# %% [markdown]
# You need to submit a report in pdf format containing the following material on canvas site:
#
# 1.   A plot of the training errors and validation errors over epochs for a base multilayer perceptron model with 2 hidden layers of sizes 256 and 128.
#
# 2.   A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64.
#
# 3.  A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization.
#
# 4. A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization and dropout layers.
#
# 5. A table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.
#
# 6. Your profit analysis of the the iBuyer business model based on the predicted price on the valid data and answers to the four questions therein.
#
#
# You also need to submit on canvas site:
#
# - The complete Juyputer notebook containing all your Pytorch code with explanations, along with a Markdown text explaining different parts if needed.
# -  A checkpoint.pth file containing all the necessary information to retrieve your best model and predictions.

# %% [markdown]
# ---
# ## Data Loading and Visualize Data

# %% [markdown]
# The train data and test data are available on Kaggle website.
# You can first download them, then upload them to the google colab, and then read the data using pandas.

# %%
import pandas as pd  # Importing pandas, which is a library for data manipulation and analysis
#TODO: Read the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
# Display the train dataframe
print(train_df.shape)
print(train_df.columns)
# Out:
# (11581, 17)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS', 'SALE_PRICE'],
#       dtype='object')

# %%
# Display the test dataframe
print(test_df.shape)
print(test_df.columns)
# Out:
# (4964, 16)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS'],
#       dtype='object')

# %% [markdown]
# As you can see, we have 11581 training samples and 4964 test samples, each with 16 features. The training samples contain the sale_prices, which are the labels. The test samples do not contain the sale_prices, which we will predict by building a MLP model.

# %% [markdown]
# ### Visualization of SALE PRICES
#
# Let's take a closer look at the sale prices in the train data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Importing matplotlib's pyplot, it provides a MATLAB-like interface for making plots and charts

# Set the style
sns.set(style="whitegrid")

# Create a histogram
plt.figure(figsize=(10, 6))
sns.histplot(train_df['SALE_PRICE'], bins=50, color='blue')
plt.title('Histogram of Sale Prices (Train Data)')
plt.xlabel('Sale Price')
plt.ylabel('Number of Properties')
plt.show()

# %% [markdown]
# Check the minimum and maximum sale_price in train data.

# %%
print(train_df['SALE_PRICE'].min())
print(train_df['SALE_PRICE'].max())
print(train_df['SALE_PRICE'].median())
# Out:
# 51000
# 1995000
# 431000.0

# %% [markdown]
# We see that the sale_price has a wide range from 50K to 2 million, with the median price 431K.

# %% [markdown]
# ### Visualization of Correlation
#
# We can also compute and visualize the correlation matrix.

# %%
# Compute the correlation matrix:
correlation_matrix = train_df.corr()

# 1. Increase the figure size for clarity
plt.figure(figsize=(8, 8))

# 2. Use a heatmap with annotations, a color map, and specific formatting for the annotations
ax = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={'size': 8})

# 3. Rotate the x-axis labels for better visibility
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Rotate the y-axis labels
plt.setp(ax.get_yticklabels(), rotation=0)

# 4. Title and display
plt.title('Correlation Heatmap')
plt.tight_layout()  # This can help if any labels are still being cut off
plt.show()

# 5. Optionally save the figure with high resolution
# plt.savefig("heatmap.png", dpi=300)
# Out:
# <ipython-input-6-28da14c2e215>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = train_df.corr()

# %% [markdown]
# We can see that the Sale_Price has high correlation with Living_SQFT and number of Full Bathrooms.

# %% [markdown]
# ### Distribution of houses over different NBHD

# %%
# Compute the number of houses per neighborhood
House_by_NBHD = train_df['NBHD'].value_counts()
print(House_by_NBHD )
# Out:
# CENTRAL PARK                    1049
# GATEWAY / GREEN VALLEY RANCH     937
# UNION STATION                    369
# HAMPDEN                          346
# WINDSOR                          316
#                                 ...
# VALVERDE                          22
# GLOBEVILLE                        20
# SUN VALLEY                         8
# CORY - MERRILL                     4
# AURARIA                            1
# Name: NBHD, Length: 75, dtype: int64

# %%
# Filtering ZIP codes that appear more than once
filtered_House_by_NBHD = House_by_NBHD[House_by_NBHD > 200]
filtered_House_by_NBHD.plot(kind='bar', figsize=(10,6))
plt.title('Distribution of Houses by NBHD')
plt.ylabel('Number of Houses')
plt.xlabel('NBHD')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability, if necessary
plt.tight_layout()  # Ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ---
# ## Data Preparation
#
# The first step when building a neural network model is getting your data into the proper form to feed into the network.
#
# - Train labels: We need to extract the sale prices from the train data as train labels. Since the house prices can take very large values, to make training fast it is helpful to define the train labels as the sale prices divided by a normalization factor.
#
# - **Handing non-numeric features**: Some of the house features are non-numeric. We will learn about how to process categorical data in the upcoming lectures. For now, you can  remove those non-numeric features and only train over the numeric features.
#
# - **Feature standardization**: When predicting house prices, you started from features that took a variety of ranges—some features had small floating-point values, and others had fairly large integer values. The model might be able to automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice for dealing with such data is to do feature-wise normalization: for each feature in the input data (a column in the input dataframe), we subtract the mean of the feature and divide by the standard deviation, so that the feature is centered around 0 and has
# a unit standard deviation. Note that here we combine the feature vectors in the train and test data. In this way, the train and test data go through the same normalization.
#
# - **Handling missing values**: There may exist some entries with missing values. After the feature standardization, we can impute the missing values with zeros.

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4964 entries, 0 to 4963
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4964 non-null   int64
#  1   NBHD         4964 non-null   object
#  2   PROP_CLASS   4964 non-null   object
#  3   LIVING_SQFT  4964 non-null   int64
#  4   FBSMT_SQFT   4964 non-null   int64
#  5   BSMT_AREA    4964 non-null   int64
#  6   LAND_SQFT    4964 non-null   int64
#  7   GRD_AREA     4964 non-null   int64
#  8   BLDG_AGE     4964 non-null   int64
#  9   RM_AGE       2623 non-null   float64
#  10  BED_RMS      4964 non-null   float64
#  11  FULL_B       4964 non-null   float64
#  12  HLF_B        4964 non-null   int64
#  13  STORY        4964 non-null   float64
#  14  STYLE_CN     4964 non-null   object
#  15  UNITS        4964 non-null   float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 620.6+ KB

# %% [markdown]
# We see that the sale_price in train data has a wide range from 50K to 2 million, with the median price 431K. We can divide the sale_price by 100K, so the normalized sale_price is between 0.5 and 20 in training data. Remember, when we output the predicted price for the test data, we need to multiply back the normalization factor.

# %%
#TODO: define labels for train data
normalization_factor=100000
train_labels = train_df['SALE_PRICE']/normalization_factor
train_df.drop('SALE_PRICE', axis=1, inplace=True) # drop the sale_prices in features.

# %% [markdown]
# The inplace parameter, when set to True , allows you to drop the rows or columns without returning a new DataFrame. The issue arises when the drop function reorders the DataFrame, which can be problematic when the order of your data matters

# %% [markdown]
# Note that both the training samples and test samples contain an ID column, which is not informative for predicting the house price. Thus we will drop the ID column.

# %%
train_ID=train_df['ID']
test_ID=test_df['ID']
train_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

# %%
# Then we combine the feature vectors in the train data and test data
features=pd.concat(objs=[train_df,test_df],axis=0)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16545 entries, 0 to 4963
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NBHD         16545 non-null  object
#  1   PROP_CLASS   16545 non-null  object
#  2   LIVING_SQFT  16545 non-null  int64
#  3   FBSMT_SQFT   16545 non-null  int64
#  4   BSMT_AREA    16545 non-null  int64
#  5   LAND_SQFT    16545 non-null  int64
#  6   GRD_AREA     16545 non-null  int64
#  7   BLDG_AGE     16545 non-null  int64
#  8   RM_AGE       8705 non-null   float64
#  9   BED_RMS      16545 non-null  float64
#  10  FULL_B       16545 non-null  float64
#  11  HLF_B        16545 non-null  int64
#  12  STORY        16545 non-null  float64
#  13  STYLE_CN     16545 non-null  object
#  14  UNITS        16545 non-null  float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# We see that there are three non-numeric features, namely `NBHD`, `PROP_CLASS`, and `STYLE_CN`. We will apply one-hot encoding to those non-numeric features in our model; you could also simply drop these non-numeric features.

# %%
numeric_features = features.dtypes[features.dtypes != 'object'].index
non_numeric_features = features.dtypes[features.dtypes == 'object'].index
numeric_features, non_numeric_features
# Out:
# (Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#         'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B', 'STORY', 'UNITS'],
#        dtype='object'),
#  Index(['NBHD', 'PROP_CLASS', 'STYLE_CN'], dtype='object'))

# %%
# If you want to drop the non-numeric features, you just set drop_non_numeric_features= True.
drop_non_numeric_features= True

if drop_non_numeric_features:
    features= features.drop(non_numeric_features, axis=1)
else:
    #One-hot encode categorical features
    features = pd.get_dummies(features, columns=non_numeric_features, dummy_na=True)

# Check for non-numeric columns
non_numeric_cols = features.select_dtypes(include=['object']).columns
if not non_numeric_cols.empty:
   raise ValueError(f"DataFrame contains non-numeric columns: {non_numeric_cols.tolist()}")

# %%
# Standardize numeric features
features[numeric_features] = features[numeric_features].apply(lambda x: (x - x.mean()) / (x.std()))

# %%
# recheck the mean and std after standardization
features[numeric_features].mean(), features[numeric_features].std()
# Out:
# (LIVING_SQFT   -6.919686e-17
#  FBSMT_SQFT    -7.907445e-17
#  BSMT_AREA      5.829929e-17
#  LAND_SQFT      1.792998e-17
#  GRD_AREA      -1.975519e-17
#  BLDG_AGE      -1.385011e-17
#  RM_AGE         2.795645e-17
#  BED_RMS        2.122341e-16
#  FULL_B         1.469829e-16
#  HLF_B         -5.658145e-17
#  STORY         -4.563020e-18
#  UNITS          5.017175e-16
#  dtype: float64,
#  LIVING_SQFT    1.0
#  FBSMT_SQFT     1.0
#  BSMT_AREA      1.0
#  LAND_SQFT      1.0
#  GRD_AREA       1.0
#  BLDG_AGE       1.0
#  RM_AGE         1.0
#  BED_RMS        1.0
#  FULL_B         1.0
#  HLF_B          1.0
#  STORY          1.0
#  UNITS          1.0
#  dtype: float64)

# %% [markdown]
# We see that after standardization, the features for the train data have mean 0 and standard deviation 1.

# %%
# After the feature standardization, we can impute the missing values with zeros.
features[numeric_features] = features[numeric_features].fillna(0)

# %% [markdown]
# Double check the features after data processing.

# %%
features.info()
print(features.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16545 entries, 0 to 4963
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LIVING_SQFT  16545 non-null  float64
#  1   FBSMT_SQFT   16545 non-null  float64
#  2   BSMT_AREA    16545 non-null  float64
#  3   LAND_SQFT    16545 non-null  float64
#  4   GRD_AREA     16545 non-null  float64
#  5   BLDG_AGE     16545 non-null  float64
#  6   RM_AGE       16545 non-null  float64
#  7   BED_RMS      16545 non-null  float64
#  8   FULL_B       16545 non-null  float64
#  9   HLF_B        16545 non-null  float64
#  10  STORY        16545 non-null  float64
#  11  UNITS        16545 non-null  float64
# dtypes: float64(12)
# memory usage: 1.6 MB
# Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#        'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B', 'STORY', 'UNITS'],
#       dtype='object')

# %% [markdown]
# Note that after the one-hot encoding of the non-numeric features, now we have 105-dimensional feature.

# %%
# check whether there is any missing entry
print(features.isnull().sum())
# Out:
# LIVING_SQFT    0
# FBSMT_SQFT     0
# BSMT_AREA      0
# LAND_SQFT      0
# GRD_AREA       0
# BLDG_AGE       0
# RM_AGE         0
# BED_RMS        0
# FULL_B         0
# HLF_B          0
# STORY          0
# UNITS          0
# dtype: int64

# %%
# we extract out the train and test features
train_features = features.iloc[:len(train_labels)]
test_features = features.iloc[len(train_labels):]
train_features.shape, test_features.shape
# Out:
# ((11581, 12), (4964, 12))

# %%
import torch
import numpy as np

# Convert training features and labels to PyTorch tensors
train_features = torch.tensor(train_features.values.astype(np.float32), dtype=torch.float32)
test_features = torch.tensor(test_features.values.astype(np.float32), dtype=torch.float32)
train_labels = torch.tensor(train_labels.values.reshape(-1, 1).astype(np.float32), dtype=torch.float32)

# %%
train_labels
# Out:
# tensor([[ 2.8500],
#         [12.3000],
#         [ 4.2000],
#         ...,
#         [ 6.0200],
#         [ 3.8370],
#         [ 5.5000]])

# %%
train_labels.shape
# Out:
# torch.Size([11581, 1])

# %% [markdown]
# ---
# ## Training and Validation
#
# To prevent overfitting, we'll split it our training data into training and validation. We will use validation set to select the appropriate model.
# One way is to use the [`train_test_split` function](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html). You're more than welcome to use your own way.

# %%
#TODO: filling in the missing code to split train data into train and validation
from sklearn.model_selection import train_test_split  # Importing train_test_split function from sklearn for splitting data into training set and validation set
# Splitting the training data: 20% is validation data
#train_indices, valid_indices, train_features, valid_features, train_labels, valid_labels = train_test_split(train_features, train_labels, test_size=0.2, random_state=30)

train_indices, valid_indices = train_ID, test_ID
train_features, valid_features, train_labels, valid_labels = train_test_split(train_features, train_labels, test_size=0.2, random_state=42)

# %%
print(train_features.shape)
print(valid_features.shape)
# Out:
# torch.Size([9264, 12])
# torch.Size([2317, 12])

# %% [markdown]
# ---
# ## DataLoaders and Batching
#
# After creating training, test, and validation data, we can create DataLoaders for this data by following two steps:
# 1. Create a known format for accessing our data, using [TensorDataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.TensorDataset) which takes in an input set of data and a target set of data with the same first dimension, and creates a dataset.
# 2. Create DataLoaders and batch our training, validation, and test Tensor datasets. Note that we will shuffle the train data, so the model will not learn a particular order. For valid and test data, we do not shuffle.

# %%
from torch.utils.data import TensorDataset, DataLoader
train_data = TensorDataset(train_features, train_labels)
train_loader = DataLoader(train_data, batch_size=256, shuffle=True)
#TODO: create dataloader for validation data
valid_data = TensorDataset(valid_features, valid_labels)
valid_loader = DataLoader(valid_data, batch_size=256, shuffle=False)

# %%
test_data = TensorDataset(test_features)
test_loader = DataLoader(test_data, batch_size=128, shuffle=False)

# %% [markdown]
# Let's take a batch to have a sanity check

# %%
# obtain one batch of training data
dataiter = iter(train_loader)
features, labels = next(dataiter)

print('Sample input size: ', features.size()) # batch_size, seq_length
print('Sample input: \n', features)
print()
print('Sample label size: ', labels.size()) # batch_size
print('Sample label: \n', labels)
# Out:
# Sample input size:  torch.Size([256, 12])
# Sample input:
#  tensor([[-0.6178,  1.1599,  0.8137,  ...,  1.0768, -0.7504, -0.1079],
#         [ 3.8006,  2.4655,  2.4921,  ...,  1.0768,  0.7971, -0.1079],
#         [-0.4350,  1.6740,  1.2455,  ..., -0.7753, -0.7504, -0.1079],
#         ...,
#         [-0.8779,  0.9104,  0.6764,  ..., -0.7753, -0.7504, -0.1079],
#         [ 0.6516,  0.8136,  0.5481,  ...,  1.0768,  0.7971, -0.1079],
#         [ 0.0232,  2.3193,  1.8345,  ..., -0.7753, -0.7504, -0.1079]])
#
# Sample label size:  torch.Size([256, 1])
# Sample label:
#  tensor([[ 5.8900],
#         [19.4000],
#         [ 4.1500],
#         [10.5000],
#         [ 3.8500],
#         [ 3.3400],
#         [ 1.8250],
#         [ 1.7000],
#         [11.0000],
#         [ 5.2500],
#         [ 5.2500],
#         [ 4.9900],
#         [ 5.3000],
#         [ 1.7090],
#         [ 1.9100],
#         [ 3.5687],
#         [ 4.7000],
#         [ 3.7500],
#         [ 3.6350],
#         [ 3.0000],
#         [ 5.0600],
#         [ 5.5000],
#         [ 4.1000],
#         [ 3.1500],
#         [ 4.5000],
#         [ 1.5500],
#         [ 6.7900],
#         [ 3.4500],
#         [14.0000],
#         [ 2.5950],
#         [ 0.9000],
#         [ 3.9200],
#         [ 3.7990],
#         [ 4.2000],
#         [ 6.3419],
#         [ 4.3500],
#         [ 2.2000],
#         [ 2.4000],
#         [ 5.6750],
#         [ 1.3700],
#         [ 2.1500],
#         [ 1.4550],
#         [ 7.9000],
#         [ 2.8500],
#         [ 9.0000],
#         [ 4.2000],
#         [ 4.3500],
#         [ 7.9250],
#         [ 2.9750],
#         [ 2.6800],
#         [ 3.4000],
#         [ 1.8500],
#         [ 4.7250],
#         [ 5.1650],
#         [ 1.5000],
#         [ 3.3000],
#         [ 4.3488],
#         [ 1.6600],
#         [ 3.5000],
#         [ 2.2490],
#         [15.1914],
#         [ 0.6000],
#         [ 2.3075],
#         [ 2.5800],
#         [ 6.6000],
#         [12.5000],
#         [ 6.3995],
#         [ 3.3750],
#         [ 4.5500],
#         [ 4.7000],
#         [ 1.8500],
#         [ 1.1000],
#         [ 3.7700],
#         [13.2594],
#         [ 3.8700],
#         [ 8.6000],
#         [ 4.6800],
#         [ 3.1500],
#         [ 1.0500],
#         [ 4.4500],
#         [ 4.1782],
#         [ 2.4000],
#         [ 5.4500],
#         [ 5.2123],
#         [ 6.0800],
#         [ 6.6500],
#         [ 2.3400],
#         [ 2.0500],
#         [ 4.0000],
#         [16.7500],
#         [ 5.5990],
#         [ 5.6800],
#         [ 5.3500],
#         [10.2500],
#         [ 3.8500],
#         [ 3.0990],
#         [ 2.5000],
#         [ 2.7900],
#         [ 3.4900],
#         [ 4.7300],
#         [ 2.9107],
#         [15.0000],
#         [ 2.7190],
#         [10.9754],
#         [12.0000],
#         [ 4.2000],
#         [ 2.5000],
#         [ 5.8500],
#         [ 7.5000],
#         [ 3.3500],
#         [ 7.1488],
#         [ 3.6500],
#         [11.4000],
#         [ 1.7790],
#         [ 1.8500],
#         [ 8.6250],
#         [ 2.9200],
#         [ 3.4500],
#         [ 3.0500],
#         [ 2.2900],
#         [ 4.4200],
#         [ 3.7800],
#         [ 8.6500],
#         [ 3.3500],
#         [ 2.6500],
#         [ 8.0000],
#         [ 3.5990],
#         [ 2.5138],
#         [ 3.2150],
#         [ 1.2500],
#         [ 2.4070],
#         [ 2.4500],
#         [ 3.3245],
#         [ 4.2500],
#         [ 4.8000],
#         [11.0902],
#         [11.2796],
#         [ 8.7500],
#         [ 3.3500],
#         [ 6.1750],
#         [ 6.3373],
#         [ 4.4990],
#         [ 3.6800],
#         [ 4.2000],
#         [ 8.5000],
#         [ 1.9500],
#         [ 2.2900],
#         [ 3.1800],
#         [ 3.5000],
#         [ 4.1000],
#         [ 5.6650],
#         [ 4.3490],
#         [ 2.7000],
#         [ 5.5000],
#         [ 1.4000],
#         [ 5.7000],
#         [ 3.4500],
#         [ 5.0900],
#         [ 3.9500],
#         [ 4.8500],
#         [ 2.1000],
#         [ 1.7100],
#         [ 3.4315],
#         [ 1.9500],
#         [ 6.3634],
#         [ 6.2300],
#         [ 5.5000],
#         [ 4.3750],
#         [ 8.4500],
#         [17.5000],
#         [ 2.7900],
#         [ 4.3800],
#         [ 6.8700],
#         [ 4.3000],
#         [ 5.4500],
#         [ 1.3500],
#         [ 2.9000],
#         [ 2.9195],
#         [ 4.3900],
#         [ 2.5000],
#         [ 3.6500],
#         [ 2.9350],
#         [ 3.5500],
#         [ 3.2400],
#         [ 3.4600],
#         [ 5.2500],
#         [ 2.3075],
#         [ 6.8500],
#         [ 5.4300],
#         [ 3.1400],
#         [ 7.3990],
#         [ 2.1000],
#         [ 4.7500],
#         [11.3500],
#         [ 4.3000],
#         [ 3.2500],
#         [ 4.5160],
#         [ 3.0500],
#         [ 1.4600],
#         [ 4.0500],
#         [ 5.8061],
#         [ 1.4990],
#         [ 3.8700],
#         [ 5.8000],
#         [ 3.0500],
#         [ 4.2700],
#         [ 4.1200],
#         [ 5.9770],
#         [ 1.4000],
#         [ 8.0900],
#         [ 2.3500],
#         [ 2.5250],
#         [ 4.3000],
#         [ 5.2000],
#         [ 4.6476],
#         [ 1.4000],
#         [ 5.5513],
#         [ 3.1000],
#         [ 5.6120],
#         [ 3.4000],
#         [ 6.3000],
#         [ 1.2500],
#         [ 6.0500],
#         [14.5000],
#         [ 4.8990],
#         [ 4.2000],
#         [ 5.5638],
#         [ 7.0600],
#         [ 2.8000],
#         [ 6.0100],
#         [ 2.6700],
#         [ 1.6900],
#         [ 8.6500],
#         [ 2.2450],
#         [ 8.0500],
#         [ 6.9000],
#         [ 5.7501],
#         [ 4.5800],
#         [ 2.4550],
#         [ 4.8000],
#         [ 5.9000],
#         [ 3.4536],
#         [ 2.1000],
#         [ 4.2000],
#         [11.5000],
#         [ 4.1000],
#         [ 3.5250],
#         [ 4.2500],
#         [ 4.0500],
#         [ 4.8593],
#         [ 4.2570],
#         [ 1.9800],
#         [ 2.6000],
#         [ 4.6500],
#         [ 5.0000],
#         [ 4.7490]])

# %% [markdown]
# ---
# ## Linear Regression as Benchmark
#
# Let us build a linear regression model as a benchmark. Note that the linear regression model can be viewed as a special instance of multi-layer perception with no hidden layer and a single output neuron.

# %%
# Build a linear regression model network
import torch.nn as nn
import torch.optim as optim

class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.fc = nn.Linear(12, 1)

    def forward(self, x):
        output = self.fc(x)
        return output

lin_net = LinearRegression()

# %% [markdown]
# Let's print out the model achitecture.

# %%
lin_net
# Out:
# LinearRegression(
#   (fc): Linear(in_features=12, out_features=1, bias=True)
# )

# %% [markdown]
# Let's take a batch and see the output

# %%
features, labels = next(dataiter)
output=lin_net(features)
output.shape,labels.shape
# Out:
# (torch.Size([256, 1]), torch.Size([256, 1]))

# %% [markdown]
# ---
# ## Train the model

# %% [markdown]
# First, we will use GPU training if it is availabe.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
lin_net = lin_net.to(device)

# %% [markdown]
# Second, let us specify the loss function.

# %%
#Since both the output and the label are real valued, we will use the standard mean-squared loss.
criterion = nn.MSELoss()

# %% [markdown]
# Third, while we are using the mean-squared loss for training loss, we will use
# a different metric to measure the predictive performance.
#
# Note that with house prices, as with stock prices, we care about relative quantities more than absolute quantities. Thus we tend to care more about the relative error than about the absolute error. For instance, if our prediction is off by \\$100,000 when estimating the sale price of a house which is \\$125,000, then we are probably doing a horrible job. On the other hand, if we err by this amount for a house with sale price \\$2 million, this might represent a pretty  accurate prediction.
#
# To address this issue, we will use the median error rate (MER) used by [Zestimate](https://www.zillow.com/z/zestimate/) to measure the predictive performance. The error rate is defined as
# $$
# \text{Error Rate} = \left| \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}} \right|
# $$
# The median error rate is defined as the median of error rates for all properties.

# %% [markdown]
# We are now ready to train the network. Let’s try training the model a bit longer: 200 epochs. To keep a record of how well the model does at each epoch, we will save the per-epoch training error and validation error in the training loop.

# %%
#TODO: Write code to train the network and save training and validation error.
optimizer = optim.Adam(lin_net.parameters(), lr=0.01)

num_epochs = 50
train_losses, valid_losses = [], []

# Initialize an empty list to store MER values
mer_train_values, mer_valid_values = [], []

for epoch in range(num_epochs):
    running_train_loss = 0
    for batch_features, batch_labels in train_loader:

        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        optimizer.zero_grad()
        outputs = lin_net(batch_features)
        loss = criterion(outputs, batch_labels)

        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

    else:
      running_valid_loss = 0
      with torch.no_grad():
        for batch_features, batch_labels in valid_loader:
          batch_features = batch_features.to(device)
          batch_labels = batch_labels.to(device)

          outputs = lin_net(batch_features)
          loss = criterion(outputs, batch_labels)
          running_valid_loss += loss.item()


      train_loss=running_train_loss/len(train_loader)
      valid_loss = running_valid_loss/len(valid_loader)
      train_losses.append(train_loss)
      valid_losses.append(valid_loss)


    # Calculate MER for this epoch and append to the list
    train_loss = running_train_loss / len(train_loader)
    train_losses.append(train_loss)

    valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(valid_loss)

    # Calculate MER based on your code
    train_features = train_features.to(device)
    train_labels = train_labels.to(device)

    valid_features = valid_features.to(device)
    valid_labels = valid_labels.to(device)

    predicted_train = lin_net(train_features).cpu().detach().numpy()
    actual_train = train_labels.cpu().numpy()
    error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
    mer_train = np.median(error_rates_train)
    mer_train_values.append(mer_train)

    predicted_valid = lin_net(valid_features).cpu().detach().numpy()
    actual_valid = valid_labels.cpu().numpy()
    error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
    mer_valid = np.median(error_rates_valid)
    mer_valid_values.append(mer_valid)



    print(f"Epoch {epoch + 1}/{num_epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train:.4f}")
    print(mer_train)
    print(f"Epoch {epoch + 1}/{num_epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid:.4f}")
    print(mer_valid)
# Out:
# Epoch 1/50 - Training Loss: 32.9684 - MER: 0.9847
# 0.98469365
# Epoch 1/50 - Valid Loss: 30.4622 - MER: 0.9806
# 0.98060894
# Epoch 2/50 - Training Loss: 26.9474 - MER: 0.9073
# 0.90731
# Epoch 2/50 - Valid Loss: 25.5253 - MER: 0.8982
# 0.8982438
# Epoch 3/50 - Training Loss: 23.4383 - MER: 0.8419
# 0.84190035
# Epoch 3/50 - Valid Loss: 22.1766 - MER: 0.8396
# 0.8395663
# Epoch 4/50 - Training Loss: 20.4631 - MER: 0.7824
# 0.78235555
# Epoch 4/50 - Valid Loss: 19.3520 - MER: 0.7797
# 0.7797166
# Epoch 5/50 - Training Loss: 17.7641 - MER: 0.7256
# 0.7255529
# Epoch 5/50 - Valid Loss: 16.8260 - MER: 0.7238
# 0.72383857
# Epoch 6/50 - Training Loss: 15.4852 - MER: 0.6659
# 0.6659162
# Epoch 6/50 - Valid Loss: 14.7664 - MER: 0.6666
# 0.6665794
# Epoch 7/50 - Training Loss: 13.5690 - MER: 0.6098
# 0.6097548
# Epoch 7/50 - Valid Loss: 12.8905 - MER: 0.6098
# 0.6097948
# Epoch 8/50 - Training Loss: 11.9006 - MER: 0.5577
# 0.55771035
# Epoch 8/50 - Valid Loss: 11.3048 - MER: 0.5559
# 0.5558924
# Epoch 9/50 - Training Loss: 10.3748 - MER: 0.5061
# 0.5061039
# Epoch 9/50 - Valid Loss: 9.9557 - MER: 0.5057
# 0.5056885
# Epoch 10/50 - Training Loss: 9.1366 - MER: 0.4555
# 0.455512
# Epoch 10/50 - Valid Loss: 8.8195 - MER: 0.4569
# 0.45688844
# Epoch 11/50 - Training Loss: 8.1201 - MER: 0.4104
# 0.41044927
# Epoch 11/50 - Valid Loss: 7.8520 - MER: 0.4076
# 0.40755466
# Epoch 12/50 - Training Loss: 7.3344 - MER: 0.3740
# 0.37401164
# Epoch 12/50 - Valid Loss: 7.0233 - MER: 0.3738
# 0.37384704
# Epoch 13/50 - Training Loss: 6.7090 - MER: 0.3379
# 0.33791822
# Epoch 13/50 - Valid Loss: 6.3568 - MER: 0.3425
# 0.3424934
# Epoch 14/50 - Training Loss: 6.0543 - MER: 0.3102
# 0.3101902
# Epoch 14/50 - Valid Loss: 5.8111 - MER: 0.3110
# 0.3110476
# Epoch 15/50 - Training Loss: 5.6470 - MER: 0.2881
# 0.28809547
# Epoch 15/50 - Valid Loss: 5.3706 - MER: 0.2904
# 0.29040042
# Epoch 16/50 - Training Loss: 5.1347 - MER: 0.2750
# 0.2749999
# Epoch 16/50 - Valid Loss: 4.9952 - MER: 0.2735
# 0.27352586
# Epoch 17/50 - Training Loss: 4.9145 - MER: 0.2600
# 0.25998908
# Epoch 17/50 - Valid Loss: 4.7096 - MER: 0.2577
# 0.25768006
# Epoch 18/50 - Training Loss: 4.5761 - MER: 0.2501
# 0.25007594
# Epoch 18/50 - Valid Loss: 4.4711 - MER: 0.2487
# 0.24866065
# Epoch 19/50 - Training Loss: 4.3533 - MER: 0.2447
# 0.24467862
# Epoch 19/50 - Valid Loss: 4.3031 - MER: 0.2419
# 0.24188158
# Epoch 20/50 - Training Loss: 4.3014 - MER: 0.2389
# 0.23893651
# Epoch 20/50 - Valid Loss: 4.1709 - MER: 0.2348
# 0.23476556
# Epoch 21/50 - Training Loss: 4.1434 - MER: 0.2359
# 0.23592573
# Epoch 21/50 - Valid Loss: 4.0573 - MER: 0.2374
# 0.23741795
# Epoch 22/50 - Training Loss: 4.0333 - MER: 0.2333
# 0.23329169
# Epoch 22/50 - Valid Loss: 3.9865 - MER: 0.2328
# 0.23276237
# Epoch 23/50 - Training Loss: 3.9708 - MER: 0.2305
# 0.23050418
# Epoch 23/50 - Valid Loss: 3.9119 - MER: 0.2314
# 0.23142648
# Epoch 24/50 - Training Loss: 3.9227 - MER: 0.2281
# 0.22808652
# Epoch 24/50 - Valid Loss: 3.8620 - MER: 0.2287
# 0.22866493
# Epoch 25/50 - Training Loss: 3.8691 - MER: 0.2246
# 0.22457501
# Epoch 25/50 - Valid Loss: 3.8336 - MER: 0.2279
# 0.22794035
# Epoch 26/50 - Training Loss: 3.8661 - MER: 0.2234
# 0.22343168
# Epoch 26/50 - Valid Loss: 3.8068 - MER: 0.2257
# 0.22570105
# Epoch 27/50 - Training Loss: 3.8315 - MER: 0.2213
# 0.22130984
# Epoch 27/50 - Valid Loss: 3.7918 - MER: 0.2242
# 0.22421758
# Epoch 28/50 - Training Loss: 3.8208 - MER: 0.2217
# 0.22170591
# Epoch 28/50 - Valid Loss: 3.7697 - MER: 0.2264
# 0.22643347
# Epoch 29/50 - Training Loss: 3.8297 - MER: 0.2208
# 0.22084549
# Epoch 29/50 - Valid Loss: 3.7623 - MER: 0.2229
# 0.22293265
# Epoch 30/50 - Training Loss: 3.8295 - MER: 0.2216
# 0.22155187
# Epoch 30/50 - Valid Loss: 3.7505 - MER: 0.2229
# 0.22288276
# Epoch 31/50 - Training Loss: 3.8293 - MER: 0.2199
# 0.21989807
# Epoch 31/50 - Valid Loss: 3.7477 - MER: 0.2230
# 0.22300825
# Epoch 32/50 - Training Loss: 3.8315 - MER: 0.2193
# 0.2193041
# Epoch 32/50 - Valid Loss: 3.7443 - MER: 0.2233
# 0.22328782
# Epoch 33/50 - Training Loss: 3.8242 - MER: 0.2195
# 0.21952254
# Epoch 33/50 - Valid Loss: 3.7415 - MER: 0.2215
# 0.22148012
# Epoch 34/50 - Training Loss: 3.7899 - MER: 0.2193
# 0.21928355
# Epoch 34/50 - Valid Loss: 3.7433 - MER: 0.2207
# 0.22070794
# Epoch 35/50 - Training Loss: 3.8348 - MER: 0.2209
# 0.22091845
# Epoch 35/50 - Valid Loss: 3.7419 - MER: 0.2254
# 0.22542825
# Epoch 36/50 - Training Loss: 3.8315 - MER: 0.2197
# 0.21967992
# Epoch 36/50 - Valid Loss: 3.7345 - MER: 0.2216
# 0.22156855
# Epoch 37/50 - Training Loss: 3.8175 - MER: 0.2206
# 0.22059941
# Epoch 37/50 - Valid Loss: 3.7326 - MER: 0.2228
# 0.22277151
# Epoch 38/50 - Training Loss: 3.7801 - MER: 0.2188
# 0.21878815
# Epoch 38/50 - Valid Loss: 3.7351 - MER: 0.2212
# 0.22122152
# Epoch 39/50 - Training Loss: 3.7675 - MER: 0.2196
# 0.21958217
# Epoch 39/50 - Valid Loss: 3.7312 - MER: 0.2205
# 0.22053342
# Epoch 40/50 - Training Loss: 3.8841 - MER: 0.2197
# 0.21970096
# Epoch 40/50 - Valid Loss: 3.7309 - MER: 0.2210
# 0.22099867
# Epoch 41/50 - Training Loss: 3.8322 - MER: 0.2199
# 0.2199439
# Epoch 41/50 - Valid Loss: 3.7408 - MER: 0.2185
# 0.2184843
# Epoch 42/50 - Training Loss: 3.8192 - MER: 0.2189
# 0.2188977
# Epoch 42/50 - Valid Loss: 3.7307 - MER: 0.2195
# 0.21951152
# Epoch 43/50 - Training Loss: 3.8282 - MER: 0.2191
# 0.21909517
# Epoch 43/50 - Valid Loss: 3.7295 - MER: 0.2202
# 0.22024967
# Epoch 44/50 - Training Loss: 3.8407 - MER: 0.2196
# 0.21956208
# Epoch 44/50 - Valid Loss: 3.7310 - MER: 0.2210
# 0.22103813
# Epoch 45/50 - Training Loss: 3.8242 - MER: 0.2192
# 0.21916473
# Epoch 45/50 - Valid Loss: 3.7304 - MER: 0.2210
# 0.22101958
# Epoch 46/50 - Training Loss: 3.8302 - MER: 0.2189
# 0.21889287
# Epoch 46/50 - Valid Loss: 3.7312 - MER: 0.2193
# 0.21927983
# Epoch 47/50 - Training Loss: 3.8082 - MER: 0.2194
# 0.21943338
# Epoch 47/50 - Valid Loss: 3.7283 - MER: 0.2221
# 0.22207007
# Epoch 48/50 - Training Loss: 3.8170 - MER: 0.2197
# 0.21974194
# Epoch 48/50 - Valid Loss: 3.7293 - MER: 0.2214
# 0.22143212
# Epoch 49/50 - Training Loss: 3.8352 - MER: 0.2201
# 0.22005373
# Epoch 49/50 - Valid Loss: 3.7311 - MER: 0.2227
# 0.22269644
# Epoch 50/50 - Training Loss: 3.7827 - MER: 0.2205
# 0.22051975
# Epoch 50/50 - Valid Loss: 3.7283 - MER: 0.2233
# 0.22328062

# %% [markdown]
# Define a function to plot errors.

# %%
#TODO: Write code to plot the training and vadliation errors (MER) over epochs
# Plot the MER values over epochs
import matplotlib.pyplot as plt

plt.plot(mer_train_values, label='Training MER')
plt.plot(mer_valid_values, label='Validation MER')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Build the Multi-layer Perceptron Base Model

# %% [markdown]
# In the following, we build a multi-layer perception model with 2 hidden layers of sizes 256 and 128, respectively and ReLu activations.

# %%
# Build a feed-forward network
import torch.nn as nn
model = nn.Sequential(nn.Linear(train_features.shape[1], 256),
                      nn.ReLU(),
                      nn.Linear(256, 128),
                      nn.ReLU(),
                      nn.Linear(128,1))

# %% [markdown]
# Let's print out the model achitecture.

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=12, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
model = model.to(device)

# %%
#TODO: write code to train the MLP network and save training and validation error.

# Example of how to use the custom loss function in your training loop
criterion_MLP = nn.SmoothL1Loss()
optimizer_MLP = optim.Adam(model.parameters(), lr=0.003)

epochs=200
train_losses_MLP, valid_losses_MLP = [], []

# Initialize empty lists to store MER values
mer_values_train_MLP, mer_values_valid_MLP = [], []

for e in range(epochs):
  running_train_loss=0
  for batch_features, batch_labels in train_loader:
    batch_features = batch_features.to(device)
    batch_labels = batch_labels.to(device)

    logps=model(batch_features)
    loss=criterion_MLP(logps, batch_labels)
    optimizer_MLP.zero_grad()
    loss.backward()
    optimizer_MLP.step()

    running_train_loss += loss.item()

  else:
    running_valid_loss = 0
    with torch.no_grad():
      for batch_features, batch_labels in valid_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        outputs = model(batch_features)
        loss = criterion_MLP(outputs, batch_labels)
        running_valid_loss += loss.item()


    train_loss = running_train_loss/len(train_loader)
    valid_loss = running_valid_loss/len(valid_loader)
    train_losses_MLP.append(train_loss)
    valid_losses_MLP.append(valid_loss)



  # Calculate MER for this epoch and append to the list
  train_loss = running_train_loss / len(train_loader)
  train_losses_MLP.append(train_loss)

  valid_loss = running_valid_loss / len(valid_loader)
  valid_losses_MLP.append(valid_loss)

  # Calculate MER based on your code
  train_features = train_features.to(device)
  train_labels = train_labels.to(device)
  valid_features = valid_features.to(device)
  valid_labels = valid_labels.to(device)

  predicted_train = model(train_features).cpu().detach().numpy()
  actual_train = train_labels.cpu().numpy()
  error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
  mer_train_MLP = np.median(error_rates_train)
  mer_values_train_MLP.append(mer_train_MLP)

  predicted_valid = model(valid_features).cpu().detach().numpy()
  actual_valid = valid_labels.cpu().numpy()
  error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
  mer_valid_MLP = np.median(error_rates_valid)
  mer_values_valid_MLP.append(mer_valid_MLP)


  print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
  print(mer_train_MLP)
  print(f"Epoch {e + 1}/{epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid_MLP:.4f}")
  print(mer_valid_MLP)
# Out:
# Epoch 1/200 - Training Loss: 1.5043 - MER: 0.2140
# 0.21403202
# Epoch 1/200 - Valid Loss: 0.9522 - MER: 0.2108
# 0.21082874
# Epoch 2/200 - Training Loss: 0.8864 - MER: 0.1898
# 0.1897819
# Epoch 2/200 - Valid Loss: 0.8149 - MER: 0.1885
# 0.1884918
# Epoch 3/200 - Training Loss: 0.8172 - MER: 0.1811
# 0.18106076
# Epoch 3/200 - Valid Loss: 0.7785 - MER: 0.1790
# 0.17900199
# Epoch 4/200 - Training Loss: 0.7726 - MER: 0.1720
# 0.17197697
# Epoch 4/200 - Valid Loss: 0.7508 - MER: 0.1771
# 0.17707157
# Epoch 5/200 - Training Loss: 0.7560 - MER: 0.1709
# 0.17086864
# Epoch 5/200 - Valid Loss: 0.7519 - MER: 0.1767
# 0.17670469
# Epoch 6/200 - Training Loss: 0.7374 - MER: 0.1668
# 0.16679093
# Epoch 6/200 - Valid Loss: 0.7401 - MER: 0.1719
# 0.17194119
# Epoch 7/200 - Training Loss: 0.7322 - MER: 0.1652
# 0.16518213
# Epoch 7/200 - Valid Loss: 0.7404 - MER: 0.1722
# 0.17222168
# Epoch 8/200 - Training Loss: 0.7161 - MER: 0.1660
# 0.16595055
# Epoch 8/200 - Valid Loss: 0.7475 - MER: 0.1734
# 0.17339374
# Epoch 9/200 - Training Loss: 0.7040 - MER: 0.1581
# 0.15814751
# Epoch 9/200 - Valid Loss: 0.7194 - MER: 0.1686
# 0.16862454
# Epoch 10/200 - Training Loss: 0.7043 - MER: 0.1639
# 0.16389716
# Epoch 10/200 - Valid Loss: 0.7536 - MER: 0.1736
# 0.17355707
# Epoch 11/200 - Training Loss: 0.6960 - MER: 0.1632
# 0.16319719
# Epoch 11/200 - Valid Loss: 0.7422 - MER: 0.1719
# 0.1719174
# Epoch 12/200 - Training Loss: 0.6938 - MER: 0.1588
# 0.15878549
# Epoch 12/200 - Valid Loss: 0.7470 - MER: 0.1687
# 0.16866976
# Epoch 13/200 - Training Loss: 0.6793 - MER: 0.1507
# 0.15067759
# Epoch 13/200 - Valid Loss: 0.7223 - MER: 0.1585
# 0.15854704
# Epoch 14/200 - Training Loss: 0.6765 - MER: 0.1555
# 0.1554518
# Epoch 14/200 - Valid Loss: 0.7297 - MER: 0.1715
# 0.1715079
# Epoch 15/200 - Training Loss: 0.6748 - MER: 0.1529
# 0.1528844
# Epoch 15/200 - Valid Loss: 0.7332 - MER: 0.1688
# 0.16876683
# Epoch 16/200 - Training Loss: 0.6694 - MER: 0.1470
# 0.14699319
# Epoch 16/200 - Valid Loss: 0.7104 - MER: 0.1590
# 0.1590155
# Epoch 17/200 - Training Loss: 0.6527 - MER: 0.1463
# 0.14632274
# Epoch 17/200 - Valid Loss: 0.7197 - MER: 0.1578
# 0.15776435
# Epoch 18/200 - Training Loss: 0.6558 - MER: 0.1496
# 0.14964715
# Epoch 18/200 - Valid Loss: 0.7222 - MER: 0.1608
# 0.16078107
# Epoch 19/200 - Training Loss: 0.6389 - MER: 0.1447
# 0.1447059
# Epoch 19/200 - Valid Loss: 0.7390 - MER: 0.1540
# 0.15399481
# Epoch 20/200 - Training Loss: 0.6359 - MER: 0.1428
# 0.14280163
# Epoch 20/200 - Valid Loss: 0.7143 - MER: 0.1528
# 0.15280905
# Epoch 21/200 - Training Loss: 0.6293 - MER: 0.1532
# 0.15318969
# Epoch 21/200 - Valid Loss: 0.7367 - MER: 0.1667
# 0.16671297
# Epoch 22/200 - Training Loss: 0.6230 - MER: 0.1456
# 0.1456441
# Epoch 22/200 - Valid Loss: 0.7162 - MER: 0.1559
# 0.15588868
# Epoch 23/200 - Training Loss: 0.6104 - MER: 0.1410
# 0.14101635
# Epoch 23/200 - Valid Loss: 0.7117 - MER: 0.1551
# 0.15507527
# Epoch 24/200 - Training Loss: 0.6233 - MER: 0.1414
# 0.14144397
# Epoch 24/200 - Valid Loss: 0.7083 - MER: 0.1523
# 0.15227379
# Epoch 25/200 - Training Loss: 0.6216 - MER: 0.1430
# 0.1429506
# Epoch 25/200 - Valid Loss: 0.7211 - MER: 0.1533
# 0.15328343
# Epoch 26/200 - Training Loss: 0.6217 - MER: 0.1468
# 0.14676431
# Epoch 26/200 - Valid Loss: 0.7172 - MER: 0.1624
# 0.1624155
# Epoch 27/200 - Training Loss: 0.6250 - MER: 0.1447
# 0.14467272
# Epoch 27/200 - Valid Loss: 0.7438 - MER: 0.1539
# 0.15390863
# Epoch 28/200 - Training Loss: 0.6113 - MER: 0.1406
# 0.14055026
# Epoch 28/200 - Valid Loss: 0.7112 - MER: 0.1530
# 0.15299417
# Epoch 29/200 - Training Loss: 0.6040 - MER: 0.1451
# 0.14512706
# Epoch 29/200 - Valid Loss: 0.7528 - MER: 0.1565
# 0.15653549
# Epoch 30/200 - Training Loss: 0.5941 - MER: 0.1385
# 0.13847351
# Epoch 30/200 - Valid Loss: 0.7317 - MER: 0.1549
# 0.15486059
# Epoch 31/200 - Training Loss: 0.5988 - MER: 0.1347
# 0.13466221
# Epoch 31/200 - Valid Loss: 0.7061 - MER: 0.1541
# 0.15412892
# Epoch 32/200 - Training Loss: 0.5829 - MER: 0.1382
# 0.13816321
# Epoch 32/200 - Valid Loss: 0.7151 - MER: 0.1586
# 0.15861341
# Epoch 33/200 - Training Loss: 0.5956 - MER: 0.1333
# 0.13330983
# Epoch 33/200 - Valid Loss: 0.7458 - MER: 0.1463
# 0.14625886
# Epoch 34/200 - Training Loss: 0.5832 - MER: 0.1382
# 0.13821551
# Epoch 34/200 - Valid Loss: 0.7240 - MER: 0.1557
# 0.15573616
# Epoch 35/200 - Training Loss: 0.5998 - MER: 0.1397
# 0.13972399
# Epoch 35/200 - Valid Loss: 0.7261 - MER: 0.1567
# 0.15671748
# Epoch 36/200 - Training Loss: 0.5817 - MER: 0.1485
# 0.14846659
# Epoch 36/200 - Valid Loss: 0.7343 - MER: 0.1638
# 0.16376153
# Epoch 37/200 - Training Loss: 0.5892 - MER: 0.1465
# 0.14648679
# Epoch 37/200 - Valid Loss: 0.7667 - MER: 0.1541
# 0.15412647
# Epoch 38/200 - Training Loss: 0.5895 - MER: 0.1310
# 0.13102634
# Epoch 38/200 - Valid Loss: 0.7266 - MER: 0.1459
# 0.14589013
# Epoch 39/200 - Training Loss: 0.5727 - MER: 0.1393
# 0.13931865
# Epoch 39/200 - Valid Loss: 0.7251 - MER: 0.1587
# 0.15874083
# Epoch 40/200 - Training Loss: 0.5756 - MER: 0.1454
# 0.14536761
# Epoch 40/200 - Valid Loss: 0.7411 - MER: 0.1635
# 0.16346821
# Epoch 41/200 - Training Loss: 0.5696 - MER: 0.1337
# 0.1336532
# Epoch 41/200 - Valid Loss: 0.7091 - MER: 0.1514
# 0.15135086
# Epoch 42/200 - Training Loss: 0.5658 - MER: 0.1265
# 0.12653449
# Epoch 42/200 - Valid Loss: 0.7043 - MER: 0.1481
# 0.14808647
# Epoch 43/200 - Training Loss: 0.5638 - MER: 0.1308
# 0.13082626
# Epoch 43/200 - Valid Loss: 0.6982 - MER: 0.1513
# 0.15134245
# Epoch 44/200 - Training Loss: 0.5824 - MER: 0.1287
# 0.12869662
# Epoch 44/200 - Valid Loss: 0.7004 - MER: 0.1499
# 0.14993559
# Epoch 45/200 - Training Loss: 0.5499 - MER: 0.1356
# 0.13559884
# Epoch 45/200 - Valid Loss: 0.7077 - MER: 0.1512
# 0.15120693
# Epoch 46/200 - Training Loss: 0.5603 - MER: 0.1316
# 0.131605
# Epoch 46/200 - Valid Loss: 0.6957 - MER: 0.1542
# 0.15419498
# Epoch 47/200 - Training Loss: 0.5608 - MER: 0.1353
# 0.13530582
# Epoch 47/200 - Valid Loss: 0.7116 - MER: 0.1555
# 0.15546735
# Epoch 48/200 - Training Loss: 0.5616 - MER: 0.1434
# 0.14336693
# Epoch 48/200 - Valid Loss: 0.7507 - MER: 0.1622
# 0.16217774
# Epoch 49/200 - Training Loss: 0.5537 - MER: 0.1343
# 0.13427594
# Epoch 49/200 - Valid Loss: 0.7059 - MER: 0.1554
# 0.15544426
# Epoch 50/200 - Training Loss: 0.5483 - MER: 0.1327
# 0.13267888
# Epoch 50/200 - Valid Loss: 0.7391 - MER: 0.1509
# 0.15087023
# Epoch 51/200 - Training Loss: 0.5489 - MER: 0.1312
# 0.1312246
# Epoch 51/200 - Valid Loss: 0.7162 - MER: 0.1483
# 0.1482802
# Epoch 52/200 - Training Loss: 0.5395 - MER: 0.1238
# 0.12379973
# Epoch 52/200 - Valid Loss: 0.7004 - MER: 0.1464
# 0.14638817
# Epoch 53/200 - Training Loss: 0.5415 - MER: 0.1304
# 0.13035893
# Epoch 53/200 - Valid Loss: 0.7080 - MER: 0.1502
# 0.15018374
# Epoch 54/200 - Training Loss: 0.5449 - MER: 0.1358
# 0.13581446
# Epoch 54/200 - Valid Loss: 0.7505 - MER: 0.1571
# 0.1570948
# Epoch 55/200 - Training Loss: 0.5437 - MER: 0.1236
# 0.12362969
# Epoch 55/200 - Valid Loss: 0.7052 - MER: 0.1440
# 0.14395498
# Epoch 56/200 - Training Loss: 0.5398 - MER: 0.1259
# 0.12588999
# Epoch 56/200 - Valid Loss: 0.6928 - MER: 0.1469
# 0.14692971
# Epoch 57/200 - Training Loss: 0.5373 - MER: 0.1220
# 0.1220372
# Epoch 57/200 - Valid Loss: 0.6841 - MER: 0.1440
# 0.1440471
# Epoch 58/200 - Training Loss: 0.5233 - MER: 0.1287
# 0.12872232
# Epoch 58/200 - Valid Loss: 0.7111 - MER: 0.1525
# 0.15253323
# Epoch 59/200 - Training Loss: 0.5392 - MER: 0.1332
# 0.13320872
# Epoch 59/200 - Valid Loss: 0.7120 - MER: 0.1558
# 0.15576297
# Epoch 60/200 - Training Loss: 0.5379 - MER: 0.1242
# 0.1241682
# Epoch 60/200 - Valid Loss: 0.7051 - MER: 0.1452
# 0.14522992
# Epoch 61/200 - Training Loss: 0.5361 - MER: 0.1311
# 0.13114509
# Epoch 61/200 - Valid Loss: 0.7107 - MER: 0.1550
# 0.15500365
# Epoch 62/200 - Training Loss: 0.5349 - MER: 0.1231
# 0.12313293
# Epoch 62/200 - Valid Loss: 0.6861 - MER: 0.1457
# 0.14568785
# Epoch 63/200 - Training Loss: 0.5333 - MER: 0.1202
# 0.12017238
# Epoch 63/200 - Valid Loss: 0.6916 - MER: 0.1459
# 0.14588447
# Epoch 64/200 - Training Loss: 0.5211 - MER: 0.1295
# 0.12950125
# Epoch 64/200 - Valid Loss: 0.7240 - MER: 0.1470
# 0.14703777
# Epoch 65/200 - Training Loss: 0.5236 - MER: 0.1269
# 0.12692556
# Epoch 65/200 - Valid Loss: 0.7077 - MER: 0.1546
# 0.15461248
# Epoch 66/200 - Training Loss: 0.5211 - MER: 0.1238
# 0.12376418
# Epoch 66/200 - Valid Loss: 0.6975 - MER: 0.1473
# 0.14726219
# Epoch 67/200 - Training Loss: 0.5162 - MER: 0.1292
# 0.12916408
# Epoch 67/200 - Valid Loss: 0.6924 - MER: 0.1475
# 0.14747556
# Epoch 68/200 - Training Loss: 0.5299 - MER: 0.1305
# 0.13046223
# Epoch 68/200 - Valid Loss: 0.7058 - MER: 0.1516
# 0.15157768
# Epoch 69/200 - Training Loss: 0.5176 - MER: 0.1251
# 0.12507978
# Epoch 69/200 - Valid Loss: 0.6773 - MER: 0.1457
# 0.14567691
# Epoch 70/200 - Training Loss: 0.5159 - MER: 0.1327
# 0.1326749
# Epoch 70/200 - Valid Loss: 0.7093 - MER: 0.1550
# 0.1549746
# Epoch 71/200 - Training Loss: 0.5224 - MER: 0.1228
# 0.12284727
# Epoch 71/200 - Valid Loss: 0.6889 - MER: 0.1467
# 0.1467384
# Epoch 72/200 - Training Loss: 0.5070 - MER: 0.1179
# 0.117855944
# Epoch 72/200 - Valid Loss: 0.7015 - MER: 0.1453
# 0.14533935
# Epoch 73/200 - Training Loss: 0.5091 - MER: 0.1255
# 0.12554461
# Epoch 73/200 - Valid Loss: 0.7044 - MER: 0.1518
# 0.15177071
# Epoch 74/200 - Training Loss: 0.5149 - MER: 0.1228
# 0.12283665
# Epoch 74/200 - Valid Loss: 0.7273 - MER: 0.1458
# 0.1457778
# Epoch 75/200 - Training Loss: 0.5089 - MER: 0.1269
# 0.12694103
# Epoch 75/200 - Valid Loss: 0.7330 - MER: 0.1510
# 0.15098251
# Epoch 76/200 - Training Loss: 0.5028 - MER: 0.1206
# 0.120634526
# Epoch 76/200 - Valid Loss: 0.6913 - MER: 0.1437
# 0.1437136
# Epoch 77/200 - Training Loss: 0.5114 - MER: 0.1189
# 0.11888456
# Epoch 77/200 - Valid Loss: 0.6783 - MER: 0.1451
# 0.14514697
# Epoch 78/200 - Training Loss: 0.5098 - MER: 0.1195
# 0.119493954
# Epoch 78/200 - Valid Loss: 0.6999 - MER: 0.1467
# 0.14665568
# Epoch 79/200 - Training Loss: 0.5038 - MER: 0.1174
# 0.1174445
# Epoch 79/200 - Valid Loss: 0.6701 - MER: 0.1437
# 0.14372285
# Epoch 80/200 - Training Loss: 0.5019 - MER: 0.1237
# 0.123685434
# Epoch 80/200 - Valid Loss: 0.6910 - MER: 0.1505
# 0.15049766
# Epoch 81/200 - Training Loss: 0.5182 - MER: 0.1299
# 0.12991625
# Epoch 81/200 - Valid Loss: 0.7113 - MER: 0.1532
# 0.15315479
# Epoch 82/200 - Training Loss: 0.4934 - MER: 0.1144
# 0.11439836
# Epoch 82/200 - Valid Loss: 0.6819 - MER: 0.1427
# 0.1427492
# Epoch 83/200 - Training Loss: 0.4882 - MER: 0.1217
# 0.12166254
# Epoch 83/200 - Valid Loss: 0.7201 - MER: 0.1461
# 0.14614785
# Epoch 84/200 - Training Loss: 0.4913 - MER: 0.1152
# 0.11524274
# Epoch 84/200 - Valid Loss: 0.6859 - MER: 0.1413
# 0.14133708
# Epoch 85/200 - Training Loss: 0.4860 - MER: 0.1176
# 0.117576405
# Epoch 85/200 - Valid Loss: 0.6943 - MER: 0.1484
# 0.14840603
# Epoch 86/200 - Training Loss: 0.5023 - MER: 0.1188
# 0.11877406
# Epoch 86/200 - Valid Loss: 0.7312 - MER: 0.1453
# 0.14528593
# Epoch 87/200 - Training Loss: 0.4978 - MER: 0.1171
# 0.117085956
# Epoch 87/200 - Valid Loss: 0.7091 - MER: 0.1480
# 0.1480108
# Epoch 88/200 - Training Loss: 0.4913 - MER: 0.1161
# 0.11609991
# Epoch 88/200 - Valid Loss: 0.6791 - MER: 0.1454
# 0.14543554
# Epoch 89/200 - Training Loss: 0.4859 - MER: 0.1154
# 0.11542981
# Epoch 89/200 - Valid Loss: 0.6902 - MER: 0.1395
# 0.13950053
# Epoch 90/200 - Training Loss: 0.4779 - MER: 0.1202
# 0.12023106
# Epoch 90/200 - Valid Loss: 0.6937 - MER: 0.1502
# 0.15016523
# Epoch 91/200 - Training Loss: 0.4898 - MER: 0.1181
# 0.118106574
# Epoch 91/200 - Valid Loss: 0.6982 - MER: 0.1466
# 0.1466164
# Epoch 92/200 - Training Loss: 0.4836 - MER: 0.1137
# 0.11369963
# Epoch 92/200 - Valid Loss: 0.6843 - MER: 0.1445
# 0.1444983
# Epoch 93/200 - Training Loss: 0.4789 - MER: 0.1188
# 0.11878522
# Epoch 93/200 - Valid Loss: 0.6976 - MER: 0.1490
# 0.14895439
# Epoch 94/200 - Training Loss: 0.4894 - MER: 0.1114
# 0.11142791
# Epoch 94/200 - Valid Loss: 0.6833 - MER: 0.1429
# 0.14291343
# Epoch 95/200 - Training Loss: 0.4900 - MER: 0.1192
# 0.11922589
# Epoch 95/200 - Valid Loss: 0.7495 - MER: 0.1440
# 0.1440353
# Epoch 96/200 - Training Loss: 0.4938 - MER: 0.1181
# 0.11809634
# Epoch 96/200 - Valid Loss: 0.6956 - MER: 0.1446
# 0.14455302
# Epoch 97/200 - Training Loss: 0.4939 - MER: 0.1134
# 0.113363445
# Epoch 97/200 - Valid Loss: 0.6968 - MER: 0.1457
# 0.14572757
# Epoch 98/200 - Training Loss: 0.4933 - MER: 0.1350
# 0.13502698
# Epoch 98/200 - Valid Loss: 0.7197 - MER: 0.1580
# 0.15800735
# Epoch 99/200 - Training Loss: 0.4886 - MER: 0.1204
# 0.12042445
# Epoch 99/200 - Valid Loss: 0.6858 - MER: 0.1502
# 0.15017398
# Epoch 100/200 - Training Loss: 0.4706 - MER: 0.1225
# 0.122524545
# Epoch 100/200 - Valid Loss: 0.7181 - MER: 0.1468
# 0.14683346
# Epoch 101/200 - Training Loss: 0.4733 - MER: 0.1227
# 0.122692585
# Epoch 101/200 - Valid Loss: 0.7080 - MER: 0.1495
# 0.14951505
# Epoch 102/200 - Training Loss: 0.4695 - MER: 0.1284
# 0.12837659
# Epoch 102/200 - Valid Loss: 0.7180 - MER: 0.1570
# 0.15702346
# Epoch 103/200 - Training Loss: 0.4880 - MER: 0.1121
# 0.11212831
# Epoch 103/200 - Valid Loss: 0.6929 - MER: 0.1418
# 0.14184928
# Epoch 104/200 - Training Loss: 0.4785 - MER: 0.1138
# 0.11377002
# Epoch 104/200 - Valid Loss: 0.6929 - MER: 0.1445
# 0.14454193
# Epoch 105/200 - Training Loss: 0.4686 - MER: 0.1101
# 0.11008939
# Epoch 105/200 - Valid Loss: 0.6856 - MER: 0.1417
# 0.1417062
# Epoch 106/200 - Training Loss: 0.4910 - MER: 0.1202
# 0.12022475
# Epoch 106/200 - Valid Loss: 0.7387 - MER: 0.1470
# 0.1469963
# Epoch 107/200 - Training Loss: 0.4782 - MER: 0.1142
# 0.11415074
# Epoch 107/200 - Valid Loss: 0.6926 - MER: 0.1443
# 0.14431386
# Epoch 108/200 - Training Loss: 0.4644 - MER: 0.1179
# 0.11786018
# Epoch 108/200 - Valid Loss: 0.7025 - MER: 0.1508
# 0.15082565
# Epoch 109/200 - Training Loss: 0.4706 - MER: 0.1108
# 0.11076748
# Epoch 109/200 - Valid Loss: 0.6792 - MER: 0.1447
# 0.14470793
# Epoch 110/200 - Training Loss: 0.4711 - MER: 0.1196
# 0.11957711
# Epoch 110/200 - Valid Loss: 0.7309 - MER: 0.1463
# 0.14629902
# Epoch 111/200 - Training Loss: 0.4658 - MER: 0.1110
# 0.11097409
# Epoch 111/200 - Valid Loss: 0.6853 - MER: 0.1445
# 0.14452417
# Epoch 112/200 - Training Loss: 0.4628 - MER: 0.1169
# 0.11689658
# Epoch 112/200 - Valid Loss: 0.6841 - MER: 0.1422
# 0.14219433
# Epoch 113/200 - Training Loss: 0.4679 - MER: 0.1099
# 0.10986261
# Epoch 113/200 - Valid Loss: 0.6909 - MER: 0.1443
# 0.144343
# Epoch 114/200 - Training Loss: 0.4546 - MER: 0.1123
# 0.112299554
# Epoch 114/200 - Valid Loss: 0.6857 - MER: 0.1415
# 0.14153771
# Epoch 115/200 - Training Loss: 0.4568 - MER: 0.1189
# 0.11887744
# Epoch 115/200 - Valid Loss: 0.7157 - MER: 0.1500
# 0.1499894
# Epoch 116/200 - Training Loss: 0.4576 - MER: 0.1100
# 0.10995856
# Epoch 116/200 - Valid Loss: 0.6925 - MER: 0.1423
# 0.14233816
# Epoch 117/200 - Training Loss: 0.4626 - MER: 0.1125
# 0.11254091
# Epoch 117/200 - Valid Loss: 0.7039 - MER: 0.1436
# 0.14357567
# Epoch 118/200 - Training Loss: 0.4698 - MER: 0.1235
# 0.12351621
# Epoch 118/200 - Valid Loss: 0.7204 - MER: 0.1586
# 0.15859596
# Epoch 119/200 - Training Loss: 0.4676 - MER: 0.1101
# 0.110132575
# Epoch 119/200 - Valid Loss: 0.6915 - MER: 0.1420
# 0.1419721
# Epoch 120/200 - Training Loss: 0.4461 - MER: 0.1134
# 0.11339008
# Epoch 120/200 - Valid Loss: 0.6880 - MER: 0.1452
# 0.14521448
# Epoch 121/200 - Training Loss: 0.4525 - MER: 0.1142
# 0.114227235
# Epoch 121/200 - Valid Loss: 0.6858 - MER: 0.1440
# 0.14401399
# Epoch 122/200 - Training Loss: 0.4465 - MER: 0.1136
# 0.11362444
# Epoch 122/200 - Valid Loss: 0.7160 - MER: 0.1461
# 0.1461109
# Epoch 123/200 - Training Loss: 0.4444 - MER: 0.1092
# 0.10921611
# Epoch 123/200 - Valid Loss: 0.7026 - MER: 0.1440
# 0.14397547
# Epoch 124/200 - Training Loss: 0.4521 - MER: 0.1122
# 0.11224585
# Epoch 124/200 - Valid Loss: 0.7121 - MER: 0.1432
# 0.14317384
# Epoch 125/200 - Training Loss: 0.4480 - MER: 0.1113
# 0.11128001
# Epoch 125/200 - Valid Loss: 0.7032 - MER: 0.1453
# 0.14533012
# Epoch 126/200 - Training Loss: 0.4521 - MER: 0.1109
# 0.11086179
# Epoch 126/200 - Valid Loss: 0.7093 - MER: 0.1446
# 0.14458136
# Epoch 127/200 - Training Loss: 0.4449 - MER: 0.1096
# 0.10957466
# Epoch 127/200 - Valid Loss: 0.7014 - MER: 0.1463
# 0.14633967
# Epoch 128/200 - Training Loss: 0.4492 - MER: 0.1130
# 0.11296322
# Epoch 128/200 - Valid Loss: 0.6927 - MER: 0.1444
# 0.14438134
# Epoch 129/200 - Training Loss: 0.4397 - MER: 0.1160
# 0.11595457
# Epoch 129/200 - Valid Loss: 0.7067 - MER: 0.1457
# 0.14574946
# Epoch 130/200 - Training Loss: 0.4543 - MER: 0.1150
# 0.11504635
# Epoch 130/200 - Valid Loss: 0.7295 - MER: 0.1536
# 0.1536485
# Epoch 131/200 - Training Loss: 0.4477 - MER: 0.1080
# 0.108035974
# Epoch 131/200 - Valid Loss: 0.6860 - MER: 0.1399
# 0.13987695
# Epoch 132/200 - Training Loss: 0.4561 - MER: 0.1124
# 0.11244227
# Epoch 132/200 - Valid Loss: 0.6929 - MER: 0.1454
# 0.1454405
# Epoch 133/200 - Training Loss: 0.4548 - MER: 0.1089
# 0.10885233
# Epoch 133/200 - Valid Loss: 0.7176 - MER: 0.1480
# 0.14799471
# Epoch 134/200 - Training Loss: 0.4351 - MER: 0.1106
# 0.11062066
# Epoch 134/200 - Valid Loss: 0.6926 - MER: 0.1401
# 0.14008677
# Epoch 135/200 - Training Loss: 0.4400 - MER: 0.1083
# 0.10831406
# Epoch 135/200 - Valid Loss: 0.7326 - MER: 0.1425
# 0.14254351
# Epoch 136/200 - Training Loss: 0.4407 - MER: 0.1171
# 0.11712762
# Epoch 136/200 - Valid Loss: 0.7311 - MER: 0.1489
# 0.1489171
# Epoch 137/200 - Training Loss: 0.4473 - MER: 0.1197
# 0.11970065
# Epoch 137/200 - Valid Loss: 0.7944 - MER: 0.1481
# 0.1481136
# Epoch 138/200 - Training Loss: 0.4551 - MER: 0.1243
# 0.124347195
# Epoch 138/200 - Valid Loss: 0.7312 - MER: 0.1535
# 0.15346248
# Epoch 139/200 - Training Loss: 0.4404 - MER: 0.1068
# 0.10675728
# Epoch 139/200 - Valid Loss: 0.7059 - MER: 0.1396
# 0.13959901
# Epoch 140/200 - Training Loss: 0.4385 - MER: 0.1162
# 0.11623582
# Epoch 140/200 - Valid Loss: 0.6975 - MER: 0.1512
# 0.15117894
# Epoch 141/200 - Training Loss: 0.4318 - MER: 0.1092
# 0.10920143
# Epoch 141/200 - Valid Loss: 0.7075 - MER: 0.1429
# 0.14294666
# Epoch 142/200 - Training Loss: 0.4383 - MER: 0.1161
# 0.116095774
# Epoch 142/200 - Valid Loss: 0.7128 - MER: 0.1500
# 0.15001926
# Epoch 143/200 - Training Loss: 0.4276 - MER: 0.1064
# 0.106420755
# Epoch 143/200 - Valid Loss: 0.6965 - MER: 0.1435
# 0.14348406
# Epoch 144/200 - Training Loss: 0.4252 - MER: 0.1095
# 0.1095316
# Epoch 144/200 - Valid Loss: 0.6990 - MER: 0.1473
# 0.1472775
# Epoch 145/200 - Training Loss: 0.4426 - MER: 0.1133
# 0.1133022
# Epoch 145/200 - Valid Loss: 0.7182 - MER: 0.1456
# 0.1456239
# Epoch 146/200 - Training Loss: 0.4393 - MER: 0.1053
# 0.1052766
# Epoch 146/200 - Valid Loss: 0.6991 - MER: 0.1423
# 0.14229229
# Epoch 147/200 - Training Loss: 0.4484 - MER: 0.1064
# 0.1063744
# Epoch 147/200 - Valid Loss: 0.7117 - MER: 0.1410
# 0.14102975
# Epoch 148/200 - Training Loss: 0.4458 - MER: 0.1117
# 0.11172813
# Epoch 148/200 - Valid Loss: 0.7185 - MER: 0.1451
# 0.14505066
# Epoch 149/200 - Training Loss: 0.4284 - MER: 0.1118
# 0.11177596
# Epoch 149/200 - Valid Loss: 0.7118 - MER: 0.1463
# 0.14631216
# Epoch 150/200 - Training Loss: 0.4295 - MER: 0.1046
# 0.10459726
# Epoch 150/200 - Valid Loss: 0.6798 - MER: 0.1386
# 0.13859428
# Epoch 151/200 - Training Loss: 0.4254 - MER: 0.1049
# 0.104936525
# Epoch 151/200 - Valid Loss: 0.6910 - MER: 0.1438
# 0.14381558
# Epoch 152/200 - Training Loss: 0.4219 - MER: 0.1078
# 0.10780033
# Epoch 152/200 - Valid Loss: 0.6981 - MER: 0.1467
# 0.1466966
# Epoch 153/200 - Training Loss: 0.4317 - MER: 0.1099
# 0.10993457
# Epoch 153/200 - Valid Loss: 0.7058 - MER: 0.1447
# 0.14471541
# Epoch 154/200 - Training Loss: 0.4302 - MER: 0.1103
# 0.11025362
# Epoch 154/200 - Valid Loss: 0.7019 - MER: 0.1488
# 0.14876935
# Epoch 155/200 - Training Loss: 0.4227 - MER: 0.1096
# 0.109554544
# Epoch 155/200 - Valid Loss: 0.6977 - MER: 0.1425
# 0.14252979
# Epoch 156/200 - Training Loss: 0.4482 - MER: 0.1203
# 0.12031772
# Epoch 156/200 - Valid Loss: 0.7483 - MER: 0.1561
# 0.15612175
# Epoch 157/200 - Training Loss: 0.4348 - MER: 0.1082
# 0.10821853
# Epoch 157/200 - Valid Loss: 0.7264 - MER: 0.1449
# 0.14489725
# Epoch 158/200 - Training Loss: 0.4226 - MER: 0.1098
# 0.109811574
# Epoch 158/200 - Valid Loss: 0.7165 - MER: 0.1452
# 0.14520583
# Epoch 159/200 - Training Loss: 0.4218 - MER: 0.1077
# 0.10765129
# Epoch 159/200 - Valid Loss: 0.6999 - MER: 0.1438
# 0.14379661
# Epoch 160/200 - Training Loss: 0.4347 - MER: 0.1111
# 0.111143306
# Epoch 160/200 - Valid Loss: 0.7117 - MER: 0.1519
# 0.15191786
# Epoch 161/200 - Training Loss: 0.4317 - MER: 0.1055
# 0.1054506
# Epoch 161/200 - Valid Loss: 0.7074 - MER: 0.1436
# 0.14358471
# Epoch 162/200 - Training Loss: 0.4169 - MER: 0.1131
# 0.11305063
# Epoch 162/200 - Valid Loss: 0.7067 - MER: 0.1531
# 0.15309039
# Epoch 163/200 - Training Loss: 0.4408 - MER: 0.1162
# 0.116187215
# Epoch 163/200 - Valid Loss: 0.7196 - MER: 0.1564
# 0.15641141
# Epoch 164/200 - Training Loss: 0.4290 - MER: 0.1107
# 0.110663265
# Epoch 164/200 - Valid Loss: 0.7076 - MER: 0.1424
# 0.14237036
# Epoch 165/200 - Training Loss: 0.4194 - MER: 0.1030
# 0.10297756
# Epoch 165/200 - Valid Loss: 0.7102 - MER: 0.1456
# 0.14560795
# Epoch 166/200 - Training Loss: 0.4154 - MER: 0.1074
# 0.10737072
# Epoch 166/200 - Valid Loss: 0.6993 - MER: 0.1464
# 0.14636233
# Epoch 167/200 - Training Loss: 0.4252 - MER: 0.1067
# 0.106650546
# Epoch 167/200 - Valid Loss: 0.6936 - MER: 0.1467
# 0.14670216
# Epoch 168/200 - Training Loss: 0.4183 - MER: 0.1053
# 0.10534179
# Epoch 168/200 - Valid Loss: 0.7044 - MER: 0.1484
# 0.14838162
# Epoch 169/200 - Training Loss: 0.4163 - MER: 0.1026
# 0.102562234
# Epoch 169/200 - Valid Loss: 0.7064 - MER: 0.1432
# 0.14321132
# Epoch 170/200 - Training Loss: 0.4145 - MER: 0.1035
# 0.10348499
# Epoch 170/200 - Valid Loss: 0.7247 - MER: 0.1469
# 0.14689091
# Epoch 171/200 - Training Loss: 0.4124 - MER: 0.1041
# 0.104077
# Epoch 171/200 - Valid Loss: 0.7146 - MER: 0.1434
# 0.14342357
# Epoch 172/200 - Training Loss: 0.4164 - MER: 0.1091
# 0.109143265
# Epoch 172/200 - Valid Loss: 0.7148 - MER: 0.1512
# 0.1512273
# Epoch 173/200 - Training Loss: 0.4093 - MER: 0.1096
# 0.10958421
# Epoch 173/200 - Valid Loss: 0.7100 - MER: 0.1484
# 0.1483557
# Epoch 174/200 - Training Loss: 0.4183 - MER: 0.1068
# 0.1067615
# Epoch 174/200 - Valid Loss: 0.7460 - MER: 0.1422
# 0.14216176
# Epoch 175/200 - Training Loss: 0.4299 - MER: 0.1056
# 0.10559052
# Epoch 175/200 - Valid Loss: 0.7024 - MER: 0.1458
# 0.14580397
# Epoch 176/200 - Training Loss: 0.4088 - MER: 0.1012
# 0.10115385
# Epoch 176/200 - Valid Loss: 0.7072 - MER: 0.1431
# 0.14306311
# Epoch 177/200 - Training Loss: 0.4076 - MER: 0.1108
# 0.11082296
# Epoch 177/200 - Valid Loss: 0.7085 - MER: 0.1524
# 0.15239902
# Epoch 178/200 - Training Loss: 0.4207 - MER: 0.1062
# 0.10617548
# Epoch 178/200 - Valid Loss: 0.6948 - MER: 0.1439
# 0.14386971
# Epoch 179/200 - Training Loss: 0.4228 - MER: 0.1108
# 0.11084683
# Epoch 179/200 - Valid Loss: 0.7257 - MER: 0.1510
# 0.15102313
# Epoch 180/200 - Training Loss: 0.4236 - MER: 0.1166
# 0.11660074
# Epoch 180/200 - Valid Loss: 0.7514 - MER: 0.1580
# 0.15800251
# Epoch 181/200 - Training Loss: 0.4185 - MER: 0.1046
# 0.104557805
# Epoch 181/200 - Valid Loss: 0.7255 - MER: 0.1435
# 0.14351694
# Epoch 182/200 - Training Loss: 0.4125 - MER: 0.1019
# 0.10191508
# Epoch 182/200 - Valid Loss: 0.6922 - MER: 0.1446
# 0.14458846
# Epoch 183/200 - Training Loss: 0.4002 - MER: 0.1060
# 0.10597497
# Epoch 183/200 - Valid Loss: 0.7146 - MER: 0.1467
# 0.14672063
# Epoch 184/200 - Training Loss: 0.4152 - MER: 0.1080
# 0.10801637
# Epoch 184/200 - Valid Loss: 0.7252 - MER: 0.1444
# 0.14443992
# Epoch 185/200 - Training Loss: 0.4088 - MER: 0.1114
# 0.11137691
# Epoch 185/200 - Valid Loss: 0.7196 - MER: 0.1500
# 0.14996427
# Epoch 186/200 - Training Loss: 0.4099 - MER: 0.1076
# 0.10757278
# Epoch 186/200 - Valid Loss: 0.7334 - MER: 0.1441
# 0.14413595
# Epoch 187/200 - Training Loss: 0.4276 - MER: 0.1052
# 0.105236284
# Epoch 187/200 - Valid Loss: 0.7022 - MER: 0.1396
# 0.13958763
# Epoch 188/200 - Training Loss: 0.4218 - MER: 0.1224
# 0.122440994
# Epoch 188/200 - Valid Loss: 0.7456 - MER: 0.1586
# 0.15860581
# Epoch 189/200 - Training Loss: 0.4084 - MER: 0.1023
# 0.102276854
# Epoch 189/200 - Valid Loss: 0.6845 - MER: 0.1415
# 0.14147897
# Epoch 190/200 - Training Loss: 0.4014 - MER: 0.1150
# 0.11504671
# Epoch 190/200 - Valid Loss: 0.7598 - MER: 0.1469
# 0.14686702
# Epoch 191/200 - Training Loss: 0.4216 - MER: 0.1030
# 0.102954485
# Epoch 191/200 - Valid Loss: 0.7256 - MER: 0.1434
# 0.14339589
# Epoch 192/200 - Training Loss: 0.3931 - MER: 0.1135
# 0.11348955
# Epoch 192/200 - Valid Loss: 0.7105 - MER: 0.1460
# 0.14597274
# Epoch 193/200 - Training Loss: 0.4085 - MER: 0.1094
# 0.10940319
# Epoch 193/200 - Valid Loss: 0.7466 - MER: 0.1502
# 0.1502027
# Epoch 194/200 - Training Loss: 0.4058 - MER: 0.1073
# 0.10728948
# Epoch 194/200 - Valid Loss: 0.7081 - MER: 0.1518
# 0.15182765
# Epoch 195/200 - Training Loss: 0.4030 - MER: 0.1067
# 0.10674396
# Epoch 195/200 - Valid Loss: 0.7334 - MER: 0.1429
# 0.14294517
# Epoch 196/200 - Training Loss: 0.3964 - MER: 0.1030
# 0.10297245
# Epoch 196/200 - Valid Loss: 0.7254 - MER: 0.1431
# 0.14305782
# Epoch 197/200 - Training Loss: 0.4276 - MER: 0.1082
# 0.10822856
# Epoch 197/200 - Valid Loss: 0.7586 - MER: 0.1453
# 0.14527182
# Epoch 198/200 - Training Loss: 0.4109 - MER: 0.1077
# 0.10766578
# Epoch 198/200 - Valid Loss: 0.7156 - MER: 0.1432
# 0.14319508
# Epoch 199/200 - Training Loss: 0.4070 - MER: 0.0994
# 0.09935234
# Epoch 199/200 - Valid Loss: 0.7059 - MER: 0.1407
# 0.14067915
# Epoch 200/200 - Training Loss: 0.3896 - MER: 0.1062
# 0.10622972
# Epoch 200/200 - Valid Loss: 0.7168 - MER: 0.1447
# 0.14471802

# %%
#TODO: Write code to plot the training and validation error (MER) over epochs
plt.plot(mer_values_train_MLP, label='Training MER')
plt.plot(mer_values_valid_MLP, label='Validation MER')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Change network architecture

# %% [markdown]
# In the following, build a MLP with 4 hidden layer of sizes 512, 256, 128, 64, respectively.

# %%
#TODO: building a MLP with 4 hidden layer of sizes 512, 256, 128, 64,
model_2 = nn.Sequential(nn.Linear(train_features.shape[1], 512),
                      nn.ReLU(),
                      nn.Linear(512, 256),
                      nn.ReLU(),
                      nn.Linear(256, 128),
                      nn.ReLU(),
                      nn.Linear(128, 64),
                      nn.ReLU(),
                      nn.Linear(64,1))
model_2.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=12, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=512, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=128, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=128, out_features=64, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
#Train the MLP network and save training and validation error.
criterion_MLP_2 = nn.SmoothL1Loss()
optimizer_MLP_2 = optim.Adam(model_2.parameters(), lr=0.001)

epochs=200
train_losses_MLP_2, valid_losses_MLP_2 = [], []

# Initialize empty lists to store MER values
mer_values_train_MLP_2, mer_values_valid_MLP_2 = [], []

for e in range(epochs):
  running_train_loss=0
  for batch_features, batch_labels in train_loader:
    batch_features = batch_features.to(device)
    batch_labels = batch_labels.to(device)

    logps=model_2(batch_features)
    loss=criterion_MLP_2(logps, batch_labels)
    optimizer_MLP_2.zero_grad()
    loss.backward()
    optimizer_MLP_2.step()

    running_train_loss += loss.item()

  else:
    running_valid_loss = 0
    with torch.no_grad():
      for batch_features, batch_labels in valid_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        outputs = model_2(batch_features)
        loss = criterion_MLP_2(outputs, batch_labels)
        running_valid_loss += loss.item()


    train_loss = running_train_loss/len(train_loader)
    valid_loss = running_valid_loss/len(valid_loader)
    train_losses_MLP_2.append(train_loss)
    valid_losses_MLP_2.append(valid_loss)



  # Calculate MER for this epoch and append to the list
  train_loss = running_train_loss / len(train_loader)
  train_losses_MLP_2.append(train_loss)

  valid_loss = running_valid_loss / len(valid_loader)
  valid_losses_MLP_2.append(valid_loss)

  # Calculate MER based on your code
  train_features = train_features.to(device)
  train_labels = train_labels.to(device)
  valid_features = valid_features.to(device)
  valid_labels = valid_labels.to(device)

  predicted_train = model_2(train_features).cpu().detach().numpy()
  actual_train = train_labels.cpu().numpy()
  error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
  mer_train_MLP = np.median(error_rates_train)
  mer_values_train_MLP_2.append(mer_train_MLP)

  predicted_valid = model_2(valid_features).cpu().detach().numpy()
  actual_valid = valid_labels.cpu().numpy()
  error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
  mer_valid_MLP = np.median(error_rates_valid)
  mer_values_valid_MLP_2.append(mer_valid_MLP)



  print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
  print(mer_train_MLP)
  print(f"Epoch {e + 1}/{epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid_MLP:.4f}")
  print(mer_valid_MLP)
# Out:
# Epoch 1/200 - Training Loss: 1.9493 - MER: 0.2228
# 0.22284445
# Epoch 1/200 - Valid Loss: 1.0249 - MER: 0.2269
# 0.22689787
# Epoch 2/200 - Training Loss: 0.9390 - MER: 0.2025
# 0.2025386
# Epoch 2/200 - Valid Loss: 0.8784 - MER: 0.2005
# 0.20053335
# Epoch 3/200 - Training Loss: 0.8534 - MER: 0.1832
# 0.18316439
# Epoch 3/200 - Valid Loss: 0.7906 - MER: 0.1793
# 0.1792743
# Epoch 4/200 - Training Loss: 0.7873 - MER: 0.1800
# 0.17998451
# Epoch 4/200 - Valid Loss: 0.7991 - MER: 0.1781
# 0.1780631
# Epoch 5/200 - Training Loss: 0.7616 - MER: 0.1736
# 0.1735884
# Epoch 5/200 - Valid Loss: 0.7444 - MER: 0.1783
# 0.1782588
# Epoch 6/200 - Training Loss: 0.7363 - MER: 0.1630
# 0.16302326
# Epoch 6/200 - Valid Loss: 0.7358 - MER: 0.1704
# 0.17035529
# Epoch 7/200 - Training Loss: 0.7189 - MER: 0.1620
# 0.16196612
# Epoch 7/200 - Valid Loss: 0.7215 - MER: 0.1665
# 0.16648647
# Epoch 8/200 - Training Loss: 0.7019 - MER: 0.1581
# 0.1581343
# Epoch 8/200 - Valid Loss: 0.7625 - MER: 0.1645
# 0.1645231
# Epoch 9/200 - Training Loss: 0.7169 - MER: 0.1555
# 0.15545811
# Epoch 9/200 - Valid Loss: 0.7122 - MER: 0.1608
# 0.16080141
# Epoch 10/200 - Training Loss: 0.6804 - MER: 0.1506
# 0.15063268
# Epoch 10/200 - Valid Loss: 0.7140 - MER: 0.1574
# 0.15742145
# Epoch 11/200 - Training Loss: 0.6736 - MER: 0.1494
# 0.14944784
# Epoch 11/200 - Valid Loss: 0.7041 - MER: 0.1573
# 0.1573273
# Epoch 12/200 - Training Loss: 0.6692 - MER: 0.1493
# 0.149276
# Epoch 12/200 - Valid Loss: 0.7046 - MER: 0.1587
# 0.1586598
# Epoch 13/200 - Training Loss: 0.6557 - MER: 0.1538
# 0.15384182
# Epoch 13/200 - Valid Loss: 0.7128 - MER: 0.1598
# 0.15984456
# Epoch 14/200 - Training Loss: 0.6636 - MER: 0.1519
# 0.15188201
# Epoch 14/200 - Valid Loss: 0.7001 - MER: 0.1615
# 0.16147318
# Epoch 15/200 - Training Loss: 0.6448 - MER: 0.1435
# 0.14352964
# Epoch 15/200 - Valid Loss: 0.6972 - MER: 0.1539
# 0.15385762
# Epoch 16/200 - Training Loss: 0.6378 - MER: 0.1460
# 0.14602637
# Epoch 16/200 - Valid Loss: 0.7091 - MER: 0.1527
# 0.15269122
# Epoch 17/200 - Training Loss: 0.6311 - MER: 0.1426
# 0.14264078
# Epoch 17/200 - Valid Loss: 0.6981 - MER: 0.1548
# 0.15483665
# Epoch 18/200 - Training Loss: 0.6302 - MER: 0.1466
# 0.14655605
# Epoch 18/200 - Valid Loss: 0.7032 - MER: 0.1576
# 0.15764824
# Epoch 19/200 - Training Loss: 0.6392 - MER: 0.1401
# 0.14005949
# Epoch 19/200 - Valid Loss: 0.6979 - MER: 0.1566
# 0.15661006
# Epoch 20/200 - Training Loss: 0.6212 - MER: 0.1395
# 0.13946499
# Epoch 20/200 - Valid Loss: 0.7184 - MER: 0.1493
# 0.14930728
# Epoch 21/200 - Training Loss: 0.6210 - MER: 0.1394
# 0.13937336
# Epoch 21/200 - Valid Loss: 0.6987 - MER: 0.1533
# 0.15327828
# Epoch 22/200 - Training Loss: 0.6163 - MER: 0.1424
# 0.14238198
# Epoch 22/200 - Valid Loss: 0.7241 - MER: 0.1503
# 0.15029858
# Epoch 23/200 - Training Loss: 0.6144 - MER: 0.1350
# 0.1349706
# Epoch 23/200 - Valid Loss: 0.7096 - MER: 0.1509
# 0.15090229
# Epoch 24/200 - Training Loss: 0.5984 - MER: 0.1366
# 0.1365647
# Epoch 24/200 - Valid Loss: 0.7185 - MER: 0.1502
# 0.15017319
# Epoch 25/200 - Training Loss: 0.6064 - MER: 0.1364
# 0.13636255
# Epoch 25/200 - Valid Loss: 0.7293 - MER: 0.1470
# 0.14704955
# Epoch 26/200 - Training Loss: 0.5975 - MER: 0.1339
# 0.13392049
# Epoch 26/200 - Valid Loss: 0.7181 - MER: 0.1509
# 0.15091594
# Epoch 27/200 - Training Loss: 0.6026 - MER: 0.1341
# 0.1340557
# Epoch 27/200 - Valid Loss: 0.7133 - MER: 0.1504
# 0.15042445
# Epoch 28/200 - Training Loss: 0.6018 - MER: 0.1331
# 0.13306221
# Epoch 28/200 - Valid Loss: 0.7154 - MER: 0.1491
# 0.14909005
# Epoch 29/200 - Training Loss: 0.5779 - MER: 0.1329
# 0.13292597
# Epoch 29/200 - Valid Loss: 0.7315 - MER: 0.1472
# 0.14720628
# Epoch 30/200 - Training Loss: 0.5950 - MER: 0.1349
# 0.13485445
# Epoch 30/200 - Valid Loss: 0.7409 - MER: 0.1514
# 0.15135005
# Epoch 31/200 - Training Loss: 0.5940 - MER: 0.1467
# 0.14670166
# Epoch 31/200 - Valid Loss: 0.7317 - MER: 0.1664
# 0.16639069
# Epoch 32/200 - Training Loss: 0.5995 - MER: 0.1270
# 0.12703857
# Epoch 32/200 - Valid Loss: 0.7341 - MER: 0.1476
# 0.14759429
# Epoch 33/200 - Training Loss: 0.5722 - MER: 0.1352
# 0.1352455
# Epoch 33/200 - Valid Loss: 0.7153 - MER: 0.1562
# 0.15624474
# Epoch 34/200 - Training Loss: 0.5803 - MER: 0.1277
# 0.12766577
# Epoch 34/200 - Valid Loss: 0.7155 - MER: 0.1411
# 0.14111678
# Epoch 35/200 - Training Loss: 0.5726 - MER: 0.1272
# 0.12724459
# Epoch 35/200 - Valid Loss: 0.7226 - MER: 0.1411
# 0.14114907
# Epoch 36/200 - Training Loss: 0.5856 - MER: 0.1309
# 0.13085985
# Epoch 36/200 - Valid Loss: 0.7343 - MER: 0.1486
# 0.14863904
# Epoch 37/200 - Training Loss: 0.5769 - MER: 0.1319
# 0.13187715
# Epoch 37/200 - Valid Loss: 0.7127 - MER: 0.1504
# 0.15038313
# Epoch 38/200 - Training Loss: 0.5623 - MER: 0.1299
# 0.12985146
# Epoch 38/200 - Valid Loss: 0.7203 - MER: 0.1477
# 0.1476721
# Epoch 39/200 - Training Loss: 0.5679 - MER: 0.1391
# 0.13914505
# Epoch 39/200 - Valid Loss: 0.7549 - MER: 0.1612
# 0.16121629
# Epoch 40/200 - Training Loss: 0.5489 - MER: 0.1359
# 0.13592128
# Epoch 40/200 - Valid Loss: 0.7802 - MER: 0.1582
# 0.15820253
# Epoch 41/200 - Training Loss: 0.5640 - MER: 0.1366
# 0.13664201
# Epoch 41/200 - Valid Loss: 0.7858 - MER: 0.1474
# 0.14743805
# Epoch 42/200 - Training Loss: 0.5516 - MER: 0.1286
# 0.12858567
# Epoch 42/200 - Valid Loss: 0.7415 - MER: 0.1535
# 0.15350348
# Epoch 43/200 - Training Loss: 0.5513 - MER: 0.1308
# 0.13083652
# Epoch 43/200 - Valid Loss: 0.7197 - MER: 0.1484
# 0.14839104
# Epoch 44/200 - Training Loss: 0.5372 - MER: 0.1258
# 0.12577587
# Epoch 44/200 - Valid Loss: 0.7178 - MER: 0.1453
# 0.14533615
# Epoch 45/200 - Training Loss: 0.5358 - MER: 0.1201
# 0.12008111
# Epoch 45/200 - Valid Loss: 0.7005 - MER: 0.1422
# 0.14215696
# Epoch 46/200 - Training Loss: 0.5489 - MER: 0.1222
# 0.12222814
# Epoch 46/200 - Valid Loss: 0.7214 - MER: 0.1446
# 0.14459175
# Epoch 47/200 - Training Loss: 0.5343 - MER: 0.1207
# 0.12070526
# Epoch 47/200 - Valid Loss: 0.7292 - MER: 0.1419
# 0.14193866
# Epoch 48/200 - Training Loss: 0.5387 - MER: 0.1188
# 0.118774146
# Epoch 48/200 - Valid Loss: 0.7134 - MER: 0.1402
# 0.14022271
# Epoch 49/200 - Training Loss: 0.5399 - MER: 0.1295
# 0.1294564
# Epoch 49/200 - Valid Loss: 0.7269 - MER: 0.1547
# 0.1546635
# Epoch 50/200 - Training Loss: 0.5250 - MER: 0.1209
# 0.12089646
# Epoch 50/200 - Valid Loss: 0.7149 - MER: 0.1438
# 0.14380394
# Epoch 51/200 - Training Loss: 0.5194 - MER: 0.1233
# 0.123271585
# Epoch 51/200 - Valid Loss: 0.7163 - MER: 0.1456
# 0.14558463
# Epoch 52/200 - Training Loss: 0.5276 - MER: 0.1252
# 0.12522888
# Epoch 52/200 - Valid Loss: 0.7272 - MER: 0.1495
# 0.14947926
# Epoch 53/200 - Training Loss: 0.5154 - MER: 0.1449
# 0.14490458
# Epoch 53/200 - Valid Loss: 0.7891 - MER: 0.1687
# 0.16873172
# Epoch 54/200 - Training Loss: 0.5264 - MER: 0.1178
# 0.1177742
# Epoch 54/200 - Valid Loss: 0.7052 - MER: 0.1433
# 0.14329454
# Epoch 55/200 - Training Loss: 0.5224 - MER: 0.1263
# 0.12626627
# Epoch 55/200 - Valid Loss: 0.7266 - MER: 0.1501
# 0.15011045
# Epoch 56/200 - Training Loss: 0.5173 - MER: 0.1268
# 0.1268361
# Epoch 56/200 - Valid Loss: 0.7315 - MER: 0.1493
# 0.14928867
# Epoch 57/200 - Training Loss: 0.5090 - MER: 0.1214
# 0.121361665
# Epoch 57/200 - Valid Loss: 0.7175 - MER: 0.1502
# 0.15017138
# Epoch 58/200 - Training Loss: 0.5072 - MER: 0.1161
# 0.11613119
# Epoch 58/200 - Valid Loss: 0.7234 - MER: 0.1449
# 0.14489813
# Epoch 59/200 - Training Loss: 0.5088 - MER: 0.1249
# 0.12488689
# Epoch 59/200 - Valid Loss: 0.7435 - MER: 0.1500
# 0.15003686
# Epoch 60/200 - Training Loss: 0.5034 - MER: 0.1193
# 0.11925535
# Epoch 60/200 - Valid Loss: 0.7204 - MER: 0.1427
# 0.142696
# Epoch 61/200 - Training Loss: 0.5035 - MER: 0.1265
# 0.1264638
# Epoch 61/200 - Valid Loss: 0.7443 - MER: 0.1440
# 0.1439806
# Epoch 62/200 - Training Loss: 0.4961 - MER: 0.1146
# 0.11462734
# Epoch 62/200 - Valid Loss: 0.7167 - MER: 0.1392
# 0.13915384
# Epoch 63/200 - Training Loss: 0.4971 - MER: 0.1258
# 0.12581679
# Epoch 63/200 - Valid Loss: 0.7425 - MER: 0.1484
# 0.1483685
# Epoch 64/200 - Training Loss: 0.4952 - MER: 0.1199
# 0.119932786
# Epoch 64/200 - Valid Loss: 0.7472 - MER: 0.1450
# 0.1449942
# Epoch 65/200 - Training Loss: 0.4961 - MER: 0.1175
# 0.11747894
# Epoch 65/200 - Valid Loss: 0.7276 - MER: 0.1458
# 0.14582753
# Epoch 66/200 - Training Loss: 0.4911 - MER: 0.1139
# 0.11391452
# Epoch 66/200 - Valid Loss: 0.7161 - MER: 0.1419
# 0.14191444
# Epoch 67/200 - Training Loss: 0.4895 - MER: 0.1191
# 0.119091496
# Epoch 67/200 - Valid Loss: 0.7725 - MER: 0.1505
# 0.1504824
# Epoch 68/200 - Training Loss: 0.4857 - MER: 0.1095
# 0.109540686
# Epoch 68/200 - Valid Loss: 0.7201 - MER: 0.1394
# 0.1393942
# Epoch 69/200 - Training Loss: 0.4936 - MER: 0.1211
# 0.12108204
# Epoch 69/200 - Valid Loss: 0.7332 - MER: 0.1431
# 0.14308308
# Epoch 70/200 - Training Loss: 0.4793 - MER: 0.1124
# 0.11238971
# Epoch 70/200 - Valid Loss: 0.7218 - MER: 0.1402
# 0.14023162
# Epoch 71/200 - Training Loss: 0.4743 - MER: 0.1103
# 0.11031126
# Epoch 71/200 - Valid Loss: 0.7192 - MER: 0.1381
# 0.1381478
# Epoch 72/200 - Training Loss: 0.4792 - MER: 0.1100
# 0.10997099
# Epoch 72/200 - Valid Loss: 0.7282 - MER: 0.1400
# 0.13998136
# Epoch 73/200 - Training Loss: 0.4891 - MER: 0.1173
# 0.11730425
# Epoch 73/200 - Valid Loss: 0.7349 - MER: 0.1410
# 0.14099634
# Epoch 74/200 - Training Loss: 0.4667 - MER: 0.1112
# 0.111156136
# Epoch 74/200 - Valid Loss: 0.7359 - MER: 0.1421
# 0.14208671
# Epoch 75/200 - Training Loss: 0.4790 - MER: 0.1201
# 0.12014161
# Epoch 75/200 - Valid Loss: 0.7275 - MER: 0.1522
# 0.15215845
# Epoch 76/200 - Training Loss: 0.4653 - MER: 0.1127
# 0.11265055
# Epoch 76/200 - Valid Loss: 0.7227 - MER: 0.1446
# 0.14456518
# Epoch 77/200 - Training Loss: 0.4704 - MER: 0.1105
# 0.110483944
# Epoch 77/200 - Valid Loss: 0.7435 - MER: 0.1419
# 0.141888
# Epoch 78/200 - Training Loss: 0.4785 - MER: 0.1088
# 0.10883182
# Epoch 78/200 - Valid Loss: 0.7088 - MER: 0.1414
# 0.14137362
# Epoch 79/200 - Training Loss: 0.4592 - MER: 0.1068
# 0.106820315
# Epoch 79/200 - Valid Loss: 0.7047 - MER: 0.1403
# 0.14031175
# Epoch 80/200 - Training Loss: 0.4733 - MER: 0.1158
# 0.11575164
# Epoch 80/200 - Valid Loss: 0.7343 - MER: 0.1446
# 0.1446087
# Epoch 81/200 - Training Loss: 0.4772 - MER: 0.1106
# 0.11059098
# Epoch 81/200 - Valid Loss: 0.7252 - MER: 0.1471
# 0.14710125
# Epoch 82/200 - Training Loss: 0.4486 - MER: 0.1067
# 0.1066798
# Epoch 82/200 - Valid Loss: 0.7286 - MER: 0.1413
# 0.14132519
# Epoch 83/200 - Training Loss: 0.4596 - MER: 0.1277
# 0.12774578
# Epoch 83/200 - Valid Loss: 0.7472 - MER: 0.1635
# 0.16348574
# Epoch 84/200 - Training Loss: 0.4540 - MER: 0.1074
# 0.10741844
# Epoch 84/200 - Valid Loss: 0.7210 - MER: 0.1383
# 0.13825431
# Epoch 85/200 - Training Loss: 0.4484 - MER: 0.1109
# 0.11089966
# Epoch 85/200 - Valid Loss: 0.7529 - MER: 0.1403
# 0.14033855
# Epoch 86/200 - Training Loss: 0.4524 - MER: 0.1048
# 0.10478673
# Epoch 86/200 - Valid Loss: 0.7178 - MER: 0.1382
# 0.13823077
# Epoch 87/200 - Training Loss: 0.4426 - MER: 0.1177
# 0.11770433
# Epoch 87/200 - Valid Loss: 0.7749 - MER: 0.1512
# 0.15121357
# Epoch 88/200 - Training Loss: 0.4474 - MER: 0.1068
# 0.10683805
# Epoch 88/200 - Valid Loss: 0.7115 - MER: 0.1404
# 0.14044367
# Epoch 89/200 - Training Loss: 0.4279 - MER: 0.1033
# 0.10325186
# Epoch 89/200 - Valid Loss: 0.7098 - MER: 0.1408
# 0.1407862
# Epoch 90/200 - Training Loss: 0.4348 - MER: 0.1099
# 0.10992038
# Epoch 90/200 - Valid Loss: 0.7359 - MER: 0.1398
# 0.13979298
# Epoch 91/200 - Training Loss: 0.4358 - MER: 0.1039
# 0.10391818
# Epoch 91/200 - Valid Loss: 0.7181 - MER: 0.1401
# 0.14009486
# Epoch 92/200 - Training Loss: 0.4453 - MER: 0.1048
# 0.10483065
# Epoch 92/200 - Valid Loss: 0.7205 - MER: 0.1461
# 0.14605188
# Epoch 93/200 - Training Loss: 0.4440 - MER: 0.1105
# 0.11045876
# Epoch 93/200 - Valid Loss: 0.7368 - MER: 0.1389
# 0.1389222
# Epoch 94/200 - Training Loss: 0.4400 - MER: 0.1111
# 0.111114554
# Epoch 94/200 - Valid Loss: 0.7427 - MER: 0.1520
# 0.15201238
# Epoch 95/200 - Training Loss: 0.4296 - MER: 0.1065
# 0.10647129
# Epoch 95/200 - Valid Loss: 0.7255 - MER: 0.1424
# 0.14239863
# Epoch 96/200 - Training Loss: 0.4234 - MER: 0.1031
# 0.103062175
# Epoch 96/200 - Valid Loss: 0.7201 - MER: 0.1393
# 0.13929704
# Epoch 97/200 - Training Loss: 0.4375 - MER: 0.1064
# 0.10638721
# Epoch 97/200 - Valid Loss: 0.7154 - MER: 0.1407
# 0.14068909
# Epoch 98/200 - Training Loss: 0.4330 - MER: 0.1328
# 0.13284263
# Epoch 98/200 - Valid Loss: 0.7730 - MER: 0.1670
# 0.16703059
# Epoch 99/200 - Training Loss: 0.4341 - MER: 0.1043
# 0.10433073
# Epoch 99/200 - Valid Loss: 0.7221 - MER: 0.1381
# 0.13813627
# Epoch 100/200 - Training Loss: 0.4262 - MER: 0.1014
# 0.101426475
# Epoch 100/200 - Valid Loss: 0.7265 - MER: 0.1392
# 0.1392015
# Epoch 101/200 - Training Loss: 0.4184 - MER: 0.1004
# 0.10038668
# Epoch 101/200 - Valid Loss: 0.7140 - MER: 0.1419
# 0.14186175
# Epoch 102/200 - Training Loss: 0.4210 - MER: 0.1074
# 0.10742305
# Epoch 102/200 - Valid Loss: 0.7259 - MER: 0.1447
# 0.14468557
# Epoch 103/200 - Training Loss: 0.4009 - MER: 0.1009
# 0.100887366
# Epoch 103/200 - Valid Loss: 0.7157 - MER: 0.1402
# 0.14015162
# Epoch 104/200 - Training Loss: 0.4118 - MER: 0.1051
# 0.105134666
# Epoch 104/200 - Valid Loss: 0.7199 - MER: 0.1408
# 0.14082956
# Epoch 105/200 - Training Loss: 0.4174 - MER: 0.1002
# 0.10016237
# Epoch 105/200 - Valid Loss: 0.7124 - MER: 0.1412
# 0.14120801
# Epoch 106/200 - Training Loss: 0.4108 - MER: 0.0988
# 0.09878158
# Epoch 106/200 - Valid Loss: 0.7064 - MER: 0.1378
# 0.13781098
# Epoch 107/200 - Training Loss: 0.3947 - MER: 0.0958
# 0.09578523
# Epoch 107/200 - Valid Loss: 0.7087 - MER: 0.1369
# 0.13688134
# Epoch 108/200 - Training Loss: 0.3949 - MER: 0.0974
# 0.09738854
# Epoch 108/200 - Valid Loss: 0.7135 - MER: 0.1443
# 0.14426918
# Epoch 109/200 - Training Loss: 0.3960 - MER: 0.0966
# 0.09657373
# Epoch 109/200 - Valid Loss: 0.7190 - MER: 0.1377
# 0.13771805
# Epoch 110/200 - Training Loss: 0.3927 - MER: 0.0964
# 0.09642191
# Epoch 110/200 - Valid Loss: 0.7323 - MER: 0.1390
# 0.13899803
# Epoch 111/200 - Training Loss: 0.3952 - MER: 0.0954
# 0.09541105
# Epoch 111/200 - Valid Loss: 0.6980 - MER: 0.1384
# 0.13843887
# Epoch 112/200 - Training Loss: 0.3874 - MER: 0.1012
# 0.101164505
# Epoch 112/200 - Valid Loss: 0.7198 - MER: 0.1410
# 0.14098941
# Epoch 113/200 - Training Loss: 0.3867 - MER: 0.0999
# 0.09987441
# Epoch 113/200 - Valid Loss: 0.7173 - MER: 0.1403
# 0.14025173
# Epoch 114/200 - Training Loss: 0.3862 - MER: 0.1096
# 0.1095909
# Epoch 114/200 - Valid Loss: 0.7277 - MER: 0.1435
# 0.14345711
# Epoch 115/200 - Training Loss: 0.3811 - MER: 0.0970
# 0.09697892
# Epoch 115/200 - Valid Loss: 0.7101 - MER: 0.1455
# 0.14553979
# Epoch 116/200 - Training Loss: 0.3731 - MER: 0.0924
# 0.09237656
# Epoch 116/200 - Valid Loss: 0.7163 - MER: 0.1429
# 0.14287752
# Epoch 117/200 - Training Loss: 0.3790 - MER: 0.1014
# 0.10135313
# Epoch 117/200 - Valid Loss: 0.7223 - MER: 0.1464
# 0.14642534
# Epoch 118/200 - Training Loss: 0.3861 - MER: 0.1058
# 0.10577434
# Epoch 118/200 - Valid Loss: 0.7304 - MER: 0.1411
# 0.14105311
# Epoch 119/200 - Training Loss: 0.3881 - MER: 0.1014
# 0.10143074
# Epoch 119/200 - Valid Loss: 0.7456 - MER: 0.1395
# 0.13953958
# Epoch 120/200 - Training Loss: 0.3663 - MER: 0.0980
# 0.09801696
# Epoch 120/200 - Valid Loss: 0.7177 - MER: 0.1451
# 0.14510804
# Epoch 121/200 - Training Loss: 0.3739 - MER: 0.0989
# 0.09894067
# Epoch 121/200 - Valid Loss: 0.7253 - MER: 0.1448
# 0.14476895
# Epoch 122/200 - Training Loss: 0.3852 - MER: 0.0912
# 0.09123722
# Epoch 122/200 - Valid Loss: 0.7133 - MER: 0.1429
# 0.14287305
# Epoch 123/200 - Training Loss: 0.3802 - MER: 0.0978
# 0.097787336
# Epoch 123/200 - Valid Loss: 0.7271 - MER: 0.1335
# 0.13346209
# Epoch 124/200 - Training Loss: 0.3685 - MER: 0.0928
# 0.09278962
# Epoch 124/200 - Valid Loss: 0.7241 - MER: 0.1402
# 0.14018856
# Epoch 125/200 - Training Loss: 0.3815 - MER: 0.0997
# 0.09972745
# Epoch 125/200 - Valid Loss: 0.7197 - MER: 0.1489
# 0.14886908
# Epoch 126/200 - Training Loss: 0.3816 - MER: 0.0946
# 0.09464257
# Epoch 126/200 - Valid Loss: 0.7149 - MER: 0.1374
# 0.13744338
# Epoch 127/200 - Training Loss: 0.3673 - MER: 0.0958
# 0.09584373
# Epoch 127/200 - Valid Loss: 0.7276 - MER: 0.1494
# 0.14935112
# Epoch 128/200 - Training Loss: 0.3623 - MER: 0.0917
# 0.09168206
# Epoch 128/200 - Valid Loss: 0.6986 - MER: 0.1453
# 0.14527678
# Epoch 129/200 - Training Loss: 0.3613 - MER: 0.0995
# 0.09948115
# Epoch 129/200 - Valid Loss: 0.7063 - MER: 0.1474
# 0.14744182
# Epoch 130/200 - Training Loss: 0.3588 - MER: 0.0891
# 0.08911258
# Epoch 130/200 - Valid Loss: 0.7206 - MER: 0.1415
# 0.14149006
# Epoch 131/200 - Training Loss: 0.3550 - MER: 0.0939
# 0.09392282
# Epoch 131/200 - Valid Loss: 0.7291 - MER: 0.1458
# 0.14575635
# Epoch 132/200 - Training Loss: 0.3574 - MER: 0.0913
# 0.09130306
# Epoch 132/200 - Valid Loss: 0.7158 - MER: 0.1419
# 0.14192286
# Epoch 133/200 - Training Loss: 0.3603 - MER: 0.0937
# 0.09370164
# Epoch 133/200 - Valid Loss: 0.7090 - MER: 0.1418
# 0.14182435
# Epoch 134/200 - Training Loss: 0.3534 - MER: 0.0930
# 0.09299446
# Epoch 134/200 - Valid Loss: 0.7490 - MER: 0.1413
# 0.14126061
# Epoch 135/200 - Training Loss: 0.3513 - MER: 0.0931
# 0.09305096
# Epoch 135/200 - Valid Loss: 0.7282 - MER: 0.1449
# 0.1449229
# Epoch 136/200 - Training Loss: 0.3644 - MER: 0.0983
# 0.09827536
# Epoch 136/200 - Valid Loss: 0.7395 - MER: 0.1483
# 0.14825353
# Epoch 137/200 - Training Loss: 0.3668 - MER: 0.1009
# 0.10094069
# Epoch 137/200 - Valid Loss: 0.7190 - MER: 0.1412
# 0.14115524
# Epoch 138/200 - Training Loss: 0.3405 - MER: 0.0876
# 0.08761535
# Epoch 138/200 - Valid Loss: 0.7108 - MER: 0.1363
# 0.13631295
# Epoch 139/200 - Training Loss: 0.3484 - MER: 0.0896
# 0.08961263
# Epoch 139/200 - Valid Loss: 0.7353 - MER: 0.1430
# 0.14302385
# Epoch 140/200 - Training Loss: 0.3425 - MER: 0.0855
# 0.08554659
# Epoch 140/200 - Valid Loss: 0.7135 - MER: 0.1371
# 0.1371342
# Epoch 141/200 - Training Loss: 0.3328 - MER: 0.0864
# 0.086382985
# Epoch 141/200 - Valid Loss: 0.7221 - MER: 0.1421
# 0.14207043
# Epoch 142/200 - Training Loss: 0.3463 - MER: 0.1099
# 0.109908104
# Epoch 142/200 - Valid Loss: 0.8051 - MER: 0.1533
# 0.1532519
# Epoch 143/200 - Training Loss: 0.3791 - MER: 0.0920
# 0.09196198
# Epoch 143/200 - Valid Loss: 0.7095 - MER: 0.1400
# 0.14000978
# Epoch 144/200 - Training Loss: 0.3499 - MER: 0.0934
# 0.09340807
# Epoch 144/200 - Valid Loss: 0.7338 - MER: 0.1454
# 0.14535527
# Epoch 145/200 - Training Loss: 0.3516 - MER: 0.0949
# 0.09487809
# Epoch 145/200 - Valid Loss: 0.7307 - MER: 0.1393
# 0.13928115
# Epoch 146/200 - Training Loss: 0.3417 - MER: 0.0885
# 0.08845301
# Epoch 146/200 - Valid Loss: 0.7225 - MER: 0.1388
# 0.13879861
# Epoch 147/200 - Training Loss: 0.3321 - MER: 0.0935
# 0.09349576
# Epoch 147/200 - Valid Loss: 0.7437 - MER: 0.1382
# 0.13815773
# Epoch 148/200 - Training Loss: 0.3357 - MER: 0.0957
# 0.09567721
# Epoch 148/200 - Valid Loss: 0.7317 - MER: 0.1382
# 0.13821371
# Epoch 149/200 - Training Loss: 0.3395 - MER: 0.0882
# 0.08823186
# Epoch 149/200 - Valid Loss: 0.7180 - MER: 0.1384
# 0.13844553
# Epoch 150/200 - Training Loss: 0.3331 - MER: 0.0842
# 0.08417788
# Epoch 150/200 - Valid Loss: 0.7149 - MER: 0.1376
# 0.13757223
# Epoch 151/200 - Training Loss: 0.3287 - MER: 0.0960
# 0.096027344
# Epoch 151/200 - Valid Loss: 0.7467 - MER: 0.1429
# 0.14292148
# Epoch 152/200 - Training Loss: 0.3298 - MER: 0.1029
# 0.102872446
# Epoch 152/200 - Valid Loss: 0.7404 - MER: 0.1577
# 0.15765853
# Epoch 153/200 - Training Loss: 0.3351 - MER: 0.0881
# 0.08810582
# Epoch 153/200 - Valid Loss: 0.7441 - MER: 0.1379
# 0.13790826
# Epoch 154/200 - Training Loss: 0.3348 - MER: 0.0893
# 0.089341894
# Epoch 154/200 - Valid Loss: 0.7220 - MER: 0.1385
# 0.13851124
# Epoch 155/200 - Training Loss: 0.3307 - MER: 0.0827
# 0.082694635
# Epoch 155/200 - Valid Loss: 0.7186 - MER: 0.1373
# 0.13732813
# Epoch 156/200 - Training Loss: 0.3247 - MER: 0.0875
# 0.08749072
# Epoch 156/200 - Valid Loss: 0.7048 - MER: 0.1403
# 0.14032684
# Epoch 157/200 - Training Loss: 0.3247 - MER: 0.1032
# 0.103228435
# Epoch 157/200 - Valid Loss: 0.7621 - MER: 0.1440
# 0.14395237
# Epoch 158/200 - Training Loss: 0.3381 - MER: 0.0870
# 0.08696097
# Epoch 158/200 - Valid Loss: 0.7219 - MER: 0.1425
# 0.14251338
# Epoch 159/200 - Training Loss: 0.3276 - MER: 0.0822
# 0.08217645
# Epoch 159/200 - Valid Loss: 0.7197 - MER: 0.1387
# 0.13865829
# Epoch 160/200 - Training Loss: 0.3243 - MER: 0.0989
# 0.09893726
# Epoch 160/200 - Valid Loss: 0.7413 - MER: 0.1444
# 0.14440584
# Epoch 161/200 - Training Loss: 0.3421 - MER: 0.0937
# 0.09370342
# Epoch 161/200 - Valid Loss: 0.7371 - MER: 0.1439
# 0.14390011
# Epoch 162/200 - Training Loss: 0.3308 - MER: 0.0890
# 0.088995315
# Epoch 162/200 - Valid Loss: 0.7142 - MER: 0.1377
# 0.13771701
# Epoch 163/200 - Training Loss: 0.3180 - MER: 0.0884
# 0.08835807
# Epoch 163/200 - Valid Loss: 0.7271 - MER: 0.1459
# 0.14591333
# Epoch 164/200 - Training Loss: 0.3181 - MER: 0.0835
# 0.083538935
# Epoch 164/200 - Valid Loss: 0.7058 - MER: 0.1430
# 0.14301544
# Epoch 165/200 - Training Loss: 0.3148 - MER: 0.0794
# 0.07938844
# Epoch 165/200 - Valid Loss: 0.7153 - MER: 0.1405
# 0.14050622
# Epoch 166/200 - Training Loss: 0.3195 - MER: 0.0913
# 0.09129022
# Epoch 166/200 - Valid Loss: 0.7286 - MER: 0.1400
# 0.14000502
# Epoch 167/200 - Training Loss: 0.3375 - MER: 0.0925
# 0.092493266
# Epoch 167/200 - Valid Loss: 0.7309 - MER: 0.1444
# 0.14439075
# Epoch 168/200 - Training Loss: 0.3187 - MER: 0.0874
# 0.08741999
# Epoch 168/200 - Valid Loss: 0.7163 - MER: 0.1395
# 0.13947102
# Epoch 169/200 - Training Loss: 0.3058 - MER: 0.0836
# 0.083612286
# Epoch 169/200 - Valid Loss: 0.7095 - MER: 0.1360
# 0.13599433
# Epoch 170/200 - Training Loss: 0.3056 - MER: 0.0823
# 0.08227855
# Epoch 170/200 - Valid Loss: 0.6991 - MER: 0.1408
# 0.14075753
# Epoch 171/200 - Training Loss: 0.3098 - MER: 0.0834
# 0.083427
# Epoch 171/200 - Valid Loss: 0.7322 - MER: 0.1398
# 0.13981065
# Epoch 172/200 - Training Loss: 0.3138 - MER: 0.0888
# 0.088768974
# Epoch 172/200 - Valid Loss: 0.7108 - MER: 0.1465
# 0.14648905
# Epoch 173/200 - Training Loss: 0.3141 - MER: 0.0926
# 0.09258212
# Epoch 173/200 - Valid Loss: 0.7263 - MER: 0.1525
# 0.15249823
# Epoch 174/200 - Training Loss: 0.3224 - MER: 0.1094
# 0.109385565
# Epoch 174/200 - Valid Loss: 0.7401 - MER: 0.1673
# 0.16729629
# Epoch 175/200 - Training Loss: 0.3017 - MER: 0.0864
# 0.086433575
# Epoch 175/200 - Valid Loss: 0.6980 - MER: 0.1415
# 0.1415475
# Epoch 176/200 - Training Loss: 0.3042 - MER: 0.0811
# 0.08110065
# Epoch 176/200 - Valid Loss: 0.6888 - MER: 0.1418
# 0.14181587
# Epoch 177/200 - Training Loss: 0.2923 - MER: 0.0843
# 0.084266424
# Epoch 177/200 - Valid Loss: 0.7142 - MER: 0.1459
# 0.14589103
# Epoch 178/200 - Training Loss: 0.2939 - MER: 0.0867
# 0.08668114
# Epoch 178/200 - Valid Loss: 0.7311 - MER: 0.1468
# 0.14681932
# Epoch 179/200 - Training Loss: 0.3123 - MER: 0.0798
# 0.07980494
# Epoch 179/200 - Valid Loss: 0.7081 - MER: 0.1382
# 0.13817987
# Epoch 180/200 - Training Loss: 0.2984 - MER: 0.0830
# 0.08296609
# Epoch 180/200 - Valid Loss: 0.7465 - MER: 0.1470
# 0.14695804
# Epoch 181/200 - Training Loss: 0.2920 - MER: 0.0770
# 0.07695374
# Epoch 181/200 - Valid Loss: 0.7078 - MER: 0.1360
# 0.13597098
# Epoch 182/200 - Training Loss: 0.2875 - MER: 0.0817
# 0.081662655
# Epoch 182/200 - Valid Loss: 0.7151 - MER: 0.1364
# 0.13639751
# Epoch 183/200 - Training Loss: 0.3041 - MER: 0.0870
# 0.08704296
# Epoch 183/200 - Valid Loss: 0.7061 - MER: 0.1488
# 0.14877306
# Epoch 184/200 - Training Loss: 0.2914 - MER: 0.0973
# 0.0973167
# Epoch 184/200 - Valid Loss: 0.7458 - MER: 0.1500
# 0.1500326
# Epoch 185/200 - Training Loss: 0.2952 - MER: 0.0857
# 0.08568187
# Epoch 185/200 - Valid Loss: 0.7075 - MER: 0.1453
# 0.14528488
# Epoch 186/200 - Training Loss: 0.2977 - MER: 0.0842
# 0.08421144
# Epoch 186/200 - Valid Loss: 0.7047 - MER: 0.1421
# 0.14207993
# Epoch 187/200 - Training Loss: 0.2866 - MER: 0.0742
# 0.074158
# Epoch 187/200 - Valid Loss: 0.7058 - MER: 0.1375
# 0.13749646
# Epoch 188/200 - Training Loss: 0.2854 - MER: 0.0817
# 0.08172043
# Epoch 188/200 - Valid Loss: 0.7295 - MER: 0.1473
# 0.14728555
# Epoch 189/200 - Training Loss: 0.2932 - MER: 0.0891
# 0.089070976
# Epoch 189/200 - Valid Loss: 0.7282 - MER: 0.1409
# 0.14090416
# Epoch 190/200 - Training Loss: 0.2990 - MER: 0.0838
# 0.08382367
# Epoch 190/200 - Valid Loss: 0.7273 - MER: 0.1415
# 0.14150032
# Epoch 191/200 - Training Loss: 0.2996 - MER: 0.0805
# 0.08046659
# Epoch 191/200 - Valid Loss: 0.7210 - MER: 0.1381
# 0.13805944
# Epoch 192/200 - Training Loss: 0.2887 - MER: 0.0830
# 0.083021335
# Epoch 192/200 - Valid Loss: 0.7326 - MER: 0.1414
# 0.14135513
# Epoch 193/200 - Training Loss: 0.2943 - MER: 0.0816
# 0.081557244
# Epoch 193/200 - Valid Loss: 0.7234 - MER: 0.1442
# 0.14417805
# Epoch 194/200 - Training Loss: 0.2968 - MER: 0.0738
# 0.07384293
# Epoch 194/200 - Valid Loss: 0.7018 - MER: 0.1376
# 0.13759953
# Epoch 195/200 - Training Loss: 0.2779 - MER: 0.0770
# 0.07696904
# Epoch 195/200 - Valid Loss: 0.6837 - MER: 0.1369
# 0.13687767
# Epoch 196/200 - Training Loss: 0.2776 - MER: 0.0775
# 0.07747851
# Epoch 196/200 - Valid Loss: 0.7148 - MER: 0.1391
# 0.13907178
# Epoch 197/200 - Training Loss: 0.2827 - MER: 0.0763
# 0.076257154
# Epoch 197/200 - Valid Loss: 0.7105 - MER: 0.1397
# 0.13972324
# Epoch 198/200 - Training Loss: 0.2834 - MER: 0.0867
# 0.0866745
# Epoch 198/200 - Valid Loss: 0.7380 - MER: 0.1411
# 0.14113133
# Epoch 199/200 - Training Loss: 0.2906 - MER: 0.0759
# 0.07590618
# Epoch 199/200 - Valid Loss: 0.7097 - MER: 0.1359
# 0.13593024
# Epoch 200/200 - Training Loss: 0.2684 - MER: 0.0797
# 0.079680994
# Epoch 200/200 - Valid Loss: 0.6903 - MER: 0.1428
# 0.14279364

# %%
#TODO: plot the training and validation error (MER) over epochs
plt.plot(mer_values_train_MLP_2, label='Training MER')
plt.plot(mer_values_valid_MLP_2, label='Validation MER')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Add norm regularization
#
# In the following, use the norm regularization to retrain the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization

model_3 = nn.Sequential(nn.Linear(train_features.shape[1], 512),
                      nn.ReLU(),
                      nn.Linear(512, 256),
                      nn.ReLU(),
                      nn.Linear(256, 128),
                      nn.ReLU(),
                      nn.Linear(128, 64),
                      nn.ReLU(),
                      nn.Linear(64,1))
model_3.to(device)

criterion_MLP_3 = nn.SmoothL1Loss()

# Define the optimizer with weight decay for L2 regularization
optimizer_MLP_3 = optim.Adam(model_3.parameters(), lr=0.001, weight_decay=0.003)  # Adjust the weight decay value as needed

epochs = 200
train_losses_MLP_3, valid_losses_MLP_3 = [], []
mer_values_train_MLP_3, mer_values_valid_MLP_3 = [], []

for e in range(epochs):
    running_train_loss = 0
    for batch_features, batch_labels in train_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        logps = model_3(batch_features)
        loss = criterion_MLP_3(logps, batch_labels)

        # Get the L2 norm of the model's parameters
        l2_reg = None
        for param in model_3.parameters():
            if l2_reg is None:
                l2_reg = param.norm(2)  # Compute the L2 norm
            else:
                l2_reg = l2_reg + param.norm(2)

        # Add the regularization term to the loss
        loss = loss + 0.001 * l2_reg  # Adjust the regularization strength (0.001 in this case)

        optimizer_MLP_3.zero_grad()
        loss.backward()
        optimizer_MLP_3.step()

        running_train_loss += loss.item()

    # Validation and other calculations remain the same as before

    else:
      running_valid_loss = 0
      with torch.no_grad():
        for batch_features, batch_labels in valid_loader:
          batch_features = batch_features.to(device)
          batch_labels = batch_labels.to(device)

          outputs = model_3(batch_features)
          loss = criterion_MLP_3(outputs, batch_labels)
          running_valid_loss += loss.item()


      train_loss = running_train_loss/len(train_loader)
      valid_loss = running_valid_loss/len(valid_loader)
      train_losses_MLP_3.append(train_loss)
      valid_losses_MLP_3.append(valid_loss)



  # Calculate MER for this epoch and append to the list
    train_loss = running_train_loss / len(train_loader)
    train_losses_MLP_3.append(train_loss)

    valid_loss = running_valid_loss / len(valid_loader)
    valid_losses_MLP_3.append(valid_loss)

  # Calculate MER based on your code
    train_features = train_features.to(device)
    train_labels = train_labels.to(device)
    valid_features = valid_features.to(device)
    valid_labels = valid_labels.to(device)

    predicted_train = model_3(train_features).cpu().detach().numpy()
    actual_train = train_labels.cpu().numpy()
    error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
    mer_train_MLP = np.median(error_rates_train)
    mer_values_train_MLP_3.append(mer_train_MLP)

    predicted_valid = model_3(valid_features).cpu().detach().numpy()
    actual_valid = valid_labels.cpu().numpy()
    error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
    mer_valid_MLP = np.median(error_rates_valid)
    mer_values_valid_MLP_3.append(mer_valid_MLP)


    print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
    print(mer_train_MLP)
    print(f"Epoch {e + 1}/{epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid_MLP:.4f}")
    print(mer_valid_MLP)
# Out:
# Epoch 1/200 - Training Loss: 2.1215 - MER: 0.2279
# 0.22787121
# Epoch 1/200 - Valid Loss: 1.0666 - MER: 0.2311
# 0.2311396
# Epoch 2/200 - Training Loss: 1.0107 - MER: 0.1951
# 0.19505814
# Epoch 2/200 - Valid Loss: 0.8598 - MER: 0.1910
# 0.19097196
# Epoch 3/200 - Training Loss: 0.8494 - MER: 0.1808
# 0.18078578
# Epoch 3/200 - Valid Loss: 0.7763 - MER: 0.1780
# 0.17796233
# Epoch 4/200 - Training Loss: 0.8141 - MER: 0.1801
# 0.18012983
# Epoch 4/200 - Valid Loss: 0.7640 - MER: 0.1776
# 0.17755672
# Epoch 5/200 - Training Loss: 0.7779 - MER: 0.1759
# 0.1758877
# Epoch 5/200 - Valid Loss: 0.7752 - MER: 0.1765
# 0.17648901
# Epoch 6/200 - Training Loss: 0.7640 - MER: 0.1630
# 0.16298479
# Epoch 6/200 - Valid Loss: 0.7286 - MER: 0.1639
# 0.16392136
# Epoch 7/200 - Training Loss: 0.7471 - MER: 0.1608
# 0.16075158
# Epoch 7/200 - Valid Loss: 0.7318 - MER: 0.1630
# 0.16301398
# Epoch 8/200 - Training Loss: 0.7393 - MER: 0.1605
# 0.16047922
# Epoch 8/200 - Valid Loss: 0.7257 - MER: 0.1638
# 0.16377144
# Epoch 9/200 - Training Loss: 0.7353 - MER: 0.1593
# 0.15926993
# Epoch 9/200 - Valid Loss: 0.7173 - MER: 0.1679
# 0.1679256
# Epoch 10/200 - Training Loss: 0.7162 - MER: 0.1597
# 0.1597157
# Epoch 10/200 - Valid Loss: 0.7347 - MER: 0.1646
# 0.16457954
# Epoch 11/200 - Training Loss: 0.7322 - MER: 0.1538
# 0.15375948
# Epoch 11/200 - Valid Loss: 0.7164 - MER: 0.1589
# 0.1588845
# Epoch 12/200 - Training Loss: 0.7026 - MER: 0.1624
# 0.16242337
# Epoch 12/200 - Valid Loss: 0.7300 - MER: 0.1722
# 0.17215116
# Epoch 13/200 - Training Loss: 0.7003 - MER: 0.1569
# 0.15691164
# Epoch 13/200 - Valid Loss: 0.7120 - MER: 0.1611
# 0.16109678
# Epoch 14/200 - Training Loss: 0.7063 - MER: 0.1578
# 0.1578353
# Epoch 14/200 - Valid Loss: 0.7643 - MER: 0.1637
# 0.16372292
# Epoch 15/200 - Training Loss: 0.6948 - MER: 0.1509
# 0.15085047
# Epoch 15/200 - Valid Loss: 0.7074 - MER: 0.1577
# 0.15770121
# Epoch 16/200 - Training Loss: 0.6985 - MER: 0.1556
# 0.15557843
# Epoch 16/200 - Valid Loss: 0.7093 - MER: 0.1629
# 0.16288139
# Epoch 17/200 - Training Loss: 0.6934 - MER: 0.1515
# 0.15150589
# Epoch 17/200 - Valid Loss: 0.6950 - MER: 0.1577
# 0.15772414
# Epoch 18/200 - Training Loss: 0.7032 - MER: 0.1657
# 0.1656729
# Epoch 18/200 - Valid Loss: 0.7806 - MER: 0.1702
# 0.1701942
# Epoch 19/200 - Training Loss: 0.6939 - MER: 0.1489
# 0.14889356
# Epoch 19/200 - Valid Loss: 0.7255 - MER: 0.1552
# 0.15515432
# Epoch 20/200 - Training Loss: 0.6851 - MER: 0.1503
# 0.1502642
# Epoch 20/200 - Valid Loss: 0.7050 - MER: 0.1579
# 0.15792766
# Epoch 21/200 - Training Loss: 0.6831 - MER: 0.1450
# 0.14495435
# Epoch 21/200 - Valid Loss: 0.7030 - MER: 0.1510
# 0.15099928
# Epoch 22/200 - Training Loss: 0.6724 - MER: 0.1485
# 0.14845952
# Epoch 22/200 - Valid Loss: 0.7252 - MER: 0.1581
# 0.15809551
# Epoch 23/200 - Training Loss: 0.6739 - MER: 0.1444
# 0.14436175
# Epoch 23/200 - Valid Loss: 0.6980 - MER: 0.1597
# 0.1596611
# Epoch 24/200 - Training Loss: 0.6700 - MER: 0.1477
# 0.1476847
# Epoch 24/200 - Valid Loss: 0.6998 - MER: 0.1558
# 0.1557512
# Epoch 25/200 - Training Loss: 0.6622 - MER: 0.1536
# 0.15355149
# Epoch 25/200 - Valid Loss: 0.7169 - MER: 0.1638
# 0.16376872
# Epoch 26/200 - Training Loss: 0.6648 - MER: 0.1461
# 0.14610034
# Epoch 26/200 - Valid Loss: 0.7346 - MER: 0.1548
# 0.15477252
# Epoch 27/200 - Training Loss: 0.6632 - MER: 0.1451
# 0.1450679
# Epoch 27/200 - Valid Loss: 0.7020 - MER: 0.1580
# 0.1579594
# Epoch 28/200 - Training Loss: 0.6619 - MER: 0.1450
# 0.14499073
# Epoch 28/200 - Valid Loss: 0.6959 - MER: 0.1600
# 0.16003975
# Epoch 29/200 - Training Loss: 0.6541 - MER: 0.1439
# 0.14391881
# Epoch 29/200 - Valid Loss: 0.6972 - MER: 0.1536
# 0.15355383
# Epoch 30/200 - Training Loss: 0.6558 - MER: 0.1384
# 0.13843215
# Epoch 30/200 - Valid Loss: 0.7088 - MER: 0.1492
# 0.14922573
# Epoch 31/200 - Training Loss: 0.6673 - MER: 0.1535
# 0.1535008
# Epoch 31/200 - Valid Loss: 0.7124 - MER: 0.1632
# 0.1631649
# Epoch 32/200 - Training Loss: 0.6502 - MER: 0.1473
# 0.14733484
# Epoch 32/200 - Valid Loss: 0.7099 - MER: 0.1555
# 0.15547815
# Epoch 33/200 - Training Loss: 0.6457 - MER: 0.1425
# 0.1425393
# Epoch 33/200 - Valid Loss: 0.7026 - MER: 0.1569
# 0.1569432
# Epoch 34/200 - Training Loss: 0.6539 - MER: 0.1479
# 0.14792833
# Epoch 34/200 - Valid Loss: 0.7262 - MER: 0.1641
# 0.16409574
# Epoch 35/200 - Training Loss: 0.6566 - MER: 0.1406
# 0.14059243
# Epoch 35/200 - Valid Loss: 0.7080 - MER: 0.1535
# 0.15349256
# Epoch 36/200 - Training Loss: 0.6445 - MER: 0.1471
# 0.14713159
# Epoch 36/200 - Valid Loss: 0.7137 - MER: 0.1567
# 0.15670027
# Epoch 37/200 - Training Loss: 0.6434 - MER: 0.1460
# 0.14599639
# Epoch 37/200 - Valid Loss: 0.7118 - MER: 0.1591
# 0.15911801
# Epoch 38/200 - Training Loss: 0.6340 - MER: 0.1403
# 0.14026766
# Epoch 38/200 - Valid Loss: 0.7196 - MER: 0.1496
# 0.14955123
# Epoch 39/200 - Training Loss: 0.6328 - MER: 0.1334
# 0.13336006
# Epoch 39/200 - Valid Loss: 0.6860 - MER: 0.1484
# 0.14839254
# Epoch 40/200 - Training Loss: 0.6294 - MER: 0.1428
# 0.14278829
# Epoch 40/200 - Valid Loss: 0.7144 - MER: 0.1608
# 0.16080864
# Epoch 41/200 - Training Loss: 0.6274 - MER: 0.1375
# 0.13754316
# Epoch 41/200 - Valid Loss: 0.7238 - MER: 0.1457
# 0.14566967
# Epoch 42/200 - Training Loss: 0.6454 - MER: 0.1501
# 0.15008804
# Epoch 42/200 - Valid Loss: 0.7443 - MER: 0.1576
# 0.1576468
# Epoch 43/200 - Training Loss: 0.6386 - MER: 0.1334
# 0.1334127
# Epoch 43/200 - Valid Loss: 0.6968 - MER: 0.1469
# 0.14687853
# Epoch 44/200 - Training Loss: 0.6221 - MER: 0.1465
# 0.14648855
# Epoch 44/200 - Valid Loss: 0.7335 - MER: 0.1536
# 0.15358655
# Epoch 45/200 - Training Loss: 0.6264 - MER: 0.1400
# 0.1400184
# Epoch 45/200 - Valid Loss: 0.7058 - MER: 0.1562
# 0.15624334
# Epoch 46/200 - Training Loss: 0.6206 - MER: 0.1421
# 0.14205816
# Epoch 46/200 - Valid Loss: 0.7233 - MER: 0.1577
# 0.15771715
# Epoch 47/200 - Training Loss: 0.6213 - MER: 0.1457
# 0.14573728
# Epoch 47/200 - Valid Loss: 0.7216 - MER: 0.1638
# 0.16384943
# Epoch 48/200 - Training Loss: 0.6220 - MER: 0.1425
# 0.14252849
# Epoch 48/200 - Valid Loss: 0.7176 - MER: 0.1529
# 0.15287545
# Epoch 49/200 - Training Loss: 0.6234 - MER: 0.1383
# 0.13834415
# Epoch 49/200 - Valid Loss: 0.7010 - MER: 0.1563
# 0.15628137
# Epoch 50/200 - Training Loss: 0.6203 - MER: 0.1347
# 0.13472146
# Epoch 50/200 - Valid Loss: 0.7050 - MER: 0.1479
# 0.147949
# Epoch 51/200 - Training Loss: 0.6209 - MER: 0.1302
# 0.13019082
# Epoch 51/200 - Valid Loss: 0.7091 - MER: 0.1495
# 0.14949067
# Epoch 52/200 - Training Loss: 0.6100 - MER: 0.1281
# 0.12807393
# Epoch 52/200 - Valid Loss: 0.6860 - MER: 0.1441
# 0.14412676
# Epoch 53/200 - Training Loss: 0.6065 - MER: 0.1314
# 0.13136601
# Epoch 53/200 - Valid Loss: 0.6901 - MER: 0.1462
# 0.14621319
# Epoch 54/200 - Training Loss: 0.6124 - MER: 0.1380
# 0.13799156
# Epoch 54/200 - Valid Loss: 0.7191 - MER: 0.1523
# 0.15231022
# Epoch 55/200 - Training Loss: 0.6114 - MER: 0.1366
# 0.1365624
# Epoch 55/200 - Valid Loss: 0.7162 - MER: 0.1544
# 0.1544372
# Epoch 56/200 - Training Loss: 0.6087 - MER: 0.1367
# 0.13673906
# Epoch 56/200 - Valid Loss: 0.7430 - MER: 0.1488
# 0.14875412
# Epoch 57/200 - Training Loss: 0.6175 - MER: 0.1289
# 0.12890139
# Epoch 57/200 - Valid Loss: 0.6959 - MER: 0.1479
# 0.14792836
# Epoch 58/200 - Training Loss: 0.6120 - MER: 0.1369
# 0.13692254
# Epoch 58/200 - Valid Loss: 0.7238 - MER: 0.1502
# 0.15023202
# Epoch 59/200 - Training Loss: 0.6115 - MER: 0.1347
# 0.13474092
# Epoch 59/200 - Valid Loss: 0.7254 - MER: 0.1490
# 0.14898305
# Epoch 60/200 - Training Loss: 0.6028 - MER: 0.1344
# 0.13440025
# Epoch 60/200 - Valid Loss: 0.7107 - MER: 0.1557
# 0.1557002
# Epoch 61/200 - Training Loss: 0.5957 - MER: 0.1263
# 0.12632145
# Epoch 61/200 - Valid Loss: 0.6916 - MER: 0.1439
# 0.14393462
# Epoch 62/200 - Training Loss: 0.6057 - MER: 0.1358
# 0.13575214
# Epoch 62/200 - Valid Loss: 0.7110 - MER: 0.1527
# 0.1527126
# Epoch 63/200 - Training Loss: 0.6023 - MER: 0.1492
# 0.14922202
# Epoch 63/200 - Valid Loss: 0.7252 - MER: 0.1647
# 0.1647439
# Epoch 64/200 - Training Loss: 0.6021 - MER: 0.1370
# 0.1369922
# Epoch 64/200 - Valid Loss: 0.7324 - MER: 0.1483
# 0.14826864
# Epoch 65/200 - Training Loss: 0.6160 - MER: 0.1284
# 0.12835932
# Epoch 65/200 - Valid Loss: 0.7023 - MER: 0.1475
# 0.14753245
# Epoch 66/200 - Training Loss: 0.6119 - MER: 0.1327
# 0.13274466
# Epoch 66/200 - Valid Loss: 0.6978 - MER: 0.1470
# 0.14702581
# Epoch 67/200 - Training Loss: 0.5895 - MER: 0.1268
# 0.1268161
# Epoch 67/200 - Valid Loss: 0.7141 - MER: 0.1401
# 0.14008887
# Epoch 68/200 - Training Loss: 0.5935 - MER: 0.1244
# 0.12440828
# Epoch 68/200 - Valid Loss: 0.7029 - MER: 0.1433
# 0.14334902
# Epoch 69/200 - Training Loss: 0.6039 - MER: 0.1328
# 0.13279405
# Epoch 69/200 - Valid Loss: 0.7159 - MER: 0.1422
# 0.14221092
# Epoch 70/200 - Training Loss: 0.5897 - MER: 0.1381
# 0.13809773
# Epoch 70/200 - Valid Loss: 0.7300 - MER: 0.1520
# 0.15199572
# Epoch 71/200 - Training Loss: 0.5995 - MER: 0.1260
# 0.12597579
# Epoch 71/200 - Valid Loss: 0.6890 - MER: 0.1438
# 0.14382154
# Epoch 72/200 - Training Loss: 0.5857 - MER: 0.1254
# 0.12541336
# Epoch 72/200 - Valid Loss: 0.6855 - MER: 0.1465
# 0.14650631
# Epoch 73/200 - Training Loss: 0.5841 - MER: 0.1303
# 0.13032319
# Epoch 73/200 - Valid Loss: 0.6950 - MER: 0.1496
# 0.14963663
# Epoch 74/200 - Training Loss: 0.5801 - MER: 0.1318
# 0.13184766
# Epoch 74/200 - Valid Loss: 0.6952 - MER: 0.1498
# 0.14975281
# Epoch 75/200 - Training Loss: 0.5920 - MER: 0.1532
# 0.1532
# Epoch 75/200 - Valid Loss: 0.7671 - MER: 0.1730
# 0.17298897
# Epoch 76/200 - Training Loss: 0.6017 - MER: 0.1334
# 0.13338609
# Epoch 76/200 - Valid Loss: 0.6927 - MER: 0.1481
# 0.14811043
# Epoch 77/200 - Training Loss: 0.5867 - MER: 0.1274
# 0.12741567
# Epoch 77/200 - Valid Loss: 0.7042 - MER: 0.1472
# 0.14717636
# Epoch 78/200 - Training Loss: 0.5928 - MER: 0.1288
# 0.12877661
# Epoch 78/200 - Valid Loss: 0.7178 - MER: 0.1490
# 0.14902799
# Epoch 79/200 - Training Loss: 0.5880 - MER: 0.1339
# 0.1339352
# Epoch 79/200 - Valid Loss: 0.7087 - MER: 0.1461
# 0.14612772
# Epoch 80/200 - Training Loss: 0.5861 - MER: 0.1428
# 0.1428478
# Epoch 80/200 - Valid Loss: 0.7314 - MER: 0.1627
# 0.16272722
# Epoch 81/200 - Training Loss: 0.6051 - MER: 0.1302
# 0.13020617
# Epoch 81/200 - Valid Loss: 0.6966 - MER: 0.1451
# 0.14508659
# Epoch 82/200 - Training Loss: 0.5909 - MER: 0.1291
# 0.12909521
# Epoch 82/200 - Valid Loss: 0.7261 - MER: 0.1410
# 0.1409874
# Epoch 83/200 - Training Loss: 0.5908 - MER: 0.1246
# 0.12458539
# Epoch 83/200 - Valid Loss: 0.6936 - MER: 0.1417
# 0.14166017
# Epoch 84/200 - Training Loss: 0.5824 - MER: 0.1247
# 0.12465765
# Epoch 84/200 - Valid Loss: 0.6769 - MER: 0.1400
# 0.13995704
# Epoch 85/200 - Training Loss: 0.5724 - MER: 0.1228
# 0.12278736
# Epoch 85/200 - Valid Loss: 0.6783 - MER: 0.1440
# 0.14404996
# Epoch 86/200 - Training Loss: 0.5710 - MER: 0.1251
# 0.12506604
# Epoch 86/200 - Valid Loss: 0.6884 - MER: 0.1457
# 0.14567772
# Epoch 87/200 - Training Loss: 0.5610 - MER: 0.1201
# 0.120064065
# Epoch 87/200 - Valid Loss: 0.6941 - MER: 0.1433
# 0.14334595
# Epoch 88/200 - Training Loss: 0.5785 - MER: 0.1247
# 0.12466225
# Epoch 88/200 - Valid Loss: 0.6855 - MER: 0.1445
# 0.14452022
# Epoch 89/200 - Training Loss: 0.5758 - MER: 0.1324
# 0.13236812
# Epoch 89/200 - Valid Loss: 0.7065 - MER: 0.1509
# 0.15085158
# Epoch 90/200 - Training Loss: 0.5949 - MER: 0.1329
# 0.13288571
# Epoch 90/200 - Valid Loss: 0.7049 - MER: 0.1483
# 0.14831804
# Epoch 91/200 - Training Loss: 0.5681 - MER: 0.1263
# 0.12634939
# Epoch 91/200 - Valid Loss: 0.6873 - MER: 0.1485
# 0.14852862
# Epoch 92/200 - Training Loss: 0.5678 - MER: 0.1213
# 0.12125936
# Epoch 92/200 - Valid Loss: 0.6841 - MER: 0.1420
# 0.14202888
# Epoch 93/200 - Training Loss: 0.5688 - MER: 0.1245
# 0.12454377
# Epoch 93/200 - Valid Loss: 0.7021 - MER: 0.1408
# 0.14084475
# Epoch 94/200 - Training Loss: 0.5735 - MER: 0.1277
# 0.12766004
# Epoch 94/200 - Valid Loss: 0.6897 - MER: 0.1510
# 0.15103514
# Epoch 95/200 - Training Loss: 0.5786 - MER: 0.1326
# 0.13263977
# Epoch 95/200 - Valid Loss: 0.7046 - MER: 0.1505
# 0.1504726
# Epoch 96/200 - Training Loss: 0.5685 - MER: 0.1205
# 0.12051277
# Epoch 96/200 - Valid Loss: 0.6902 - MER: 0.1438
# 0.14384134
# Epoch 97/200 - Training Loss: 0.5612 - MER: 0.1225
# 0.12246536
# Epoch 97/200 - Valid Loss: 0.6976 - MER: 0.1478
# 0.14776702
# Epoch 98/200 - Training Loss: 0.5686 - MER: 0.1223
# 0.122254655
# Epoch 98/200 - Valid Loss: 0.6987 - MER: 0.1467
# 0.14665733
# Epoch 99/200 - Training Loss: 0.5627 - MER: 0.1281
# 0.1280531
# Epoch 99/200 - Valid Loss: 0.7124 - MER: 0.1486
# 0.14860792
# Epoch 100/200 - Training Loss: 0.5666 - MER: 0.1307
# 0.13072887
# Epoch 100/200 - Valid Loss: 0.7083 - MER: 0.1516
# 0.1515798
# Epoch 101/200 - Training Loss: 0.5667 - MER: 0.1311
# 0.13113058
# Epoch 101/200 - Valid Loss: 0.6922 - MER: 0.1498
# 0.14975663
# Epoch 102/200 - Training Loss: 0.5663 - MER: 0.1336
# 0.133646
# Epoch 102/200 - Valid Loss: 0.7302 - MER: 0.1478
# 0.1478451
# Epoch 103/200 - Training Loss: 0.5764 - MER: 0.1215
# 0.12147823
# Epoch 103/200 - Valid Loss: 0.7049 - MER: 0.1450
# 0.1450329
# Epoch 104/200 - Training Loss: 0.5590 - MER: 0.1216
# 0.121648096
# Epoch 104/200 - Valid Loss: 0.6932 - MER: 0.1448
# 0.14475831
# Epoch 105/200 - Training Loss: 0.5544 - MER: 0.1195
# 0.11948226
# Epoch 105/200 - Valid Loss: 0.6791 - MER: 0.1428
# 0.14283396
# Epoch 106/200 - Training Loss: 0.5633 - MER: 0.1382
# 0.13815562
# Epoch 106/200 - Valid Loss: 0.7479 - MER: 0.1540
# 0.15398026
# Epoch 107/200 - Training Loss: 0.5763 - MER: 0.1226
# 0.12258351
# Epoch 107/200 - Valid Loss: 0.6939 - MER: 0.1440
# 0.14402083
# Epoch 108/200 - Training Loss: 0.5570 - MER: 0.1266
# 0.12662938
# Epoch 108/200 - Valid Loss: 0.6871 - MER: 0.1453
# 0.1453419
# Epoch 109/200 - Training Loss: 0.5501 - MER: 0.1265
# 0.12646121
# Epoch 109/200 - Valid Loss: 0.7004 - MER: 0.1421
# 0.14213076
# Epoch 110/200 - Training Loss: 0.5524 - MER: 0.1205
# 0.12047827
# Epoch 110/200 - Valid Loss: 0.6845 - MER: 0.1445
# 0.14446086
# Epoch 111/200 - Training Loss: 0.5621 - MER: 0.1210
# 0.12099634
# Epoch 111/200 - Valid Loss: 0.6816 - MER: 0.1437
# 0.14370343
# Epoch 112/200 - Training Loss: 0.5496 - MER: 0.1219
# 0.12192445
# Epoch 112/200 - Valid Loss: 0.6888 - MER: 0.1423
# 0.14232744
# Epoch 113/200 - Training Loss: 0.5465 - MER: 0.1263
# 0.12632582
# Epoch 113/200 - Valid Loss: 0.7122 - MER: 0.1504
# 0.15040314
# Epoch 114/200 - Training Loss: 0.5577 - MER: 0.1187
# 0.118695736
# Epoch 114/200 - Valid Loss: 0.7208 - MER: 0.1446
# 0.14459896
# Epoch 115/200 - Training Loss: 0.5452 - MER: 0.1218
# 0.1217764
# Epoch 115/200 - Valid Loss: 0.6990 - MER: 0.1424
# 0.14238533
# Epoch 116/200 - Training Loss: 0.5502 - MER: 0.1241
# 0.12411267
# Epoch 116/200 - Valid Loss: 0.6769 - MER: 0.1481
# 0.14806797
# Epoch 117/200 - Training Loss: 0.5461 - MER: 0.1227
# 0.122670196
# Epoch 117/200 - Valid Loss: 0.6959 - MER: 0.1462
# 0.14620766
# Epoch 118/200 - Training Loss: 0.5511 - MER: 0.1163
# 0.11634652
# Epoch 118/200 - Valid Loss: 0.6850 - MER: 0.1421
# 0.14212164
# Epoch 119/200 - Training Loss: 0.5463 - MER: 0.1208
# 0.120781004
# Epoch 119/200 - Valid Loss: 0.6780 - MER: 0.1480
# 0.14795032
# Epoch 120/200 - Training Loss: 0.5458 - MER: 0.1178
# 0.117816195
# Epoch 120/200 - Valid Loss: 0.6834 - MER: 0.1422
# 0.14221191
# Epoch 121/200 - Training Loss: 0.5524 - MER: 0.1212
# 0.121229924
# Epoch 121/200 - Valid Loss: 0.6841 - MER: 0.1428
# 0.14280565
# Epoch 122/200 - Training Loss: 0.5454 - MER: 0.1277
# 0.12766317
# Epoch 122/200 - Valid Loss: 0.7015 - MER: 0.1477
# 0.14766042
# Epoch 123/200 - Training Loss: 0.5511 - MER: 0.1201
# 0.12011103
# Epoch 123/200 - Valid Loss: 0.6897 - MER: 0.1413
# 0.14128436
# Epoch 124/200 - Training Loss: 0.5405 - MER: 0.1249
# 0.12493695
# Epoch 124/200 - Valid Loss: 0.7349 - MER: 0.1459
# 0.14592163
# Epoch 125/200 - Training Loss: 0.5626 - MER: 0.1223
# 0.12228537
# Epoch 125/200 - Valid Loss: 0.6908 - MER: 0.1447
# 0.1447355
# Epoch 126/200 - Training Loss: 0.5474 - MER: 0.1273
# 0.12732437
# Epoch 126/200 - Valid Loss: 0.7076 - MER: 0.1495
# 0.14952026
# Epoch 127/200 - Training Loss: 0.5422 - MER: 0.1163
# 0.11627835
# Epoch 127/200 - Valid Loss: 0.6812 - MER: 0.1417
# 0.14167516
# Epoch 128/200 - Training Loss: 0.5308 - MER: 0.1171
# 0.11706389
# Epoch 128/200 - Valid Loss: 0.6909 - MER: 0.1431
# 0.14305368
# Epoch 129/200 - Training Loss: 0.5401 - MER: 0.1214
# 0.12143183
# Epoch 129/200 - Valid Loss: 0.7101 - MER: 0.1469
# 0.14689536
# Epoch 130/200 - Training Loss: 0.5446 - MER: 0.1206
# 0.1205959
# Epoch 130/200 - Valid Loss: 0.6912 - MER: 0.1477
# 0.14774199
# Epoch 131/200 - Training Loss: 0.5324 - MER: 0.1271
# 0.12711352
# Epoch 131/200 - Valid Loss: 0.6939 - MER: 0.1468
# 0.1468434
# Epoch 132/200 - Training Loss: 0.5450 - MER: 0.1197
# 0.11974372
# Epoch 132/200 - Valid Loss: 0.6841 - MER: 0.1393
# 0.13933504
# Epoch 133/200 - Training Loss: 0.5302 - MER: 0.1198
# 0.119758844
# Epoch 133/200 - Valid Loss: 0.7146 - MER: 0.1492
# 0.149214
# Epoch 134/200 - Training Loss: 0.5354 - MER: 0.1257
# 0.12569487
# Epoch 134/200 - Valid Loss: 0.7252 - MER: 0.1451
# 0.14511566
# Epoch 135/200 - Training Loss: 0.5499 - MER: 0.1170
# 0.11699924
# Epoch 135/200 - Valid Loss: 0.6864 - MER: 0.1407
# 0.14069735
# Epoch 136/200 - Training Loss: 0.5396 - MER: 0.1219
# 0.121939965
# Epoch 136/200 - Valid Loss: 0.7052 - MER: 0.1433
# 0.14334397
# Epoch 137/200 - Training Loss: 0.5300 - MER: 0.1200
# 0.119964406
# Epoch 137/200 - Valid Loss: 0.6861 - MER: 0.1387
# 0.13867515
# Epoch 138/200 - Training Loss: 0.5328 - MER: 0.1207
# 0.120749414
# Epoch 138/200 - Valid Loss: 0.7013 - MER: 0.1447
# 0.14470656
# Epoch 139/200 - Training Loss: 0.5339 - MER: 0.1203
# 0.12027584
# Epoch 139/200 - Valid Loss: 0.6790 - MER: 0.1425
# 0.14247665
# Epoch 140/200 - Training Loss: 0.5453 - MER: 0.1192
# 0.1191511
# Epoch 140/200 - Valid Loss: 0.6834 - MER: 0.1401
# 0.14005852
# Epoch 141/200 - Training Loss: 0.5250 - MER: 0.1209
# 0.12086685
# Epoch 141/200 - Valid Loss: 0.6939 - MER: 0.1425
# 0.14253971
# Epoch 142/200 - Training Loss: 0.5420 - MER: 0.1248
# 0.12478787
# Epoch 142/200 - Valid Loss: 0.7037 - MER: 0.1442
# 0.14421873
# Epoch 143/200 - Training Loss: 0.5423 - MER: 0.1211
# 0.121096335
# Epoch 143/200 - Valid Loss: 0.6847 - MER: 0.1440
# 0.14396927
# Epoch 144/200 - Training Loss: 0.5510 - MER: 0.1241
# 0.124109805
# Epoch 144/200 - Valid Loss: 0.6873 - MER: 0.1424
# 0.14240442
# Epoch 145/200 - Training Loss: 0.5280 - MER: 0.1217
# 0.12167704
# Epoch 145/200 - Valid Loss: 0.6878 - MER: 0.1481
# 0.14812437
# Epoch 146/200 - Training Loss: 0.5396 - MER: 0.1206
# 0.12064747
# Epoch 146/200 - Valid Loss: 0.7058 - MER: 0.1466
# 0.14664352
# Epoch 147/200 - Training Loss: 0.5233 - MER: 0.1207
# 0.12068318
# Epoch 147/200 - Valid Loss: 0.6934 - MER: 0.1439
# 0.1439189
# Epoch 148/200 - Training Loss: 0.5375 - MER: 0.1245
# 0.124532916
# Epoch 148/200 - Valid Loss: 0.7093 - MER: 0.1451
# 0.14505386
# Epoch 149/200 - Training Loss: 0.5198 - MER: 0.1180
# 0.11799918
# Epoch 149/200 - Valid Loss: 0.6830 - MER: 0.1438
# 0.14383605
# Epoch 150/200 - Training Loss: 0.5228 - MER: 0.1258
# 0.12577398
# Epoch 150/200 - Valid Loss: 0.6878 - MER: 0.1472
# 0.14722973
# Epoch 151/200 - Training Loss: 0.5310 - MER: 0.1165
# 0.11654346
# Epoch 151/200 - Valid Loss: 0.6816 - MER: 0.1380
# 0.13801652
# Epoch 152/200 - Training Loss: 0.5257 - MER: 0.1209
# 0.12086682
# Epoch 152/200 - Valid Loss: 0.6897 - MER: 0.1439
# 0.14392751
# Epoch 153/200 - Training Loss: 0.5194 - MER: 0.1178
# 0.1178452
# Epoch 153/200 - Valid Loss: 0.7024 - MER: 0.1396
# 0.13964733
# Epoch 154/200 - Training Loss: 0.5243 - MER: 0.1147
# 0.11465587
# Epoch 154/200 - Valid Loss: 0.6776 - MER: 0.1389
# 0.13889568
# Epoch 155/200 - Training Loss: 0.5234 - MER: 0.1203
# 0.120335415
# Epoch 155/200 - Valid Loss: 0.6914 - MER: 0.1429
# 0.1428865
# Epoch 156/200 - Training Loss: 0.5288 - MER: 0.1197
# 0.1196779
# Epoch 156/200 - Valid Loss: 0.6958 - MER: 0.1434
# 0.14344727
# Epoch 157/200 - Training Loss: 0.5257 - MER: 0.1132
# 0.1131891
# Epoch 157/200 - Valid Loss: 0.6759 - MER: 0.1403
# 0.14033842
# Epoch 158/200 - Training Loss: 0.5336 - MER: 0.1294
# 0.12943695
# Epoch 158/200 - Valid Loss: 0.7085 - MER: 0.1519
# 0.1519321
# Epoch 159/200 - Training Loss: 0.5264 - MER: 0.1144
# 0.114383854
# Epoch 159/200 - Valid Loss: 0.6735 - MER: 0.1383
# 0.13828862
# Epoch 160/200 - Training Loss: 0.5237 - MER: 0.1134
# 0.11339949
# Epoch 160/200 - Valid Loss: 0.6834 - MER: 0.1419
# 0.14193448
# Epoch 161/200 - Training Loss: 0.5229 - MER: 0.1276
# 0.12758932
# Epoch 161/200 - Valid Loss: 0.7075 - MER: 0.1473
# 0.14728643
# Epoch 162/200 - Training Loss: 0.5348 - MER: 0.1245
# 0.12446885
# Epoch 162/200 - Valid Loss: 0.6944 - MER: 0.1466
# 0.1465788
# Epoch 163/200 - Training Loss: 0.5174 - MER: 0.1179
# 0.117932566
# Epoch 163/200 - Valid Loss: 0.6887 - MER: 0.1365
# 0.13652106
# Epoch 164/200 - Training Loss: 0.5211 - MER: 0.1236
# 0.123622775
# Epoch 164/200 - Valid Loss: 0.6839 - MER: 0.1445
# 0.14445853
# Epoch 165/200 - Training Loss: 0.5150 - MER: 0.1136
# 0.113586634
# Epoch 165/200 - Valid Loss: 0.6937 - MER: 0.1400
# 0.13998045
# Epoch 166/200 - Training Loss: 0.5256 - MER: 0.1208
# 0.120778225
# Epoch 166/200 - Valid Loss: 0.6995 - MER: 0.1474
# 0.14742333
# Epoch 167/200 - Training Loss: 0.5241 - MER: 0.1184
# 0.118401855
# Epoch 167/200 - Valid Loss: 0.6957 - MER: 0.1423
# 0.14225043
# Epoch 168/200 - Training Loss: 0.5245 - MER: 0.1217
# 0.1217483
# Epoch 168/200 - Valid Loss: 0.7215 - MER: 0.1425
# 0.14249668
# Epoch 169/200 - Training Loss: 0.5287 - MER: 0.1147
# 0.114709094
# Epoch 169/200 - Valid Loss: 0.6770 - MER: 0.1426
# 0.14256746
# Epoch 170/200 - Training Loss: 0.5193 - MER: 0.1316
# 0.1315796
# Epoch 170/200 - Valid Loss: 0.7209 - MER: 0.1549
# 0.1549219
# Epoch 171/200 - Training Loss: 0.5254 - MER: 0.1138
# 0.11381804
# Epoch 171/200 - Valid Loss: 0.6872 - MER: 0.1366
# 0.1365894
# Epoch 172/200 - Training Loss: 0.5139 - MER: 0.1185
# 0.11845201
# Epoch 172/200 - Valid Loss: 0.6774 - MER: 0.1458
# 0.14581828
# Epoch 173/200 - Training Loss: 0.5100 - MER: 0.1211
# 0.12114501
# Epoch 173/200 - Valid Loss: 0.6892 - MER: 0.1469
# 0.14694421
# Epoch 174/200 - Training Loss: 0.5124 - MER: 0.1144
# 0.11436389
# Epoch 174/200 - Valid Loss: 0.6634 - MER: 0.1415
# 0.14152199
# Epoch 175/200 - Training Loss: 0.5093 - MER: 0.1127
# 0.1126627
# Epoch 175/200 - Valid Loss: 0.6836 - MER: 0.1396
# 0.13964553
# Epoch 176/200 - Training Loss: 0.5117 - MER: 0.1148
# 0.114836015
# Epoch 176/200 - Valid Loss: 0.6845 - MER: 0.1368
# 0.13683482
# Epoch 177/200 - Training Loss: 0.5251 - MER: 0.1318
# 0.1318269
# Epoch 177/200 - Valid Loss: 0.7221 - MER: 0.1528
# 0.15282479
# Epoch 178/200 - Training Loss: 0.5182 - MER: 0.1123
# 0.112325646
# Epoch 178/200 - Valid Loss: 0.6723 - MER: 0.1385
# 0.13847229
# Epoch 179/200 - Training Loss: 0.5150 - MER: 0.1155
# 0.11552875
# Epoch 179/200 - Valid Loss: 0.6823 - MER: 0.1394
# 0.13940619
# Epoch 180/200 - Training Loss: 0.5148 - MER: 0.1249
# 0.12486969
# Epoch 180/200 - Valid Loss: 0.7423 - MER: 0.1454
# 0.14536348
# Epoch 181/200 - Training Loss: 0.5218 - MER: 0.1183
# 0.1182798
# Epoch 181/200 - Valid Loss: 0.6841 - MER: 0.1427
# 0.14266206
# Epoch 182/200 - Training Loss: 0.5065 - MER: 0.1136
# 0.113630116
# Epoch 182/200 - Valid Loss: 0.6931 - MER: 0.1398
# 0.13979875
# Epoch 183/200 - Training Loss: 0.5082 - MER: 0.1147
# 0.11466077
# Epoch 183/200 - Valid Loss: 0.6693 - MER: 0.1426
# 0.14255916
# Epoch 184/200 - Training Loss: 0.5087 - MER: 0.1121
# 0.1120874
# Epoch 184/200 - Valid Loss: 0.6705 - MER: 0.1340
# 0.1339526
# Epoch 185/200 - Training Loss: 0.5159 - MER: 0.1193
# 0.1192988
# Epoch 185/200 - Valid Loss: 0.7147 - MER: 0.1396
# 0.13961034
# Epoch 186/200 - Training Loss: 0.5313 - MER: 0.1197
# 0.1196605
# Epoch 186/200 - Valid Loss: 0.6946 - MER: 0.1427
# 0.14265001
# Epoch 187/200 - Training Loss: 0.5092 - MER: 0.1171
# 0.11712669
# Epoch 187/200 - Valid Loss: 0.6778 - MER: 0.1415
# 0.14151822
# Epoch 188/200 - Training Loss: 0.5060 - MER: 0.1215
# 0.12150674
# Epoch 188/200 - Valid Loss: 0.6984 - MER: 0.1442
# 0.14417653
# Epoch 189/200 - Training Loss: 0.5124 - MER: 0.1159
# 0.11592043
# Epoch 189/200 - Valid Loss: 0.6769 - MER: 0.1408
# 0.14084618
# Epoch 190/200 - Training Loss: 0.5049 - MER: 0.1218
# 0.1218321
# Epoch 190/200 - Valid Loss: 0.6893 - MER: 0.1454
# 0.14543697
# Epoch 191/200 - Training Loss: 0.5069 - MER: 0.1192
# 0.11919332
# Epoch 191/200 - Valid Loss: 0.6914 - MER: 0.1430
# 0.14300226
# Epoch 192/200 - Training Loss: 0.5227 - MER: 0.1244
# 0.12444228
# Epoch 192/200 - Valid Loss: 0.6924 - MER: 0.1477
# 0.14774303
# Epoch 193/200 - Training Loss: 0.5109 - MER: 0.1144
# 0.114366286
# Epoch 193/200 - Valid Loss: 0.6830 - MER: 0.1421
# 0.14211395
# Epoch 194/200 - Training Loss: 0.4979 - MER: 0.1177
# 0.11773221
# Epoch 194/200 - Valid Loss: 0.6871 - MER: 0.1430
# 0.14298654
# Epoch 195/200 - Training Loss: 0.4984 - MER: 0.1145
# 0.114471056
# Epoch 195/200 - Valid Loss: 0.6819 - MER: 0.1446
# 0.1446249
# Epoch 196/200 - Training Loss: 0.5003 - MER: 0.1119
# 0.111865625
# Epoch 196/200 - Valid Loss: 0.6837 - MER: 0.1404
# 0.14037786
# Epoch 197/200 - Training Loss: 0.5016 - MER: 0.1112
# 0.11121367
# Epoch 197/200 - Valid Loss: 0.6809 - MER: 0.1373
# 0.13733898
# Epoch 198/200 - Training Loss: 0.5077 - MER: 0.1325
# 0.13249154
# Epoch 198/200 - Valid Loss: 0.7273 - MER: 0.1524
# 0.15237477
# Epoch 199/200 - Training Loss: 0.5084 - MER: 0.1146
# 0.11458711
# Epoch 199/200 - Valid Loss: 0.6968 - MER: 0.1402
# 0.14018235
# Epoch 200/200 - Training Loss: 0.5022 - MER: 0.1126
# 0.112632155
# Epoch 200/200 - Valid Loss: 0.6804 - MER: 0.1426
# 0.14260805

# %%
plt.plot(mer_values_train_MLP_3, label='Training MER')
plt.plot(mer_values_valid_MLP_3, label='Validation MER')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Add dropout layer
#
# In the following, add dropout layer to the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization
model_4 = nn.Sequential(
    nn.Linear(train_features.shape[1], 512),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(64, 1)
)

model_4.to(device)


criterion_MLP_4 = nn.SmoothL1Loss()

# Define the optimizer with weight decay for L2 regularization
optimizer_MLP_4 = optim.Adam(model_4.parameters(), lr=0.001, weight_decay=0.001)  # Adjust the weight decay value as needed

epochs = 200
train_losses_MLP_4, valid_losses_MLP_4 = [], []
mer_values_train_MLP_4, mer_values_valid_MLP_4 = [], []

for e in range(epochs):
    running_train_loss = 0
    for batch_features, batch_labels in train_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        logps = model_4(batch_features)
        loss = criterion_MLP_4(logps, batch_labels)

        # Get the L2 norm of the model's parameters
        l2_reg = None
        for param in model_4.parameters():
            if l2_reg is None:
                l2_reg = param.norm(2)  # Compute the L2 norm
            else:
                l2_reg = l2_reg + param.norm(2)

        # Add the regularization term to the loss
        loss = loss + 0.001 * l2_reg  # Adjust the regularization strength (0.001 in this case)

        optimizer_MLP_4.zero_grad()
        loss.backward()
        optimizer_MLP_4.step()

        running_train_loss += loss.item()

    # Validation and other calculations remain the same as before

    else:
      running_valid_loss = 0
      with torch.no_grad():
        model_4.eval()
        for batch_features, batch_labels in valid_loader:
          batch_features = batch_features.to(device)
          batch_labels = batch_labels.to(device)

          outputs = model_4(batch_features)
          loss = criterion_MLP_4(outputs, batch_labels)
          running_valid_loss += loss.item()

      model_4.train()
      train_loss = running_train_loss/len(train_loader)
      valid_loss = running_valid_loss/len(valid_loader)
      train_losses_MLP_4.append(train_loss)
      valid_losses_MLP_4.append(valid_loss)



  # Calculate MER for this epoch and append to the list
    train_loss = running_train_loss / len(train_loader)
    train_losses_MLP_4.append(train_loss)

    valid_loss = running_valid_loss / len(valid_loader)
    valid_losses_MLP_4.append(valid_loss)

  # Calculate MER based on your code
    train_features = train_features.to(device)
    train_labels = train_labels.to(device)
    valid_features = valid_features.to(device)
    valid_labels = valid_labels.to(device)

    predicted_train = model_4(train_features).cpu().detach().numpy()
    actual_train = train_labels.cpu().numpy()
    error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
    mer_train_MLP = np.median(error_rates_train)
    mer_values_train_MLP_4.append(mer_train_MLP)

    predicted_valid = model_4(valid_features).cpu().detach().numpy()
    actual_valid = valid_labels.cpu().numpy()
    error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
    mer_valid_MLP = np.median(error_rates_valid)
    mer_values_valid_MLP_4.append(mer_valid_MLP)


    print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
    print(mer_train_MLP)
    print(f"Epoch {e + 1}/{epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid_MLP:.4f}")
    print(mer_valid_MLP)
# Out:
# Epoch 1/200 - Training Loss: 2.2030 - MER: 0.2539
# 0.25387353
# Epoch 1/200 - Valid Loss: 1.0345 - MER: 0.2574
# 0.25740302
# Epoch 2/200 - Training Loss: 1.1640 - MER: 0.2306
# 0.23056711
# Epoch 2/200 - Valid Loss: 0.8707 - MER: 0.2316
# 0.23157628
# Epoch 3/200 - Training Loss: 1.0368 - MER: 0.2202
# 0.22015475
# Epoch 3/200 - Valid Loss: 0.8370 - MER: 0.2199
# 0.2199108
# Epoch 4/200 - Training Loss: 0.9638 - MER: 0.2169
# 0.21685682
# Epoch 4/200 - Valid Loss: 0.7754 - MER: 0.2123
# 0.21230793
# Epoch 5/200 - Training Loss: 0.9327 - MER: 0.2064
# 0.2063877
# Epoch 5/200 - Valid Loss: 0.8258 - MER: 0.2092
# 0.2092051
# Epoch 6/200 - Training Loss: 0.9063 - MER: 0.2025
# 0.2025244
# Epoch 6/200 - Valid Loss: 0.7733 - MER: 0.2070
# 0.20703511
# Epoch 7/200 - Training Loss: 0.8863 - MER: 0.2002
# 0.20021504
# Epoch 7/200 - Valid Loss: 0.7582 - MER: 0.2082
# 0.20821784
# Epoch 8/200 - Training Loss: 0.8771 - MER: 0.1952
# 0.19521037
# Epoch 8/200 - Valid Loss: 0.7321 - MER: 0.1987
# 0.19872305
# Epoch 9/200 - Training Loss: 0.8575 - MER: 0.1936
# 0.19356501
# Epoch 9/200 - Valid Loss: 0.7151 - MER: 0.1949
# 0.19491497
# Epoch 10/200 - Training Loss: 0.8642 - MER: 0.1864
# 0.18635869
# Epoch 10/200 - Valid Loss: 0.7172 - MER: 0.2034
# 0.20338999
# Epoch 11/200 - Training Loss: 0.8441 - MER: 0.1853
# 0.18526626
# Epoch 11/200 - Valid Loss: 0.7175 - MER: 0.1943
# 0.1943403
# Epoch 12/200 - Training Loss: 0.8307 - MER: 0.1905
# 0.19047779
# Epoch 12/200 - Valid Loss: 0.7116 - MER: 0.2028
# 0.20284078
# Epoch 13/200 - Training Loss: 0.8159 - MER: 0.1901
# 0.190115
# Epoch 13/200 - Valid Loss: 0.7459 - MER: 0.2040
# 0.20398435
# Epoch 14/200 - Training Loss: 0.8447 - MER: 0.2056
# 0.20559713
# Epoch 14/200 - Valid Loss: 0.7990 - MER: 0.2096
# 0.20956883
# Epoch 15/200 - Training Loss: 0.8174 - MER: 0.1825
# 0.18251422
# Epoch 15/200 - Valid Loss: 0.6953 - MER: 0.1899
# 0.18987851
# Epoch 16/200 - Training Loss: 0.8047 - MER: 0.1842
# 0.18418631
# Epoch 16/200 - Valid Loss: 0.7077 - MER: 0.1923
# 0.19230495
# Epoch 17/200 - Training Loss: 0.8131 - MER: 0.1826
# 0.18263845
# Epoch 17/200 - Valid Loss: 0.7132 - MER: 0.1841
# 0.18405104
# Epoch 18/200 - Training Loss: 0.8148 - MER: 0.1792
# 0.17920007
# Epoch 18/200 - Valid Loss: 0.6977 - MER: 0.1853
# 0.18533008
# Epoch 19/200 - Training Loss: 0.7997 - MER: 0.1799
# 0.17992876
# Epoch 19/200 - Valid Loss: 0.6929 - MER: 0.1829
# 0.1829293
# Epoch 20/200 - Training Loss: 0.8051 - MER: 0.2001
# 0.20013577
# Epoch 20/200 - Valid Loss: 0.7470 - MER: 0.2050
# 0.20498708
# Epoch 21/200 - Training Loss: 0.8095 - MER: 0.1771
# 0.1771467
# Epoch 21/200 - Valid Loss: 0.6955 - MER: 0.1861
# 0.18605405
# Epoch 22/200 - Training Loss: 0.7927 - MER: 0.1791
# 0.17907834
# Epoch 22/200 - Valid Loss: 0.6955 - MER: 0.1948
# 0.19482899
# Epoch 23/200 - Training Loss: 0.7828 - MER: 0.1803
# 0.18025678
# Epoch 23/200 - Valid Loss: 0.6914 - MER: 0.1882
# 0.1882328
# Epoch 24/200 - Training Loss: 0.7963 - MER: 0.1784
# 0.17844604
# Epoch 24/200 - Valid Loss: 0.7396 - MER: 0.1854
# 0.18536866
# Epoch 25/200 - Training Loss: 0.8101 - MER: 0.1726
# 0.17264846
# Epoch 25/200 - Valid Loss: 0.6954 - MER: 0.1754
# 0.1754023
# Epoch 26/200 - Training Loss: 0.7901 - MER: 0.1718
# 0.17175545
# Epoch 26/200 - Valid Loss: 0.7118 - MER: 0.1809
# 0.18094349
# Epoch 27/200 - Training Loss: 0.7965 - MER: 0.1725
# 0.17246951
# Epoch 27/200 - Valid Loss: 0.7393 - MER: 0.1768
# 0.1767621
# Epoch 28/200 - Training Loss: 0.7666 - MER: 0.1761
# 0.1761015
# Epoch 28/200 - Valid Loss: 0.7373 - MER: 0.1795
# 0.17952
# Epoch 29/200 - Training Loss: 0.7669 - MER: 0.1751
# 0.17509916
# Epoch 29/200 - Valid Loss: 0.6964 - MER: 0.1776
# 0.17762607
# Epoch 30/200 - Training Loss: 0.7603 - MER: 0.1679
# 0.16794702
# Epoch 30/200 - Valid Loss: 0.7022 - MER: 0.1727
# 0.17267363
# Epoch 31/200 - Training Loss: 0.7744 - MER: 0.1729
# 0.1729317
# Epoch 31/200 - Valid Loss: 0.7039 - MER: 0.1769
# 0.17685765
# Epoch 32/200 - Training Loss: 0.7810 - MER: 0.1704
# 0.17036203
# Epoch 32/200 - Valid Loss: 0.6913 - MER: 0.1738
# 0.17380333
# Epoch 33/200 - Training Loss: 0.7627 - MER: 0.1774
# 0.17740557
# Epoch 33/200 - Valid Loss: 0.7657 - MER: 0.1806
# 0.18057545
# Epoch 34/200 - Training Loss: 0.7656 - MER: 0.1753
# 0.17529973
# Epoch 34/200 - Valid Loss: 0.7592 - MER: 0.1808
# 0.18082333
# Epoch 35/200 - Training Loss: 0.7514 - MER: 0.1742
# 0.17417197
# Epoch 35/200 - Valid Loss: 0.7124 - MER: 0.1795
# 0.17954428
# Epoch 36/200 - Training Loss: 0.7521 - MER: 0.1704
# 0.1704365
# Epoch 36/200 - Valid Loss: 0.6996 - MER: 0.1704
# 0.17039603
# Epoch 37/200 - Training Loss: 0.7585 - MER: 0.1723
# 0.17234083
# Epoch 37/200 - Valid Loss: 0.7094 - MER: 0.1827
# 0.1826626
# Epoch 38/200 - Training Loss: 0.7525 - MER: 0.1749
# 0.17485544
# Epoch 38/200 - Valid Loss: 0.7086 - MER: 0.1777
# 0.17767766
# Epoch 39/200 - Training Loss: 0.7625 - MER: 0.1655
# 0.16551217
# Epoch 39/200 - Valid Loss: 0.6928 - MER: 0.1764
# 0.17638938
# Epoch 40/200 - Training Loss: 0.7471 - MER: 0.1653
# 0.16531463
# Epoch 40/200 - Valid Loss: 0.6983 - MER: 0.1702
# 0.1701693
# Epoch 41/200 - Training Loss: 0.7573 - MER: 0.1708
# 0.17083457
# Epoch 41/200 - Valid Loss: 0.7408 - MER: 0.1776
# 0.17759958
# Epoch 42/200 - Training Loss: 0.7453 - MER: 0.1663
# 0.16626696
# Epoch 42/200 - Valid Loss: 0.7009 - MER: 0.1692
# 0.16920422
# Epoch 43/200 - Training Loss: 0.7605 - MER: 0.1671
# 0.16714016
# Epoch 43/200 - Valid Loss: 0.6886 - MER: 0.1747
# 0.17466302
# Epoch 44/200 - Training Loss: 0.7586 - MER: 0.1647
# 0.16467838
# Epoch 44/200 - Valid Loss: 0.7087 - MER: 0.1736
# 0.17357816
# Epoch 45/200 - Training Loss: 0.7594 - MER: 0.1663
# 0.16630334
# Epoch 45/200 - Valid Loss: 0.6909 - MER: 0.1746
# 0.17464004
# Epoch 46/200 - Training Loss: 0.7399 - MER: 0.1652
# 0.16517285
# Epoch 46/200 - Valid Loss: 0.7032 - MER: 0.1725
# 0.17247483
# Epoch 47/200 - Training Loss: 0.7307 - MER: 0.1666
# 0.16655138
# Epoch 47/200 - Valid Loss: 0.7220 - MER: 0.1763
# 0.17629151
# Epoch 48/200 - Training Loss: 0.7322 - MER: 0.1644
# 0.16444713
# Epoch 48/200 - Valid Loss: 0.6953 - MER: 0.1692
# 0.16915974
# Epoch 49/200 - Training Loss: 0.7400 - MER: 0.1648
# 0.16477096
# Epoch 49/200 - Valid Loss: 0.6979 - MER: 0.1731
# 0.17311957
# Epoch 50/200 - Training Loss: 0.7461 - MER: 0.1602
# 0.16018708
# Epoch 50/200 - Valid Loss: 0.6992 - MER: 0.1706
# 0.1706135
# Epoch 51/200 - Training Loss: 0.7291 - MER: 0.1679
# 0.16789183
# Epoch 51/200 - Valid Loss: 0.7542 - MER: 0.1755
# 0.17551869
# Epoch 52/200 - Training Loss: 0.7296 - MER: 0.1670
# 0.16702506
# Epoch 52/200 - Valid Loss: 0.7023 - MER: 0.1812
# 0.18117633
# Epoch 53/200 - Training Loss: 0.7097 - MER: 0.1616
# 0.16163908
# Epoch 53/200 - Valid Loss: 0.6963 - MER: 0.1669
# 0.16692427
# Epoch 54/200 - Training Loss: 0.7179 - MER: 0.1651
# 0.16514996
# Epoch 54/200 - Valid Loss: 0.6933 - MER: 0.1723
# 0.17232303
# Epoch 55/200 - Training Loss: 0.7207 - MER: 0.1642
# 0.164238
# Epoch 55/200 - Valid Loss: 0.6944 - MER: 0.1669
# 0.16688119
# Epoch 56/200 - Training Loss: 0.7223 - MER: 0.1664
# 0.16635215
# Epoch 56/200 - Valid Loss: 0.6935 - MER: 0.1768
# 0.17682377
# Epoch 57/200 - Training Loss: 0.7219 - MER: 0.1609
# 0.16085094
# Epoch 57/200 - Valid Loss: 0.7013 - MER: 0.1683
# 0.16834947
# Epoch 58/200 - Training Loss: 0.7232 - MER: 0.1576
# 0.15759605
# Epoch 58/200 - Valid Loss: 0.6854 - MER: 0.1614
# 0.16135502
# Epoch 59/200 - Training Loss: 0.7225 - MER: 0.1591
# 0.15905216
# Epoch 59/200 - Valid Loss: 0.6826 - MER: 0.1616
# 0.16163082
# Epoch 60/200 - Training Loss: 0.7273 - MER: 0.1608
# 0.16075614
# Epoch 60/200 - Valid Loss: 0.6964 - MER: 0.1726
# 0.17261055
# Epoch 61/200 - Training Loss: 0.7064 - MER: 0.1654
# 0.16535309
# Epoch 61/200 - Valid Loss: 0.7257 - MER: 0.1665
# 0.16654901
# Epoch 62/200 - Training Loss: 0.7284 - MER: 0.1609
# 0.16086532
# Epoch 62/200 - Valid Loss: 0.6945 - MER: 0.1683
# 0.16829586
# Epoch 63/200 - Training Loss: 0.7211 - MER: 0.1581
# 0.15812944
# Epoch 63/200 - Valid Loss: 0.6960 - MER: 0.1660
# 0.16603665
# Epoch 64/200 - Training Loss: 0.7145 - MER: 0.1622
# 0.16222677
# Epoch 64/200 - Valid Loss: 0.7207 - MER: 0.1707
# 0.17074786
# Epoch 65/200 - Training Loss: 0.7122 - MER: 0.1703
# 0.17032623
# Epoch 65/200 - Valid Loss: 0.7074 - MER: 0.1806
# 0.180608
# Epoch 66/200 - Training Loss: 0.7225 - MER: 0.1581
# 0.1580753
# Epoch 66/200 - Valid Loss: 0.7109 - MER: 0.1659
# 0.16586098
# Epoch 67/200 - Training Loss: 0.7109 - MER: 0.1581
# 0.15811935
# Epoch 67/200 - Valid Loss: 0.6978 - MER: 0.1627
# 0.16266887
# Epoch 68/200 - Training Loss: 0.7213 - MER: 0.1567
# 0.15667546
# Epoch 68/200 - Valid Loss: 0.6947 - MER: 0.1578
# 0.15783432
# Epoch 69/200 - Training Loss: 0.7121 - MER: 0.1578
# 0.15775894
# Epoch 69/200 - Valid Loss: 0.6847 - MER: 0.1734
# 0.17342949
# Epoch 70/200 - Training Loss: 0.7119 - MER: 0.1570
# 0.15702036
# Epoch 70/200 - Valid Loss: 0.7021 - MER: 0.1656
# 0.16563427
# Epoch 71/200 - Training Loss: 0.7132 - MER: 0.1594
# 0.15936258
# Epoch 71/200 - Valid Loss: 0.6983 - MER: 0.1686
# 0.16859472
# Epoch 72/200 - Training Loss: 0.7270 - MER: 0.1567
# 0.15669635
# Epoch 72/200 - Valid Loss: 0.6893 - MER: 0.1675
# 0.1675041
# Epoch 73/200 - Training Loss: 0.7098 - MER: 0.1564
# 0.15643543
# Epoch 73/200 - Valid Loss: 0.7029 - MER: 0.1664
# 0.1663815
# Epoch 74/200 - Training Loss: 0.7060 - MER: 0.1578
# 0.15784185
# Epoch 74/200 - Valid Loss: 0.6837 - MER: 0.1705
# 0.17054833
# Epoch 75/200 - Training Loss: 0.6956 - MER: 0.1560
# 0.15596357
# Epoch 75/200 - Valid Loss: 0.6994 - MER: 0.1592
# 0.15923806
# Epoch 76/200 - Training Loss: 0.6981 - MER: 0.1636
# 0.1635513
# Epoch 76/200 - Valid Loss: 0.7093 - MER: 0.1706
# 0.17061356
# Epoch 77/200 - Training Loss: 0.6905 - MER: 0.1586
# 0.15861082
# Epoch 77/200 - Valid Loss: 0.7074 - MER: 0.1586
# 0.15863965
# Epoch 78/200 - Training Loss: 0.6950 - MER: 0.1555
# 0.15548669
# Epoch 78/200 - Valid Loss: 0.7064 - MER: 0.1639
# 0.16385932
# Epoch 79/200 - Training Loss: 0.6975 - MER: 0.1583
# 0.15828073
# Epoch 79/200 - Valid Loss: 0.7070 - MER: 0.1729
# 0.1729482
# Epoch 80/200 - Training Loss: 0.7000 - MER: 0.1552
# 0.15518875
# Epoch 80/200 - Valid Loss: 0.6978 - MER: 0.1641
# 0.16413876
# Epoch 81/200 - Training Loss: 0.7011 - MER: 0.1560
# 0.15598854
# Epoch 81/200 - Valid Loss: 0.7101 - MER: 0.1609
# 0.16094267
# Epoch 82/200 - Training Loss: 0.6995 - MER: 0.1565
# 0.1564524
# Epoch 82/200 - Valid Loss: 0.6945 - MER: 0.1683
# 0.1682684
# Epoch 83/200 - Training Loss: 0.6988 - MER: 0.1625
# 0.162473
# Epoch 83/200 - Valid Loss: 0.6912 - MER: 0.1675
# 0.16753711
# Epoch 84/200 - Training Loss: 0.6962 - MER: 0.1553
# 0.15533844
# Epoch 84/200 - Valid Loss: 0.7251 - MER: 0.1641
# 0.16407222
# Epoch 85/200 - Training Loss: 0.7053 - MER: 0.1556
# 0.15555115
# Epoch 85/200 - Valid Loss: 0.6895 - MER: 0.1674
# 0.16736062
# Epoch 86/200 - Training Loss: 0.6899 - MER: 0.1540
# 0.15399863
# Epoch 86/200 - Valid Loss: 0.7030 - MER: 0.1703
# 0.17034021
# Epoch 87/200 - Training Loss: 0.6984 - MER: 0.1539
# 0.15387374
# Epoch 87/200 - Valid Loss: 0.7351 - MER: 0.1651
# 0.16506918
# Epoch 88/200 - Training Loss: 0.6949 - MER: 0.1565
# 0.156541
# Epoch 88/200 - Valid Loss: 0.6952 - MER: 0.1732
# 0.17315382
# Epoch 89/200 - Training Loss: 0.6803 - MER: 0.1503
# 0.15028861
# Epoch 89/200 - Valid Loss: 0.6749 - MER: 0.1655
# 0.1654533
# Epoch 90/200 - Training Loss: 0.6816 - MER: 0.1527
# 0.15272364
# Epoch 90/200 - Valid Loss: 0.6833 - MER: 0.1666
# 0.16659105
# Epoch 91/200 - Training Loss: 0.6774 - MER: 0.1559
# 0.15593237
# Epoch 91/200 - Valid Loss: 0.7000 - MER: 0.1680
# 0.167951
# Epoch 92/200 - Training Loss: 0.6886 - MER: 0.1568
# 0.15683249
# Epoch 92/200 - Valid Loss: 0.6961 - MER: 0.1614
# 0.16135924
# Epoch 93/200 - Training Loss: 0.6956 - MER: 0.1524
# 0.15243739
# Epoch 93/200 - Valid Loss: 0.7108 - MER: 0.1578
# 0.15779935
# Epoch 94/200 - Training Loss: 0.6944 - MER: 0.1519
# 0.15186402
# Epoch 94/200 - Valid Loss: 0.6768 - MER: 0.1596
# 0.15962602
# Epoch 95/200 - Training Loss: 0.6740 - MER: 0.1536
# 0.15357183
# Epoch 95/200 - Valid Loss: 0.6857 - MER: 0.1631
# 0.16313142
# Epoch 96/200 - Training Loss: 0.6916 - MER: 0.1537
# 0.1536969
# Epoch 96/200 - Valid Loss: 0.6987 - MER: 0.1692
# 0.16924909
# Epoch 97/200 - Training Loss: 0.6868 - MER: 0.1572
# 0.15722544
# Epoch 97/200 - Valid Loss: 0.6782 - MER: 0.1659
# 0.16588715
# Epoch 98/200 - Training Loss: 0.6894 - MER: 0.1524
# 0.1523583
# Epoch 98/200 - Valid Loss: 0.6944 - MER: 0.1663
# 0.16628255
# Epoch 99/200 - Training Loss: 0.6872 - MER: 0.1570
# 0.15697372
# Epoch 99/200 - Valid Loss: 0.7001 - MER: 0.1676
# 0.16755523
# Epoch 100/200 - Training Loss: 0.6863 - MER: 0.1498
# 0.14983615
# Epoch 100/200 - Valid Loss: 0.6819 - MER: 0.1614
# 0.16144593
# Epoch 101/200 - Training Loss: 0.6808 - MER: 0.1621
# 0.1621092
# Epoch 101/200 - Valid Loss: 0.7013 - MER: 0.1760
# 0.1759978
# Epoch 102/200 - Training Loss: 0.6730 - MER: 0.1520
# 0.15198022
# Epoch 102/200 - Valid Loss: 0.6954 - MER: 0.1671
# 0.16705094
# Epoch 103/200 - Training Loss: 0.6821 - MER: 0.1568
# 0.15684271
# Epoch 103/200 - Valid Loss: 0.7395 - MER: 0.1633
# 0.16326979
# Epoch 104/200 - Training Loss: 0.6823 - MER: 0.1487
# 0.14873944
# Epoch 104/200 - Valid Loss: 0.6856 - MER: 0.1644
# 0.1643511
# Epoch 105/200 - Training Loss: 0.6830 - MER: 0.1554
# 0.15535232
# Epoch 105/200 - Valid Loss: 0.7155 - MER: 0.1602
# 0.16024454
# Epoch 106/200 - Training Loss: 0.6726 - MER: 0.1522
# 0.15220088
# Epoch 106/200 - Valid Loss: 0.6841 - MER: 0.1664
# 0.16643988
# Epoch 107/200 - Training Loss: 0.6687 - MER: 0.1536
# 0.15361866
# Epoch 107/200 - Valid Loss: 0.7049 - MER: 0.1683
# 0.16827656
# Epoch 108/200 - Training Loss: 0.6769 - MER: 0.1518
# 0.15176731
# Epoch 108/200 - Valid Loss: 0.6663 - MER: 0.1605
# 0.1605324
# Epoch 109/200 - Training Loss: 0.6785 - MER: 0.1514
# 0.15138575
# Epoch 109/200 - Valid Loss: 0.6764 - MER: 0.1673
# 0.16726568
# Epoch 110/200 - Training Loss: 0.6685 - MER: 0.1502
# 0.1502362
# Epoch 110/200 - Valid Loss: 0.6763 - MER: 0.1633
# 0.16328886
# Epoch 111/200 - Training Loss: 0.6763 - MER: 0.1540
# 0.15399566
# Epoch 111/200 - Valid Loss: 0.6778 - MER: 0.1636
# 0.16357219
# Epoch 112/200 - Training Loss: 0.6918 - MER: 0.1511
# 0.15110338
# Epoch 112/200 - Valid Loss: 0.6697 - MER: 0.1618
# 0.16177501
# Epoch 113/200 - Training Loss: 0.6688 - MER: 0.1494
# 0.14938241
# Epoch 113/200 - Valid Loss: 0.6917 - MER: 0.1638
# 0.16380881
# Epoch 114/200 - Training Loss: 0.6770 - MER: 0.1503
# 0.15027069
# Epoch 114/200 - Valid Loss: 0.7009 - MER: 0.1608
# 0.16083221
# Epoch 115/200 - Training Loss: 0.6726 - MER: 0.1508
# 0.15078327
# Epoch 115/200 - Valid Loss: 0.6805 - MER: 0.1661
# 0.16610345
# Epoch 116/200 - Training Loss: 0.6803 - MER: 0.1511
# 0.15109178
# Epoch 116/200 - Valid Loss: 0.6708 - MER: 0.1585
# 0.15852098
# Epoch 117/200 - Training Loss: 0.6539 - MER: 0.1473
# 0.14730561
# Epoch 117/200 - Valid Loss: 0.6792 - MER: 0.1536
# 0.1536113
# Epoch 118/200 - Training Loss: 0.6604 - MER: 0.1517
# 0.15168282
# Epoch 118/200 - Valid Loss: 0.7344 - MER: 0.1596
# 0.1595812
# Epoch 119/200 - Training Loss: 0.6760 - MER: 0.1540
# 0.15397277
# Epoch 119/200 - Valid Loss: 0.6928 - MER: 0.1688
# 0.1688068
# Epoch 120/200 - Training Loss: 0.6675 - MER: 0.1532
# 0.15320742
# Epoch 120/200 - Valid Loss: 0.7321 - MER: 0.1567
# 0.1566739
# Epoch 121/200 - Training Loss: 0.6720 - MER: 0.1493
# 0.14930975
# Epoch 121/200 - Valid Loss: 0.6775 - MER: 0.1645
# 0.16447836
# Epoch 122/200 - Training Loss: 0.6709 - MER: 0.1554
# 0.1554079
# Epoch 122/200 - Valid Loss: 0.6867 - MER: 0.1643
# 0.1642544
# Epoch 123/200 - Training Loss: 0.6729 - MER: 0.1505
# 0.15050706
# Epoch 123/200 - Valid Loss: 0.6834 - MER: 0.1632
# 0.16320993
# Epoch 124/200 - Training Loss: 0.6635 - MER: 0.1483
# 0.14829597
# Epoch 124/200 - Valid Loss: 0.6713 - MER: 0.1553
# 0.155274
# Epoch 125/200 - Training Loss: 0.6587 - MER: 0.1465
# 0.14648834
# Epoch 125/200 - Valid Loss: 0.6982 - MER: 0.1559
# 0.15592137
# Epoch 126/200 - Training Loss: 0.6667 - MER: 0.1494
# 0.1493758
# Epoch 126/200 - Valid Loss: 0.6781 - MER: 0.1534
# 0.15344866
# Epoch 127/200 - Training Loss: 0.6635 - MER: 0.1487
# 0.14867157
# Epoch 127/200 - Valid Loss: 0.6796 - MER: 0.1588
# 0.15876454
# Epoch 128/200 - Training Loss: 0.6758 - MER: 0.1484
# 0.1484249
# Epoch 128/200 - Valid Loss: 0.6867 - MER: 0.1553
# 0.15532632
# Epoch 129/200 - Training Loss: 0.6522 - MER: 0.1498
# 0.14982241
# Epoch 129/200 - Valid Loss: 0.6794 - MER: 0.1618
# 0.16180861
# Epoch 130/200 - Training Loss: 0.6660 - MER: 0.1480
# 0.14800046
# Epoch 130/200 - Valid Loss: 0.6746 - MER: 0.1560
# 0.15603271
# Epoch 131/200 - Training Loss: 0.6716 - MER: 0.1517
# 0.15165126
# Epoch 131/200 - Valid Loss: 0.7199 - MER: 0.1631
# 0.16314267
# Epoch 132/200 - Training Loss: 0.6491 - MER: 0.1479
# 0.14792648
# Epoch 132/200 - Valid Loss: 0.6875 - MER: 0.1559
# 0.15591815
# Epoch 133/200 - Training Loss: 0.6515 - MER: 0.1467
# 0.14668407
# Epoch 133/200 - Valid Loss: 0.6826 - MER: 0.1569
# 0.15692666
# Epoch 134/200 - Training Loss: 0.6606 - MER: 0.1495
# 0.1495075
# Epoch 134/200 - Valid Loss: 0.6805 - MER: 0.1669
# 0.1668717
# Epoch 135/200 - Training Loss: 0.6643 - MER: 0.1477
# 0.14771524
# Epoch 135/200 - Valid Loss: 0.6782 - MER: 0.1579
# 0.15794146
# Epoch 136/200 - Training Loss: 0.6528 - MER: 0.1453
# 0.14526592
# Epoch 136/200 - Valid Loss: 0.6639 - MER: 0.1572
# 0.15716429
# Epoch 137/200 - Training Loss: 0.6445 - MER: 0.1516
# 0.15156099
# Epoch 137/200 - Valid Loss: 0.6724 - MER: 0.1658
# 0.16579601
# Epoch 138/200 - Training Loss: 0.6477 - MER: 0.1513
# 0.15133294
# Epoch 138/200 - Valid Loss: 0.7074 - MER: 0.1611
# 0.16109228
# Epoch 139/200 - Training Loss: 0.6572 - MER: 0.1443
# 0.14431268
# Epoch 139/200 - Valid Loss: 0.6997 - MER: 0.1583
# 0.1582715
# Epoch 140/200 - Training Loss: 0.6605 - MER: 0.1516
# 0.15160902
# Epoch 140/200 - Valid Loss: 0.6704 - MER: 0.1610
# 0.1610384
# Epoch 141/200 - Training Loss: 0.6409 - MER: 0.1471
# 0.14713809
# Epoch 141/200 - Valid Loss: 0.6709 - MER: 0.1566
# 0.1566023
# Epoch 142/200 - Training Loss: 0.6551 - MER: 0.1479
# 0.14794686
# Epoch 142/200 - Valid Loss: 0.6715 - MER: 0.1650
# 0.16498788
# Epoch 143/200 - Training Loss: 0.6601 - MER: 0.1547
# 0.1546588
# Epoch 143/200 - Valid Loss: 0.7538 - MER: 0.1621
# 0.16211635
# Epoch 144/200 - Training Loss: 0.6822 - MER: 0.1485
# 0.14849311
# Epoch 144/200 - Valid Loss: 0.6724 - MER: 0.1578
# 0.1578197
# Epoch 145/200 - Training Loss: 0.6502 - MER: 0.1459
# 0.14592779
# Epoch 145/200 - Valid Loss: 0.6647 - MER: 0.1577
# 0.15768652
# Epoch 146/200 - Training Loss: 0.6437 - MER: 0.1477
# 0.14770691
# Epoch 146/200 - Valid Loss: 0.6889 - MER: 0.1606
# 0.16058706
# Epoch 147/200 - Training Loss: 0.6446 - MER: 0.1476
# 0.14755878
# Epoch 147/200 - Valid Loss: 0.6936 - MER: 0.1600
# 0.16001256
# Epoch 148/200 - Training Loss: 0.6607 - MER: 0.1472
# 0.14715199
# Epoch 148/200 - Valid Loss: 0.6774 - MER: 0.1584
# 0.15835772
# Epoch 149/200 - Training Loss: 0.6467 - MER: 0.1503
# 0.15030932
# Epoch 149/200 - Valid Loss: 0.6999 - MER: 0.1577
# 0.15769976
# Epoch 150/200 - Training Loss: 0.6457 - MER: 0.1463
# 0.14631578
# Epoch 150/200 - Valid Loss: 0.6738 - MER: 0.1613
# 0.16132058
# Epoch 151/200 - Training Loss: 0.6593 - MER: 0.1445
# 0.14448681
# Epoch 151/200 - Valid Loss: 0.6648 - MER: 0.1529
# 0.15290539
# Epoch 152/200 - Training Loss: 0.6573 - MER: 0.1483
# 0.14832745
# Epoch 152/200 - Valid Loss: 0.6993 - MER: 0.1603
# 0.16027121
# Epoch 153/200 - Training Loss: 0.6521 - MER: 0.1478
# 0.1477823
# Epoch 153/200 - Valid Loss: 0.6926 - MER: 0.1603
# 0.1602654
# Epoch 154/200 - Training Loss: 0.6401 - MER: 0.1460
# 0.14599073
# Epoch 154/200 - Valid Loss: 0.6795 - MER: 0.1619
# 0.16189219
# Epoch 155/200 - Training Loss: 0.6515 - MER: 0.1442
# 0.14415894
# Epoch 155/200 - Valid Loss: 0.6667 - MER: 0.1572
# 0.15724364
# Epoch 156/200 - Training Loss: 0.6379 - MER: 0.1463
# 0.14634149
# Epoch 156/200 - Valid Loss: 0.6695 - MER: 0.1553
# 0.15525328
# Epoch 157/200 - Training Loss: 0.6413 - MER: 0.1444
# 0.14441743
# Epoch 157/200 - Valid Loss: 0.6743 - MER: 0.1600
# 0.15999754
# Epoch 158/200 - Training Loss: 0.6487 - MER: 0.1456
# 0.14560974
# Epoch 158/200 - Valid Loss: 0.6718 - MER: 0.1565
# 0.15649602
# Epoch 159/200 - Training Loss: 0.6355 - MER: 0.1461
# 0.14606564
# Epoch 159/200 - Valid Loss: 0.6655 - MER: 0.1613
# 0.16126487
# Epoch 160/200 - Training Loss: 0.6493 - MER: 0.1462
# 0.14623545
# Epoch 160/200 - Valid Loss: 0.6787 - MER: 0.1588
# 0.158812
# Epoch 161/200 - Training Loss: 0.6415 - MER: 0.1437
# 0.14365077
# Epoch 161/200 - Valid Loss: 0.6552 - MER: 0.1534
# 0.15344764
# Epoch 162/200 - Training Loss: 0.6430 - MER: 0.1440
# 0.14397167
# Epoch 162/200 - Valid Loss: 0.6916 - MER: 0.1607
# 0.16072445
# Epoch 163/200 - Training Loss: 0.6456 - MER: 0.1421
# 0.14210805
# Epoch 163/200 - Valid Loss: 0.6637 - MER: 0.1603
# 0.16032115
# Epoch 164/200 - Training Loss: 0.6440 - MER: 0.1440
# 0.14401513
# Epoch 164/200 - Valid Loss: 0.6693 - MER: 0.1559
# 0.15591636
# Epoch 165/200 - Training Loss: 0.6470 - MER: 0.1443
# 0.14430048
# Epoch 165/200 - Valid Loss: 0.6755 - MER: 0.1597
# 0.15971445
# Epoch 166/200 - Training Loss: 0.6402 - MER: 0.1548
# 0.15476629
# Epoch 166/200 - Valid Loss: 0.7071 - MER: 0.1661
# 0.1661494
# Epoch 167/200 - Training Loss: 0.6504 - MER: 0.1434
# 0.14344727
# Epoch 167/200 - Valid Loss: 0.6744 - MER: 0.1560
# 0.15604047
# Epoch 168/200 - Training Loss: 0.6278 - MER: 0.1449
# 0.14494595
# Epoch 168/200 - Valid Loss: 0.7025 - MER: 0.1594
# 0.15943383
# Epoch 169/200 - Training Loss: 0.6384 - MER: 0.1434
# 0.143406
# Epoch 169/200 - Valid Loss: 0.6940 - MER: 0.1549
# 0.15485857
# Epoch 170/200 - Training Loss: 0.6423 - MER: 0.1478
# 0.14783101
# Epoch 170/200 - Valid Loss: 0.6832 - MER: 0.1564
# 0.1564119
# Epoch 171/200 - Training Loss: 0.6448 - MER: 0.1493
# 0.14928578
# Epoch 171/200 - Valid Loss: 0.6815 - MER: 0.1632
# 0.1631981
# Epoch 172/200 - Training Loss: 0.6344 - MER: 0.1433
# 0.14331657
# Epoch 172/200 - Valid Loss: 0.6670 - MER: 0.1555
# 0.15553194
# Epoch 173/200 - Training Loss: 0.6573 - MER: 0.1483
# 0.14832844
# Epoch 173/200 - Valid Loss: 0.6772 - MER: 0.1668
# 0.16681217
# Epoch 174/200 - Training Loss: 0.6478 - MER: 0.1469
# 0.14691025
# Epoch 174/200 - Valid Loss: 0.6679 - MER: 0.1591
# 0.15909965
# Epoch 175/200 - Training Loss: 0.6287 - MER: 0.1438
# 0.14375807
# Epoch 175/200 - Valid Loss: 0.6596 - MER: 0.1551
# 0.15509388
# Epoch 176/200 - Training Loss: 0.6332 - MER: 0.1412
# 0.1411975
# Epoch 176/200 - Valid Loss: 0.6653 - MER: 0.1588
# 0.1588469
# Epoch 177/200 - Training Loss: 0.6329 - MER: 0.1440
# 0.14395724
# Epoch 177/200 - Valid Loss: 0.6474 - MER: 0.1558
# 0.15578972
# Epoch 178/200 - Training Loss: 0.6452 - MER: 0.1424
# 0.14244094
# Epoch 178/200 - Valid Loss: 0.6655 - MER: 0.1604
# 0.16043708
# Epoch 179/200 - Training Loss: 0.6343 - MER: 0.1414
# 0.14144018
# Epoch 179/200 - Valid Loss: 0.6662 - MER: 0.1563
# 0.15626231
# Epoch 180/200 - Training Loss: 0.6177 - MER: 0.1441
# 0.14410722
# Epoch 180/200 - Valid Loss: 0.6660 - MER: 0.1591
# 0.15907058
# Epoch 181/200 - Training Loss: 0.6309 - MER: 0.1489
# 0.14890204
# Epoch 181/200 - Valid Loss: 0.6673 - MER: 0.1607
# 0.16070582
# Epoch 182/200 - Training Loss: 0.6451 - MER: 0.1431
# 0.14308518
# Epoch 182/200 - Valid Loss: 0.6761 - MER: 0.1612
# 0.16116783
# Epoch 183/200 - Training Loss: 0.6290 - MER: 0.1461
# 0.1460822
# Epoch 183/200 - Valid Loss: 0.6991 - MER: 0.1543
# 0.1543048
# Epoch 184/200 - Training Loss: 0.6406 - MER: 0.1463
# 0.14629462
# Epoch 184/200 - Valid Loss: 0.6886 - MER: 0.1609
# 0.16091564
# Epoch 185/200 - Training Loss: 0.6536 - MER: 0.1446
# 0.14457014
# Epoch 185/200 - Valid Loss: 0.6844 - MER: 0.1583
# 0.15827648
# Epoch 186/200 - Training Loss: 0.6371 - MER: 0.1429
# 0.14288613
# Epoch 186/200 - Valid Loss: 0.6745 - MER: 0.1588
# 0.15879326
# Epoch 187/200 - Training Loss: 0.6181 - MER: 0.1471
# 0.14710912
# Epoch 187/200 - Valid Loss: 0.6716 - MER: 0.1653
# 0.16527735
# Epoch 188/200 - Training Loss: 0.6400 - MER: 0.1426
# 0.14259255
# Epoch 188/200 - Valid Loss: 0.6580 - MER: 0.1543
# 0.15434285
# Epoch 189/200 - Training Loss: 0.6120 - MER: 0.1424
# 0.14239311
# Epoch 189/200 - Valid Loss: 0.6713 - MER: 0.1535
# 0.15350647
# Epoch 190/200 - Training Loss: 0.6338 - MER: 0.1447
# 0.1446562
# Epoch 190/200 - Valid Loss: 0.6584 - MER: 0.1644
# 0.16435628
# Epoch 191/200 - Training Loss: 0.6476 - MER: 0.1416
# 0.14163336
# Epoch 191/200 - Valid Loss: 0.6645 - MER: 0.1518
# 0.15181905
# Epoch 192/200 - Training Loss: 0.6296 - MER: 0.1419
# 0.14194587
# Epoch 192/200 - Valid Loss: 0.6443 - MER: 0.1537
# 0.15373787
# Epoch 193/200 - Training Loss: 0.6197 - MER: 0.1396
# 0.13955349
# Epoch 193/200 - Valid Loss: 0.6643 - MER: 0.1564
# 0.1564157
# Epoch 194/200 - Training Loss: 0.6295 - MER: 0.1435
# 0.14347893
# Epoch 194/200 - Valid Loss: 0.6787 - MER: 0.1634
# 0.1634282
# Epoch 195/200 - Training Loss: 0.6441 - MER: 0.1457
# 0.14571372
# Epoch 195/200 - Valid Loss: 0.6771 - MER: 0.1638
# 0.16378564
# Epoch 196/200 - Training Loss: 0.6229 - MER: 0.1412
# 0.14117417
# Epoch 196/200 - Valid Loss: 0.6624 - MER: 0.1510
# 0.15097193
# Epoch 197/200 - Training Loss: 0.6168 - MER: 0.1424
# 0.14235094
# Epoch 197/200 - Valid Loss: 0.6612 - MER: 0.1580
# 0.15799806
# Epoch 198/200 - Training Loss: 0.6282 - MER: 0.1410
# 0.1409606
# Epoch 198/200 - Valid Loss: 0.6537 - MER: 0.1598
# 0.15977849
# Epoch 199/200 - Training Loss: 0.6315 - MER: 0.1417
# 0.14174092
# Epoch 199/200 - Valid Loss: 0.6633 - MER: 0.1561
# 0.15608448
# Epoch 200/200 - Training Loss: 0.6365 - MER: 0.1448
# 0.14476998
# Epoch 200/200 - Valid Loss: 0.6882 - MER: 0.1570
# 0.15704536

# %%
plt.plot(mer_values_train_MLP_4, label='Training MER')
plt.plot(mer_values_valid_MLP_4, label='Validation MER')
plt.legend(frameon=False)

# %% [markdown]
# ## Some other model variations
#
# **You're more than welcome to try some other model varations (e.g. different number of hidden layers, hidden neurons, learning rate, etc) to achieve lower valid error. Include a table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.**

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

normalization_factor=100000
train_labels = train_df['SALE_PRICE']/normalization_factor
train_df.drop('SALE_PRICE', axis=1, inplace=True)

train_ID=train_df['ID']
test_ID=test_df['ID']
train_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

features=pd.concat(objs=[train_df,test_df],axis=0)

numeric_features = features.dtypes[features.dtypes != 'object'].index
non_numeric_features = features.dtypes[features.dtypes == 'object'].index
numeric_features, non_numeric_features


features[numeric_features] = features[numeric_features].apply(lambda x: (x - x.mean()) / x.std())

# Convert non-numeric features to dummy variables
features = pd.get_dummies(features, columns=non_numeric_features)
features[numeric_features] = features[numeric_features].fillna(0)

train_features = features.iloc[:len(train_labels)]
test_features = features.iloc[len(train_labels):]
train_features.shape, test_features.shape
# Out:
# ((11581, 102), (4964, 102))

# %%
train_features = torch.tensor(train_features.values.astype(np.float32), dtype=torch.float32)
test_features = torch.tensor(test_features.values.astype(np.float32), dtype=torch.float32)
train_labels = torch.tensor(train_labels.values.reshape(-1, 1).astype(np.float32), dtype=torch.float32)

train_indices, valid_indices = train_ID, test_ID
train_features, valid_features, train_labels, valid_labels = train_test_split(train_features, train_labels, test_size=0.2, random_state=42)

train_data = TensorDataset(train_features, train_labels)
train_loader = DataLoader(train_data, batch_size=256, shuffle=True)
#TODO: create dataloader for validation data
valid_data = TensorDataset(valid_features, valid_labels)
valid_loader = DataLoader(valid_data, batch_size=256, shuffle=False)

test_data = TensorDataset(test_features)
test_loader = DataLoader(test_data, batch_size=128, shuffle=False)

# %%
model_5 = nn.Sequential(
    nn.Linear(train_features.shape[1], 64),
    nn.ReLU(),
    #nn.Dropout(0.3),
    #nn.Linear(64, 32),
    #nn.ReLU(),
    #nn.Dropout(0.3),
    nn.Linear(64, 32),
    nn.ReLU(),
    #nn.Dropout(0.3),
    nn.Linear(32, 1)
)

model_5.to(device)


criterion_MLP_5 = nn.L1Loss()

# Define the optimizer with weight decay for L2 regularization
optimizer_MLP_5 = optim.AdamW(model_5.parameters(), lr=0.001, weight_decay = 0.001)  # Adjust the weight decay value as needed


# model_5 = fc_model.Network(102, 1, [64, 32])
# model_5.to(device)
# criterion = nn.SmoothL1Loss()
# optimizer_MLP_5 = optim.Adam(model_5.parameters(), lr=0.001, weight_decay = 0.001)

epochs = 120
train_losses_MLP_5, valid_losses_MLP_5 = [], []
mer_values_train_MLP_5, mer_values_valid_MLP_5 = [], []

for e in range(epochs):
    running_train_loss = 0
    for batch_features, batch_labels in train_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        logps = model_5(batch_features)
        loss = criterion_MLP_5(logps, batch_labels)

        # Get the L2 norm of the model's parameters
        l2_reg = None
        for param in model_5.parameters():
            if l2_reg is None:
              l2_reg = param.norm(2)  # Compute the L2 norm
            else:
                l2_reg = l2_reg + param.norm(2)

        # Add the regularization term to the loss
        loss = loss + 0.001 * l2_reg  # Adjust the regularization strength (0.001 in this case)

        optimizer_MLP_5.zero_grad()
        loss.backward()
        optimizer_MLP_5.step()

        running_train_loss += loss.item()

    # Validation and other calculations remain the same as before

    else:
      running_valid_loss = 0
      with torch.no_grad():
        model_5.eval()
        for batch_features, batch_labels in valid_loader:
          batch_features = batch_features.to(device)
          batch_labels = batch_labels.to(device)

          outputs = model_5(batch_features)
          loss = criterion_MLP_5(outputs, batch_labels)
          running_valid_loss += loss.item()

      model_5.train()
      train_loss = running_train_loss/len(train_loader)
      valid_loss = running_valid_loss/len(valid_loader)
      train_losses_MLP_5.append(train_loss)
      valid_losses_MLP_5.append(valid_loss)


  # Calculate MER for this epoch and append to the list
    train_loss = running_train_loss / len(train_loader)
    train_losses_MLP_5.append(train_loss)

    valid_loss = running_valid_loss / len(valid_loader)
    valid_losses_MLP_5.append(valid_loss)

  # Calculate MER based on your code
    train_features = train_features.to(device)
    train_labels = train_labels.to(device)
    valid_features = valid_features.to(device)
    valid_labels = valid_labels.to(device)

    predicted_train = model_5(train_features).cpu().detach().numpy()
    actual_train = train_labels.cpu().numpy()
    error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
    mer_train_MLP = np.median(error_rates_train)
    mer_values_train_MLP_5.append(mer_train_MLP)

    predicted_valid = model_5(valid_features).cpu().detach().numpy()
    actual_valid = valid_labels.cpu().numpy()
    error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
    mer_valid_MLP = np.median(error_rates_valid)
    mer_values_valid_MLP_5.append(mer_valid_MLP)


    print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
    print(mer_train_MLP)
    print(f"Epoch {e + 1}/{epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid_MLP:.4f}")
    print(mer_valid_MLP)
# Out:
# Epoch 1/120 - Training Loss: 4.5744 - MER: 0.7309
# 0.7308774
# Epoch 1/120 - Valid Loss: 3.9803 - MER: 0.7299
# 0.72989655
# Epoch 2/120 - Training Loss: 2.3601 - MER: 0.2464
# 0.24636683
# Epoch 2/120 - Valid Loss: 1.5139 - MER: 0.2467
# 0.24669026
# Epoch 3/120 - Training Loss: 1.3385 - MER: 0.1667
# 0.16667235
# Epoch 3/120 - Valid Loss: 1.1828 - MER: 0.1665
# 0.16647965
# Epoch 4/120 - Training Loss: 1.1168 - MER: 0.1320
# 0.1320486
# Epoch 4/120 - Valid Loss: 1.0283 - MER: 0.1317
# 0.13172217
# Epoch 5/120 - Training Loss: 0.9842 - MER: 0.1143
# 0.11426905
# Epoch 5/120 - Valid Loss: 0.9287 - MER: 0.1154
# 0.11543821
# Epoch 6/120 - Training Loss: 0.9266 - MER: 0.1067
# 0.106745884
# Epoch 6/120 - Valid Loss: 0.8890 - MER: 0.1110
# 0.11100338
# Epoch 7/120 - Training Loss: 0.8837 - MER: 0.1016
# 0.10161969
# Epoch 7/120 - Valid Loss: 0.8643 - MER: 0.1085
# 0.10851841
# Epoch 8/120 - Training Loss: 0.8635 - MER: 0.0980
# 0.09803142
# Epoch 8/120 - Valid Loss: 0.8557 - MER: 0.1057
# 0.10569252
# Epoch 9/120 - Training Loss: 0.8549 - MER: 0.0983
# 0.09828053
# Epoch 9/120 - Valid Loss: 0.8456 - MER: 0.1048
# 0.10479683
# Epoch 10/120 - Training Loss: 0.8485 - MER: 0.0968
# 0.09677539
# Epoch 10/120 - Valid Loss: 0.8394 - MER: 0.1050
# 0.10502591
# Epoch 11/120 - Training Loss: 0.8298 - MER: 0.0982
# 0.098199755
# Epoch 11/120 - Valid Loss: 0.8339 - MER: 0.1053
# 0.105261475
# Epoch 12/120 - Training Loss: 0.8209 - MER: 0.0917
# 0.091744736
# Epoch 12/120 - Valid Loss: 0.8170 - MER: 0.0973
# 0.097255275
# Epoch 13/120 - Training Loss: 0.8234 - MER: 0.0929
# 0.09287423
# Epoch 13/120 - Valid Loss: 0.8147 - MER: 0.1015
# 0.10153215
# Epoch 14/120 - Training Loss: 0.8123 - MER: 0.0903
# 0.09032137
# Epoch 14/120 - Valid Loss: 0.8083 - MER: 0.0995
# 0.09949877
# Epoch 15/120 - Training Loss: 0.8097 - MER: 0.0905
# 0.09048326
# Epoch 15/120 - Valid Loss: 0.8032 - MER: 0.0981
# 0.098054715
# Epoch 16/120 - Training Loss: 0.8042 - MER: 0.0881
# 0.08810191
# Epoch 16/120 - Valid Loss: 0.7978 - MER: 0.0958
# 0.0958094
# Epoch 17/120 - Training Loss: 0.8050 - MER: 0.0878
# 0.08777174
# Epoch 17/120 - Valid Loss: 0.7946 - MER: 0.0970
# 0.09695482
# Epoch 18/120 - Training Loss: 0.7953 - MER: 0.0858
# 0.085823074
# Epoch 18/120 - Valid Loss: 0.7891 - MER: 0.0940
# 0.09395847
# Epoch 19/120 - Training Loss: 0.7865 - MER: 0.0859
# 0.08590005
# Epoch 19/120 - Valid Loss: 0.7880 - MER: 0.0956
# 0.0955978
# Epoch 20/120 - Training Loss: 0.7780 - MER: 0.0863
# 0.08632509
# Epoch 20/120 - Valid Loss: 0.7872 - MER: 0.0948
# 0.094786756
# Epoch 21/120 - Training Loss: 0.7758 - MER: 0.0858
# 0.08579277
# Epoch 21/120 - Valid Loss: 0.7913 - MER: 0.0945
# 0.094512366
# Epoch 22/120 - Training Loss: 0.7770 - MER: 0.0842
# 0.084215775
# Epoch 22/120 - Valid Loss: 0.7849 - MER: 0.0947
# 0.09474306
# Epoch 23/120 - Training Loss: 0.7662 - MER: 0.0844
# 0.084421545
# Epoch 23/120 - Valid Loss: 0.7767 - MER: 0.0948
# 0.09481564
# Epoch 24/120 - Training Loss: 0.7667 - MER: 0.0858
# 0.0858037
# Epoch 24/120 - Valid Loss: 0.7856 - MER: 0.0962
# 0.096160084
# Epoch 25/120 - Training Loss: 0.7598 - MER: 0.0821
# 0.08210624
# Epoch 25/120 - Valid Loss: 0.7778 - MER: 0.0931
# 0.0931371
# Epoch 26/120 - Training Loss: 0.7586 - MER: 0.0819
# 0.08192994
# Epoch 26/120 - Valid Loss: 0.7787 - MER: 0.0919
# 0.09190632
# Epoch 27/120 - Training Loss: 0.7576 - MER: 0.0808
# 0.08076744
# Epoch 27/120 - Valid Loss: 0.7726 - MER: 0.0913
# 0.09132326
# Epoch 28/120 - Training Loss: 0.7550 - MER: 0.0827
# 0.08272758
# Epoch 28/120 - Valid Loss: 0.7719 - MER: 0.0931
# 0.09312967
# Epoch 29/120 - Training Loss: 0.7572 - MER: 0.0809
# 0.08090461
# Epoch 29/120 - Valid Loss: 0.7708 - MER: 0.0911
# 0.09109222
# Epoch 30/120 - Training Loss: 0.7491 - MER: 0.0789
# 0.078900784
# Epoch 30/120 - Valid Loss: 0.7672 - MER: 0.0887
# 0.08869405
# Epoch 31/120 - Training Loss: 0.7429 - MER: 0.0811
# 0.081115566
# Epoch 31/120 - Valid Loss: 0.7738 - MER: 0.0933
# 0.09327969
# Epoch 32/120 - Training Loss: 0.7419 - MER: 0.0832
# 0.08318159
# Epoch 32/120 - Valid Loss: 0.7890 - MER: 0.0946
# 0.09460266
# Epoch 33/120 - Training Loss: 0.7429 - MER: 0.0775
# 0.07754858
# Epoch 33/120 - Valid Loss: 0.7687 - MER: 0.0903
# 0.09034278
# Epoch 34/120 - Training Loss: 0.7374 - MER: 0.0772
# 0.07724711
# Epoch 34/120 - Valid Loss: 0.7719 - MER: 0.0879
# 0.08790677
# Epoch 35/120 - Training Loss: 0.7353 - MER: 0.0773
# 0.077344194
# Epoch 35/120 - Valid Loss: 0.7680 - MER: 0.0895
# 0.089487664
# Epoch 36/120 - Training Loss: 0.7320 - MER: 0.0794
# 0.07941556
# Epoch 36/120 - Valid Loss: 0.7695 - MER: 0.0930
# 0.09296316
# Epoch 37/120 - Training Loss: 0.7345 - MER: 0.0795
# 0.07948004
# Epoch 37/120 - Valid Loss: 0.7653 - MER: 0.0914
# 0.09138761
# Epoch 38/120 - Training Loss: 0.7331 - MER: 0.0760
# 0.07603866
# Epoch 38/120 - Valid Loss: 0.7725 - MER: 0.0887
# 0.088653564
# Epoch 39/120 - Training Loss: 0.7296 - MER: 0.0757
# 0.075685926
# Epoch 39/120 - Valid Loss: 0.7652 - MER: 0.0891
# 0.08914828
# Epoch 40/120 - Training Loss: 0.7283 - MER: 0.0758
# 0.07578669
# Epoch 40/120 - Valid Loss: 0.7658 - MER: 0.0879
# 0.08785848
# Epoch 41/120 - Training Loss: 0.7285 - MER: 0.0741
# 0.074108385
# Epoch 41/120 - Valid Loss: 0.7628 - MER: 0.0870
# 0.08698077
# Epoch 42/120 - Training Loss: 0.7200 - MER: 0.0765
# 0.07652713
# Epoch 42/120 - Valid Loss: 0.7743 - MER: 0.0890
# 0.089011
# Epoch 43/120 - Training Loss: 0.7228 - MER: 0.0776
# 0.07760923
# Epoch 43/120 - Valid Loss: 0.7635 - MER: 0.0915
# 0.09153956
# Epoch 44/120 - Training Loss: 0.7223 - MER: 0.0757
# 0.07566065
# Epoch 44/120 - Valid Loss: 0.7723 - MER: 0.0891
# 0.089146405
# Epoch 45/120 - Training Loss: 0.7122 - MER: 0.0781
# 0.078066334
# Epoch 45/120 - Valid Loss: 0.7599 - MER: 0.0904
# 0.090363316
# Epoch 46/120 - Training Loss: 0.7212 - MER: 0.0769
# 0.076860785
# Epoch 46/120 - Valid Loss: 0.7761 - MER: 0.0909
# 0.09093292
# Epoch 47/120 - Training Loss: 0.7116 - MER: 0.0769
# 0.07688605
# Epoch 47/120 - Valid Loss: 0.7683 - MER: 0.0909
# 0.0908947
# Epoch 48/120 - Training Loss: 0.7097 - MER: 0.0718
# 0.071767725
# Epoch 48/120 - Valid Loss: 0.7626 - MER: 0.0863
# 0.08626526
# Epoch 49/120 - Training Loss: 0.7114 - MER: 0.0736
# 0.07360703
# Epoch 49/120 - Valid Loss: 0.7570 - MER: 0.0855
# 0.08551586
# Epoch 50/120 - Training Loss: 0.7131 - MER: 0.0713
# 0.07130725
# Epoch 50/120 - Valid Loss: 0.7599 - MER: 0.0849
# 0.08487197
# Epoch 51/120 - Training Loss: 0.7122 - MER: 0.0759
# 0.07588394
# Epoch 51/120 - Valid Loss: 0.7673 - MER: 0.0903
# 0.090294205
# Epoch 52/120 - Training Loss: 0.7011 - MER: 0.0719
# 0.07185604
# Epoch 52/120 - Valid Loss: 0.7638 - MER: 0.0869
# 0.08693082
# Epoch 53/120 - Training Loss: 0.7099 - MER: 0.0745
# 0.074486
# Epoch 53/120 - Valid Loss: 0.7833 - MER: 0.0909
# 0.09093824
# Epoch 54/120 - Training Loss: 0.7028 - MER: 0.0713
# 0.0712786
# Epoch 54/120 - Valid Loss: 0.7704 - MER: 0.0885
# 0.088544995
# Epoch 55/120 - Training Loss: 0.6913 - MER: 0.0706
# 0.07064287
# Epoch 55/120 - Valid Loss: 0.7571 - MER: 0.0875
# 0.08748922
# Epoch 56/120 - Training Loss: 0.6936 - MER: 0.0748
# 0.07475908
# Epoch 56/120 - Valid Loss: 0.7640 - MER: 0.0916
# 0.091578744
# Epoch 57/120 - Training Loss: 0.6889 - MER: 0.0694
# 0.06937362
# Epoch 57/120 - Valid Loss: 0.7547 - MER: 0.0859
# 0.085947916
# Epoch 58/120 - Training Loss: 0.6883 - MER: 0.0690
# 0.0690162
# Epoch 58/120 - Valid Loss: 0.7567 - MER: 0.0844
# 0.084413275
# Epoch 59/120 - Training Loss: 0.6964 - MER: 0.0755
# 0.07554959
# Epoch 59/120 - Valid Loss: 0.7842 - MER: 0.0881
# 0.08811752
# Epoch 60/120 - Training Loss: 0.6981 - MER: 0.0720
# 0.07204228
# Epoch 60/120 - Valid Loss: 0.7773 - MER: 0.0870
# 0.08702574
# Epoch 61/120 - Training Loss: 0.7015 - MER: 0.0686
# 0.068604484
# Epoch 61/120 - Valid Loss: 0.7701 - MER: 0.0858
# 0.08578387
# Epoch 62/120 - Training Loss: 0.6861 - MER: 0.0717
# 0.07174711
# Epoch 62/120 - Valid Loss: 0.7653 - MER: 0.0880
# 0.087983586
# Epoch 63/120 - Training Loss: 0.6839 - MER: 0.0698
# 0.06983961
# Epoch 63/120 - Valid Loss: 0.7565 - MER: 0.0840
# 0.084039606
# Epoch 64/120 - Training Loss: 0.6829 - MER: 0.0706
# 0.070643805
# Epoch 64/120 - Valid Loss: 0.7668 - MER: 0.0874
# 0.08739387
# Epoch 65/120 - Training Loss: 0.6792 - MER: 0.0691
# 0.06908503
# Epoch 65/120 - Valid Loss: 0.7662 - MER: 0.0862
# 0.08616496
# Epoch 66/120 - Training Loss: 0.6798 - MER: 0.0692
# 0.069237255
# Epoch 66/120 - Valid Loss: 0.7534 - MER: 0.0851
# 0.085102946
# Epoch 67/120 - Training Loss: 0.6811 - MER: 0.0693
# 0.069253325
# Epoch 67/120 - Valid Loss: 0.7533 - MER: 0.0867
# 0.08668682
# Epoch 68/120 - Training Loss: 0.6773 - MER: 0.0674
# 0.0674101
# Epoch 68/120 - Valid Loss: 0.7457 - MER: 0.0833
# 0.08334953
# Epoch 69/120 - Training Loss: 0.6752 - MER: 0.0695
# 0.06945517
# Epoch 69/120 - Valid Loss: 0.7565 - MER: 0.0864
# 0.08641794
# Epoch 70/120 - Training Loss: 0.6769 - MER: 0.0678
# 0.067805246
# Epoch 70/120 - Valid Loss: 0.7538 - MER: 0.0861
# 0.086106926
# Epoch 71/120 - Training Loss: 0.6689 - MER: 0.0679
# 0.06786889
# Epoch 71/120 - Valid Loss: 0.7586 - MER: 0.0863
# 0.08628932
# Epoch 72/120 - Training Loss: 0.6703 - MER: 0.0679
# 0.0679145
# Epoch 72/120 - Valid Loss: 0.7477 - MER: 0.0867
# 0.08673904
# Epoch 73/120 - Training Loss: 0.6715 - MER: 0.0658
# 0.065812625
# Epoch 73/120 - Valid Loss: 0.7511 - MER: 0.0831
# 0.083107926
# Epoch 74/120 - Training Loss: 0.6636 - MER: 0.0656
# 0.06559598
# Epoch 74/120 - Valid Loss: 0.7485 - MER: 0.0852
# 0.08516255
# Epoch 75/120 - Training Loss: 0.6690 - MER: 0.0657
# 0.065712154
# Epoch 75/120 - Valid Loss: 0.7471 - MER: 0.0833
# 0.083269775
# Epoch 76/120 - Training Loss: 0.6614 - MER: 0.0674
# 0.06735034
# Epoch 76/120 - Valid Loss: 0.7490 - MER: 0.0843
# 0.08429227
# Epoch 77/120 - Training Loss: 0.6653 - MER: 0.0654
# 0.0654124
# Epoch 77/120 - Valid Loss: 0.7516 - MER: 0.0863
# 0.08630898
# Epoch 78/120 - Training Loss: 0.6664 - MER: 0.0655
# 0.06549125
# Epoch 78/120 - Valid Loss: 0.7559 - MER: 0.0841
# 0.0841015
# Epoch 79/120 - Training Loss: 0.6685 - MER: 0.0647
# 0.064680114
# Epoch 79/120 - Valid Loss: 0.7539 - MER: 0.0845
# 0.084464625
# Epoch 80/120 - Training Loss: 0.6597 - MER: 0.0675
# 0.067492366
# Epoch 80/120 - Valid Loss: 0.7628 - MER: 0.0880
# 0.088016815
# Epoch 81/120 - Training Loss: 0.6567 - MER: 0.0658
# 0.065791935
# Epoch 81/120 - Valid Loss: 0.7552 - MER: 0.0850
# 0.084950104
# Epoch 82/120 - Training Loss: 0.6628 - MER: 0.0645
# 0.06445021
# Epoch 82/120 - Valid Loss: 0.7498 - MER: 0.0842
# 0.08419344
# Epoch 83/120 - Training Loss: 0.6504 - MER: 0.0645
# 0.064504355
# Epoch 83/120 - Valid Loss: 0.7506 - MER: 0.0835
# 0.08354726
# Epoch 84/120 - Training Loss: 0.6588 - MER: 0.0669
# 0.06688992
# Epoch 84/120 - Valid Loss: 0.7512 - MER: 0.0862
# 0.08619184
# Epoch 85/120 - Training Loss: 0.6560 - MER: 0.0651
# 0.06510742
# Epoch 85/120 - Valid Loss: 0.7486 - MER: 0.0869
# 0.08689481
# Epoch 86/120 - Training Loss: 0.6548 - MER: 0.0648
# 0.064800926
# Epoch 86/120 - Valid Loss: 0.7469 - MER: 0.0854
# 0.08544695
# Epoch 87/120 - Training Loss: 0.6540 - MER: 0.0653
# 0.06534555
# Epoch 87/120 - Valid Loss: 0.7507 - MER: 0.0865
# 0.086496875
# Epoch 88/120 - Training Loss: 0.6451 - MER: 0.0641
# 0.06411944
# Epoch 88/120 - Valid Loss: 0.7511 - MER: 0.0846
# 0.08461513
# Epoch 89/120 - Training Loss: 0.6481 - MER: 0.0621
# 0.06210818
# Epoch 89/120 - Valid Loss: 0.7502 - MER: 0.0841
# 0.08414011
# Epoch 90/120 - Training Loss: 0.6559 - MER: 0.0620
# 0.061962694
# Epoch 90/120 - Valid Loss: 0.7507 - MER: 0.0838
# 0.08380813
# Epoch 91/120 - Training Loss: 0.6408 - MER: 0.0627
# 0.06268908
# Epoch 91/120 - Valid Loss: 0.7490 - MER: 0.0851
# 0.085075475
# Epoch 92/120 - Training Loss: 0.6431 - MER: 0.0634
# 0.06341268
# Epoch 92/120 - Valid Loss: 0.7542 - MER: 0.0849
# 0.08486561
# Epoch 93/120 - Training Loss: 0.6409 - MER: 0.0622
# 0.06215439
# Epoch 93/120 - Valid Loss: 0.7460 - MER: 0.0844
# 0.08435089
# Epoch 94/120 - Training Loss: 0.6396 - MER: 0.0640
# 0.064029604
# Epoch 94/120 - Valid Loss: 0.7490 - MER: 0.0839
# 0.08391866
# Epoch 95/120 - Training Loss: 0.6420 - MER: 0.0619
# 0.061928306
# Epoch 95/120 - Valid Loss: 0.7526 - MER: 0.0842
# 0.0841838
# Epoch 96/120 - Training Loss: 0.6370 - MER: 0.0606
# 0.06056119
# Epoch 96/120 - Valid Loss: 0.7444 - MER: 0.0833
# 0.083271585
# Epoch 97/120 - Training Loss: 0.6275 - MER: 0.0596
# 0.059553836
# Epoch 97/120 - Valid Loss: 0.7467 - MER: 0.0831
# 0.08311291
# Epoch 98/120 - Training Loss: 0.6369 - MER: 0.0605
# 0.06054073
# Epoch 98/120 - Valid Loss: 0.7490 - MER: 0.0846
# 0.08464243
# Epoch 99/120 - Training Loss: 0.6299 - MER: 0.0598
# 0.059797287
# Epoch 99/120 - Valid Loss: 0.7430 - MER: 0.0849
# 0.08486173
# Epoch 100/120 - Training Loss: 0.6267 - MER: 0.0624
# 0.062434856
# Epoch 100/120 - Valid Loss: 0.7449 - MER: 0.0846
# 0.08456488
# Epoch 101/120 - Training Loss: 0.6305 - MER: 0.0608
# 0.060808394
# Epoch 101/120 - Valid Loss: 0.7426 - MER: 0.0855
# 0.085521154
# Epoch 102/120 - Training Loss: 0.6301 - MER: 0.0589
# 0.05888198
# Epoch 102/120 - Valid Loss: 0.7439 - MER: 0.0833
# 0.083336964
# Epoch 103/120 - Training Loss: 0.6284 - MER: 0.0599
# 0.059937533
# Epoch 103/120 - Valid Loss: 0.7466 - MER: 0.0837
# 0.0837053
# Epoch 104/120 - Training Loss: 0.6235 - MER: 0.0610
# 0.061015777
# Epoch 104/120 - Valid Loss: 0.7418 - MER: 0.0828
# 0.082772665
# Epoch 105/120 - Training Loss: 0.6302 - MER: 0.0605
# 0.06050086
# Epoch 105/120 - Valid Loss: 0.7441 - MER: 0.0839
# 0.08385145
# Epoch 106/120 - Training Loss: 0.6256 - MER: 0.0588
# 0.058817856
# Epoch 106/120 - Valid Loss: 0.7392 - MER: 0.0840
# 0.08397665
# Epoch 107/120 - Training Loss: 0.6205 - MER: 0.0587
# 0.05867807
# Epoch 107/120 - Valid Loss: 0.7405 - MER: 0.0839
# 0.0839448
# Epoch 108/120 - Training Loss: 0.6269 - MER: 0.0622
# 0.062186748
# Epoch 108/120 - Valid Loss: 0.7454 - MER: 0.0862
# 0.08616521
# Epoch 109/120 - Training Loss: 0.6163 - MER: 0.0605
# 0.06052898
# Epoch 109/120 - Valid Loss: 0.7475 - MER: 0.0849
# 0.08485497
# Epoch 110/120 - Training Loss: 0.6196 - MER: 0.0619
# 0.061916634
# Epoch 110/120 - Valid Loss: 0.7412 - MER: 0.0869
# 0.086911045
# Epoch 111/120 - Training Loss: 0.6229 - MER: 0.0588
# 0.058828995
# Epoch 111/120 - Valid Loss: 0.7462 - MER: 0.0858
# 0.0857685
# Epoch 112/120 - Training Loss: 0.6248 - MER: 0.0619
# 0.061864145
# Epoch 112/120 - Valid Loss: 0.7442 - MER: 0.0866
# 0.08655067
# Epoch 113/120 - Training Loss: 0.6164 - MER: 0.0585
# 0.058468975
# Epoch 113/120 - Valid Loss: 0.7559 - MER: 0.0839
# 0.08390981
# Epoch 114/120 - Training Loss: 0.6149 - MER: 0.0608
# 0.06082971
# Epoch 114/120 - Valid Loss: 0.7469 - MER: 0.0856
# 0.085603215
# Epoch 115/120 - Training Loss: 0.6193 - MER: 0.0565
# 0.056505576
# Epoch 115/120 - Valid Loss: 0.7468 - MER: 0.0829
# 0.082923315
# Epoch 116/120 - Training Loss: 0.6095 - MER: 0.0575
# 0.057537746
# Epoch 116/120 - Valid Loss: 0.7424 - MER: 0.0834
# 0.083380215
# Epoch 117/120 - Training Loss: 0.6153 - MER: 0.0579
# 0.05789382
# Epoch 117/120 - Valid Loss: 0.7443 - MER: 0.0833
# 0.083275154
# Epoch 118/120 - Training Loss: 0.6130 - MER: 0.0586
# 0.05859042
# Epoch 118/120 - Valid Loss: 0.7420 - MER: 0.0836
# 0.08358934
# Epoch 119/120 - Training Loss: 0.6157 - MER: 0.0605
# 0.060495205
# Epoch 119/120 - Valid Loss: 0.7486 - MER: 0.0865
# 0.08652079
# Epoch 120/120 - Training Loss: 0.6097 - MER: 0.0572
# 0.057154037
# Epoch 120/120 - Valid Loss: 0.7508 - MER: 0.0847
# 0.08467432

# %%
plt.plot(mer_values_train_MLP_5, label='Training MER')
plt.plot(mer_values_valid_MLP_5, label='Validation MER')
plt.legend(frameon=False)

# %%
whole_features = torch.cat((train_features, valid_features), dim=0)
whole_labels = torch.cat((train_labels, valid_labels), dim=0)

whole_data = TensorDataset(whole_features, whole_labels)

whole_loader = DataLoader(whole_data, batch_size=256, shuffle=True)

# %%
final_model = nn.Sequential(
    nn.Linear(train_features.shape[1], 32),
    nn.ReLU(),
    nn.Linear(32, 16),
    nn.ReLU(),
    nn.Linear(16, 1)
)

final_model.to(device)


criterion = nn.L1Loss()

# Define the optimizer with weight decay for L2 regularization
optimizer = optim.AdamW(final_model.parameters(), lr=0.001, weight_decay = 0.001)  # Adjust the weight decay value as needed

epochs = 120
train_losses_MLP = []
mer_values_MLP = []

for e in range(epochs):
    running_train_loss = 0
    for batch_features, batch_labels in whole_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        logps = final_model(batch_features)
        loss = criterion(logps, batch_labels)

        # Get the L2 norm of the model's parameters
        l2_reg = None
        for param in final_model.parameters():
            if l2_reg is None:
              l2_reg = param.norm(2)  # Compute the L2 norm
            else:
                l2_reg = l2_reg + param.norm(2)

        # Add the regularization term to the loss
        loss = loss + 0.001 * l2_reg  # Adjust the regularization strength (0.001 in this case)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

    else:

      train_loss = running_train_loss/len(whole_loader)
      train_losses_MLP.append(train_loss)
      print(f"Training loss: {train_loss}")

  # Calculate MER based on your code
    whole_features = whole_features.to(device)
    whole_labels = whole_labels.to(device)

    predicted_train = final_model(whole_features).cpu().detach().numpy()
    actual_train = whole_labels.cpu().numpy()
    error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
    mer_train_MLP = np.median(error_rates_train)
    mer_values_MLP.append(mer_train_MLP)


    print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
    print(mer_train_MLP)
# Out:
# Training loss: 5.0718858034714405
# Epoch 1/120 - Training Loss: 5.0719 - MER: 0.9673
# 0.9673102
# Training loss: 4.042873159698818
# Epoch 2/120 - Training Loss: 4.0429 - MER: 0.5282
# 0.5281982
# Training loss: 1.8973710925682732
# Epoch 3/120 - Training Loss: 1.8974 - MER: 0.2115
# 0.21153255
# Training loss: 1.278266966342926
# Epoch 4/120 - Training Loss: 1.2783 - MER: 0.1555
# 0.1555446
# Training loss: 1.0845728361088296
# Epoch 5/120 - Training Loss: 1.0846 - MER: 0.1267
# 0.12666327
# Training loss: 0.9738765216392019
# Epoch 6/120 - Training Loss: 0.9739 - MER: 0.1153
# 0.11530965
# Training loss: 0.9303990537705629
# Epoch 7/120 - Training Loss: 0.9304 - MER: 0.1092
# 0.10922094
# Training loss: 0.9033351721970931
# Epoch 8/120 - Training Loss: 0.9033 - MER: 0.1038
# 0.103831485
# Training loss: 0.8698810455591782
# Epoch 9/120 - Training Loss: 0.8699 - MER: 0.0994
# 0.099365346
# Training loss: 0.8545324841271276
# Epoch 10/120 - Training Loss: 0.8545 - MER: 0.0994
# 0.09944484
# Training loss: 0.847793443047482
# Epoch 11/120 - Training Loss: 0.8478 - MER: 0.0957
# 0.09565959
# Training loss: 0.8379861647668092
# Epoch 12/120 - Training Loss: 0.8380 - MER: 0.0950
# 0.095014304
# Training loss: 0.8279562190822933
# Epoch 13/120 - Training Loss: 0.8280 - MER: 0.0941
# 0.09410425
# Training loss: 0.8307012928568799
# Epoch 14/120 - Training Loss: 0.8307 - MER: 0.0929
# 0.0929114
# Training loss: 0.821792923885843
# Epoch 15/120 - Training Loss: 0.8218 - MER: 0.0908
# 0.090840735
# Training loss: 0.8144035430058189
# Epoch 16/120 - Training Loss: 0.8144 - MER: 0.0907
# 0.090683766
# Training loss: 0.8134800558504851
# Epoch 17/120 - Training Loss: 0.8135 - MER: 0.0913
# 0.09134686
# Training loss: 0.8105994411136793
# Epoch 18/120 - Training Loss: 0.8106 - MER: 0.0883
# 0.08833769
# Training loss: 0.7993077285911726
# Epoch 19/120 - Training Loss: 0.7993 - MER: 0.0875
# 0.087466374
# Training loss: 0.8060862434946973
# Epoch 20/120 - Training Loss: 0.8061 - MER: 0.0865
# 0.086539
# Training loss: 0.7950239946012911
# Epoch 21/120 - Training Loss: 0.7950 - MER: 0.0887
# 0.088699184
# Training loss: 0.7941183344177578
# Epoch 22/120 - Training Loss: 0.7941 - MER: 0.0874
# 0.08744172
# Training loss: 0.7926915922890538
# Epoch 23/120 - Training Loss: 0.7927 - MER: 0.0850
# 0.085044526
# Training loss: 0.7943640973256982
# Epoch 24/120 - Training Loss: 0.7944 - MER: 0.0854
# 0.08535254
# Training loss: 0.787694548783095
# Epoch 25/120 - Training Loss: 0.7877 - MER: 0.0829
# 0.08293278
# Training loss: 0.7828453040641287
# Epoch 26/120 - Training Loss: 0.7828 - MER: 0.0836
# 0.08363639
# Training loss: 0.7841179293134938
# Epoch 27/120 - Training Loss: 0.7841 - MER: 0.0842
# 0.084184855
# Training loss: 0.777510518613069
# Epoch 28/120 - Training Loss: 0.7775 - MER: 0.0835
# 0.083507895
# Training loss: 0.7785203716029292
# Epoch 29/120 - Training Loss: 0.7785 - MER: 0.0843
# 0.0843097
# Training loss: 0.7771983613138613
# Epoch 30/120 - Training Loss: 0.7772 - MER: 0.0850
# 0.08498425
# Training loss: 0.7792999614839968
# Epoch 31/120 - Training Loss: 0.7793 - MER: 0.0833
# 0.08334258
# Training loss: 0.7723773212536521
# Epoch 32/120 - Training Loss: 0.7724 - MER: 0.0808
# 0.08082403
# Training loss: 0.7732826432456141
# Epoch 33/120 - Training Loss: 0.7733 - MER: 0.0832
# 0.08322766
# Training loss: 0.7651938510977704
# Epoch 34/120 - Training Loss: 0.7652 - MER: 0.0828
# 0.082803175
# Training loss: 0.7683271454728168
# Epoch 35/120 - Training Loss: 0.7683 - MER: 0.0821
# 0.082110524
# Training loss: 0.7664774086164392
# Epoch 36/120 - Training Loss: 0.7665 - MER: 0.0804
# 0.08038473
# Training loss: 0.7625319711540056
# Epoch 37/120 - Training Loss: 0.7625 - MER: 0.0806
# 0.08058086
# Training loss: 0.7600446317506873
# Epoch 38/120 - Training Loss: 0.7600 - MER: 0.0792
# 0.079225235
# Training loss: 0.7642128441644751
# Epoch 39/120 - Training Loss: 0.7642 - MER: 0.0806
# 0.08057687
# Training loss: 0.7593401165112205
# Epoch 40/120 - Training Loss: 0.7593 - MER: 0.0810
# 0.08098387
# Training loss: 0.76248968684155
# Epoch 41/120 - Training Loss: 0.7625 - MER: 0.0812
# 0.08122671
# Training loss: 0.7573486294435419
# Epoch 42/120 - Training Loss: 0.7573 - MER: 0.0801
# 0.0800708
# Training loss: 0.751595165418542
# Epoch 43/120 - Training Loss: 0.7516 - MER: 0.0807
# 0.08072526
# Training loss: 0.7541611246440721
# Epoch 44/120 - Training Loss: 0.7542 - MER: 0.0788
# 0.07883824
# Training loss: 0.7518403491248256
# Epoch 45/120 - Training Loss: 0.7518 - MER: 0.0784
# 0.07836853
# Training loss: 0.7506243586540222
# Epoch 46/120 - Training Loss: 0.7506 - MER: 0.0790
# 0.079033375
# Training loss: 0.7520592264507128
# Epoch 47/120 - Training Loss: 0.7521 - MER: 0.0789
# 0.07890165
# Training loss: 0.7411471436852994
# Epoch 48/120 - Training Loss: 0.7411 - MER: 0.0774
# 0.07739553
# Training loss: 0.7430686717448027
# Epoch 49/120 - Training Loss: 0.7431 - MER: 0.0774
# 0.07742873
# Training loss: 0.7480926941270414
# Epoch 50/120 - Training Loss: 0.7481 - MER: 0.0771
# 0.07709682
# Training loss: 0.7420805109583813
# Epoch 51/120 - Training Loss: 0.7421 - MER: 0.0764
# 0.076420836
# Training loss: 0.7417126116545304
# Epoch 52/120 - Training Loss: 0.7417 - MER: 0.0769
# 0.0769475
# Training loss: 0.742388155149377
# Epoch 53/120 - Training Loss: 0.7424 - MER: 0.0759
# 0.07588757
# Training loss: 0.7436350804308186
# Epoch 54/120 - Training Loss: 0.7436 - MER: 0.0767
# 0.07670904
# Training loss: 0.7392378566057786
# Epoch 55/120 - Training Loss: 0.7392 - MER: 0.0766
# 0.076602295
# Training loss: 0.7404242974260579
# Epoch 56/120 - Training Loss: 0.7404 - MER: 0.0767
# 0.07668643
# Training loss: 0.732651860817619
# Epoch 57/120 - Training Loss: 0.7327 - MER: 0.0755
# 0.07547606
# Training loss: 0.7327487216047619
# Epoch 58/120 - Training Loss: 0.7327 - MER: 0.0777
# 0.07772939
# Training loss: 0.7302294101404108
# Epoch 59/120 - Training Loss: 0.7302 - MER: 0.0754
# 0.07544384
# Training loss: 0.7318190128906913
# Epoch 60/120 - Training Loss: 0.7318 - MER: 0.0768
# 0.07683478
# Training loss: 0.7341960564903591
# Epoch 61/120 - Training Loss: 0.7342 - MER: 0.0754
# 0.075438514
# Training loss: 0.7259215997612994
# Epoch 62/120 - Training Loss: 0.7259 - MER: 0.0747
# 0.074672595
# Training loss: 0.7317400043425353
# Epoch 63/120 - Training Loss: 0.7317 - MER: 0.0756
# 0.07564175
# Training loss: 0.7250042700249216
# Epoch 64/120 - Training Loss: 0.7250 - MER: 0.0763
# 0.07625078
# Training loss: 0.7298691609631414
# Epoch 65/120 - Training Loss: 0.7299 - MER: 0.0740
# 0.073984504
# Training loss: 0.726173091193904
# Epoch 66/120 - Training Loss: 0.7262 - MER: 0.0758
# 0.075800896
# Training loss: 0.7223827877770299
# Epoch 67/120 - Training Loss: 0.7224 - MER: 0.0747
# 0.07468104
# Training loss: 0.7248575026574342
# Epoch 68/120 - Training Loss: 0.7249 - MER: 0.0766
# 0.076570496
# Training loss: 0.7223318452420442
# Epoch 69/120 - Training Loss: 0.7223 - MER: 0.0754
# 0.0753808
# Training loss: 0.7229231077691783
# Epoch 70/120 - Training Loss: 0.7229 - MER: 0.0744
# 0.07436725
# Training loss: 0.7192281406858693
# Epoch 71/120 - Training Loss: 0.7192 - MER: 0.0743
# 0.0743244
# Training loss: 0.7177740063356317
# Epoch 72/120 - Training Loss: 0.7178 - MER: 0.0741
# 0.07411724
# Training loss: 0.7172376889249553
# Epoch 73/120 - Training Loss: 0.7172 - MER: 0.0727
# 0.07265661
# Training loss: 0.7130001796328503
# Epoch 74/120 - Training Loss: 0.7130 - MER: 0.0737
# 0.07368151
# Training loss: 0.7127608954906464
# Epoch 75/120 - Training Loss: 0.7128 - MER: 0.0740
# 0.073992945
# Training loss: 0.7163560403429944
# Epoch 76/120 - Training Loss: 0.7164 - MER: 0.0735
# 0.07347497
# Training loss: 0.71138937836108
# Epoch 77/120 - Training Loss: 0.7114 - MER: 0.0761
# 0.07607925
# Training loss: 0.7129232611345209
# Epoch 78/120 - Training Loss: 0.7129 - MER: 0.0736
# 0.07355372
# Training loss: 0.7136998863323875
# Epoch 79/120 - Training Loss: 0.7137 - MER: 0.0755
# 0.0755083
# Training loss: 0.7099517920742864
# Epoch 80/120 - Training Loss: 0.7100 - MER: 0.0725
# 0.07245226
# Training loss: 0.710632913786432
# Epoch 81/120 - Training Loss: 0.7106 - MER: 0.0729
# 0.07287126
# Training loss: 0.7100585712038953
# Epoch 82/120 - Training Loss: 0.7101 - MER: 0.0736
# 0.07358482
# Training loss: 0.7097457504790762
# Epoch 83/120 - Training Loss: 0.7097 - MER: 0.0755
# 0.07547889
# Training loss: 0.7121482724728792
# Epoch 84/120 - Training Loss: 0.7121 - MER: 0.0739
# 0.07390307
# Training loss: 0.7055814641973247
# Epoch 85/120 - Training Loss: 0.7056 - MER: 0.0728
# 0.07275799
# Training loss: 0.7019725623338119
# Epoch 86/120 - Training Loss: 0.7020 - MER: 0.0763
# 0.076289624
# Training loss: 0.7032348785711371
# Epoch 87/120 - Training Loss: 0.7032 - MER: 0.0723
# 0.07233605
# Training loss: 0.7074704701485841
# Epoch 88/120 - Training Loss: 0.7075 - MER: 0.0721
# 0.07211696
# Training loss: 0.7033764059128969
# Epoch 89/120 - Training Loss: 0.7034 - MER: 0.0714
# 0.07140321
# Training loss: 0.7077553946038951
# Epoch 90/120 - Training Loss: 0.7078 - MER: 0.0723
# 0.072310105
# Training loss: 0.6982552059318708
# Epoch 91/120 - Training Loss: 0.6983 - MER: 0.0721
# 0.072137974
# Training loss: 0.7026020029316777
# Epoch 92/120 - Training Loss: 0.7026 - MER: 0.0735
# 0.07349606
# Training loss: 0.7020765672559324
# Epoch 93/120 - Training Loss: 0.7021 - MER: 0.0713
# 0.07134925
# Training loss: 0.6987322594808496
# Epoch 94/120 - Training Loss: 0.6987 - MER: 0.0706
# 0.07059531
# Training loss: 0.6968969845253489
# Epoch 95/120 - Training Loss: 0.6969 - MER: 0.0720
# 0.072014436
# Training loss: 0.6969019783579785
# Epoch 96/120 - Training Loss: 0.6969 - MER: 0.0715
# 0.07152645
# Training loss: 0.6974881680115409
# Epoch 97/120 - Training Loss: 0.6975 - MER: 0.0735
# 0.07349764
# Training loss: 0.6945358696191207
# Epoch 98/120 - Training Loss: 0.6945 - MER: 0.0725
# 0.07252606
# Training loss: 0.694324923598248
# Epoch 99/120 - Training Loss: 0.6943 - MER: 0.0715
# 0.07149965
# Training loss: 0.6963089199169822
# Epoch 100/120 - Training Loss: 0.6963 - MER: 0.0708
# 0.070781216
# Training loss: 0.6950716467007346
# Epoch 101/120 - Training Loss: 0.6951 - MER: 0.0705
# 0.070480056
# Training loss: 0.693397572507029
# Epoch 102/120 - Training Loss: 0.6934 - MER: 0.0708
# 0.07076508
# Training loss: 0.6943993970103886
# Epoch 103/120 - Training Loss: 0.6944 - MER: 0.0710
# 0.070993446
# Training loss: 0.6923078531804292
# Epoch 104/120 - Training Loss: 0.6923 - MER: 0.0701
# 0.07013903
# Training loss: 0.6898524346558944
# Epoch 105/120 - Training Loss: 0.6899 - MER: 0.0714
# 0.07143509
# Training loss: 0.689523335384286
# Epoch 106/120 - Training Loss: 0.6895 - MER: 0.0715
# 0.07151816
# Training loss: 0.6932925854040228
# Epoch 107/120 - Training Loss: 0.6933 - MER: 0.0726
# 0.07261042
# Training loss: 0.6932350254577139
# Epoch 108/120 - Training Loss: 0.6932 - MER: 0.0697
# 0.06966129
# Training loss: 0.688559168058893
# Epoch 109/120 - Training Loss: 0.6886 - MER: 0.0710
# 0.071020335
# Training loss: 0.6852448245753413
# Epoch 110/120 - Training Loss: 0.6852 - MER: 0.0720
# 0.07200601
# Training loss: 0.6881357988585597
# Epoch 111/120 - Training Loss: 0.6881 - MER: 0.0717
# 0.07169336
# Training loss: 0.689524751642476
# Epoch 112/120 - Training Loss: 0.6895 - MER: 0.0726
# 0.07260912
# Training loss: 0.6867894595083983
# Epoch 113/120 - Training Loss: 0.6868 - MER: 0.0706
# 0.07055401
# Training loss: 0.6878409826237223
# Epoch 114/120 - Training Loss: 0.6878 - MER: 0.0720
# 0.072009936
# Training loss: 0.6878014990816945
# Epoch 115/120 - Training Loss: 0.6878 - MER: 0.0710
# 0.07095842
# Training loss: 0.6834003018296283
# Epoch 116/120 - Training Loss: 0.6834 - MER: 0.0697
# 0.06967123
# Training loss: 0.6864436346551647
# Epoch 117/120 - Training Loss: 0.6864 - MER: 0.0702
# 0.07016583
# Training loss: 0.6824001229327658
# Epoch 118/120 - Training Loss: 0.6824 - MER: 0.0710
# 0.070960656
# Training loss: 0.6876490504845328
# Epoch 119/120 - Training Loss: 0.6876 - MER: 0.0692
# 0.069240116
# Training loss: 0.6817846725816312
# Epoch 120/120 - Training Loss: 0.6818 - MER: 0.0720
# 0.07202618

# %%
model_6 = nn.Sequential(
    nn.Linear(train_features.shape[1], 64),
    nn.ReLU(),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 1)
)

model_6.to(device)


criterion_MLP_6 = nn.L1Loss()

# Define the optimizer with weight decay for L2 regularization
optimizer_MLP_6 = optim.AdamW(model_6.parameters(), lr=0.001, weight_decay = 0.001)  # Adjust the weight decay value as needed


# model_5 = fc_model.Network(102, 1, [64, 32])
# model_5.to(device)
# criterion = nn.SmoothL1Loss()
# optimizer_MLP_5 = optim.Adam(model_5.parameters(), lr=0.001, weight_decay = 0.001)

epochs = 150
train_losses_MLP_6, valid_losses_MLP_6 = [], []
mer_values_train_MLP_6, mer_values_valid_MLP_6 = [], []

for e in range(epochs):
    running_train_loss = 0
    for batch_features, batch_labels in train_loader:
        batch_features = batch_features.to(device)
        batch_labels = batch_labels.to(device)

        logps = model_6(batch_features)
        loss = criterion_MLP_6(logps, batch_labels)

        # Get the L2 norm of the model's parameters
        l2_reg = None
        for param in model_6.parameters():
            if l2_reg is None:
              l2_reg = param.norm(2)  # Compute the L2 norm
            else:
                l2_reg = l2_reg + param.norm(2)

        # Add the regularization term to the loss
        loss = loss + 0.001 * l2_reg  # Adjust the regularization strength (0.001 in this case)

        optimizer_MLP_6.zero_grad()
        loss.backward()
        optimizer_MLP_6.step()

        running_train_loss += loss.item()

    # Validation and other calculations remain the same as before

    else:
      running_valid_loss = 0
      with torch.no_grad():
        model_6.eval()
        # for batch_features, batch_labels in valid_loader:
        #   batch_features = batch_features.to(device)
        #   batch_labels = batch_labels.to(device)

        #   outputs = model_5(batch_features)
        #   loss = criterion_MLP_5(outputs, batch_labels)
        #   running_valid_loss += loss.item()

      model_6.train()
      train_loss = running_train_loss/len(train_loader)
      #valid_loss = running_valid_loss/len(valid_loader)
      train_losses_MLP_6.append(train_loss)
      #valid_losses_MLP_5.append(valid_loss)


  # Calculate MER for this epoch and append to the list
    train_loss = running_train_loss / len(train_loader)
    train_losses_MLP_6.append(train_loss)

    # valid_loss = running_valid_loss / len(valid_loader)
    # valid_losses_MLP_5.append(valid_loss)

  # Calculate MER based on your code
    train_features = train_features.to(device)
    train_labels = train_labels.to(device)
    # valid_features = valid_features.to(device)
    # valid_labels = valid_labels.to(device)

    predicted_train = model_6(train_features).cpu().detach().numpy()
    actual_train = train_labels.cpu().numpy()
    error_rates_train = np.abs((predicted_train - actual_train) / actual_train)
    mer_train_MLP = np.median(error_rates_train)
    mer_values_train_MLP_6.append(mer_train_MLP)

    # predicted_valid = model_5(valid_features).cpu().detach().numpy()
    # actual_valid = valid_labels.cpu().numpy()
    # error_rates_valid = np.abs((predicted_valid - actual_valid) / actual_valid)
    # mer_valid_MLP = np.median(error_rates_valid)
    # mer_values_valid_MLP_5.append(mer_valid_MLP)


    print(f"Epoch {e + 1}/{epochs} - Training Loss: {train_loss:.4f} - MER: {mer_train_MLP:.4f}")
    print(mer_train_MLP)
    # print(f"Epoch {e + 1}/{epochs} - Valid Loss: {valid_loss:.4f} - MER: {mer_valid_MLP:.4f}")
    # print(mer_valid_MLP)
# Out:
# Epoch 1/300 - Training Loss: 2.0341 - MER: 0.2145
# 0.21448886
# Epoch 1/300 - Valid Loss: 0.9320 - MER: 0.2177
# 0.21773605
# Epoch 2/300 - Training Loss: 0.9163 - MER: 0.1688
# 0.16881117
# Epoch 2/300 - Valid Loss: 0.6675 - MER: 0.1750
# 0.17498614
# Epoch 3/300 - Training Loss: 0.7429 - MER: 0.1528
# 0.15279365
# Epoch 3/300 - Valid Loss: 0.5599 - MER: 0.1531
# 0.15314084
# Epoch 4/300 - Training Loss: 0.6708 - MER: 0.1445
# 0.1445317
# Epoch 4/300 - Valid Loss: 0.5113 - MER: 0.1458
# 0.14576277
# Epoch 5/300 - Training Loss: 0.6694 - MER: 0.1448
# 0.14476258
# Epoch 5/300 - Valid Loss: 0.5460 - MER: 0.1492
# 0.14923316
# Epoch 6/300 - Training Loss: 0.6303 - MER: 0.1344
# 0.13438031
# Epoch 6/300 - Valid Loss: 0.4950 - MER: 0.1412
# 0.14119343
# Epoch 7/300 - Training Loss: 0.6338 - MER: 0.1373
# 0.13731271
# Epoch 7/300 - Valid Loss: 0.5172 - MER: 0.1436
# 0.14359333
# Epoch 8/300 - Training Loss: 0.6092 - MER: 0.1315
# 0.13152614
# Epoch 8/300 - Valid Loss: 0.4895 - MER: 0.1399
# 0.13987808
# Epoch 9/300 - Training Loss: 0.6108 - MER: 0.1257
# 0.12573013
# Epoch 9/300 - Valid Loss: 0.4674 - MER: 0.1351
# 0.13509709
# Epoch 10/300 - Training Loss: 0.5886 - MER: 0.1313
# 0.13129464
# Epoch 10/300 - Valid Loss: 0.5167 - MER: 0.1341
# 0.13405965
# Epoch 11/300 - Training Loss: 0.5736 - MER: 0.1272
# 0.12722354
# Epoch 11/300 - Valid Loss: 0.4636 - MER: 0.1295
# 0.12945212
# Epoch 12/300 - Training Loss: 0.5694 - MER: 0.1257
# 0.12568074
# Epoch 12/300 - Valid Loss: 0.4591 - MER: 0.1322
# 0.13223696
# Epoch 13/300 - Training Loss: 0.5738 - MER: 0.1326
# 0.13258603
# Epoch 13/300 - Valid Loss: 0.5168 - MER: 0.1357
# 0.13572173
# Epoch 14/300 - Training Loss: 0.5761 - MER: 0.1190
# 0.11903026
# Epoch 14/300 - Valid Loss: 0.4652 - MER: 0.1327
# 0.13273786
# Epoch 15/300 - Training Loss: 0.5550 - MER: 0.1242
# 0.12415707
# Epoch 15/300 - Valid Loss: 0.4682 - MER: 0.1258
# 0.1257821
# Epoch 16/300 - Training Loss: 0.5544 - MER: 0.1216
# 0.12162595
# Epoch 16/300 - Valid Loss: 0.4852 - MER: 0.1277
# 0.12774388
# Epoch 17/300 - Training Loss: 0.5484 - MER: 0.1234
# 0.12343025
# Epoch 17/300 - Valid Loss: 0.5020 - MER: 0.1308
# 0.13079064
# Epoch 18/300 - Training Loss: 0.5396 - MER: 0.1203
# 0.120280236
# Epoch 18/300 - Valid Loss: 0.4657 - MER: 0.1243
# 0.12432361
# Epoch 19/300 - Training Loss: 0.5376 - MER: 0.1180
# 0.11798643
# Epoch 19/300 - Valid Loss: 0.4640 - MER: 0.1239
# 0.12385712
# Epoch 20/300 - Training Loss: 0.5313 - MER: 0.1130
# 0.112979606
# Epoch 20/300 - Valid Loss: 0.4426 - MER: 0.1233
# 0.12327097
# Epoch 21/300 - Training Loss: 0.5285 - MER: 0.1187
# 0.11868264
# Epoch 21/300 - Valid Loss: 0.4833 - MER: 0.1257
# 0.12569135
# Epoch 22/300 - Training Loss: 0.5175 - MER: 0.1210
# 0.12096678
# Epoch 22/300 - Valid Loss: 0.4860 - MER: 0.1231
# 0.123088434
# Epoch 23/300 - Training Loss: 0.5068 - MER: 0.1214
# 0.12136778
# Epoch 23/300 - Valid Loss: 0.4727 - MER: 0.1276
# 0.12756576
# Epoch 24/300 - Training Loss: 0.5208 - MER: 0.1160
# 0.116024226
# Epoch 24/300 - Valid Loss: 0.4489 - MER: 0.1255
# 0.12548909
# Epoch 25/300 - Training Loss: 0.5164 - MER: 0.1196
# 0.11955975
# Epoch 25/300 - Valid Loss: 0.4719 - MER: 0.1253
# 0.12527862
# Epoch 26/300 - Training Loss: 0.5100 - MER: 0.1244
# 0.124442056
# Epoch 26/300 - Valid Loss: 0.4870 - MER: 0.1364
# 0.13636133
# Epoch 27/300 - Training Loss: 0.5206 - MER: 0.1146
# 0.11458607
# Epoch 27/300 - Valid Loss: 0.4526 - MER: 0.1220
# 0.12202653
# Epoch 28/300 - Training Loss: 0.4943 - MER: 0.1120
# 0.11200818
# Epoch 28/300 - Valid Loss: 0.4415 - MER: 0.1172
# 0.11724869
# Epoch 29/300 - Training Loss: 0.4899 - MER: 0.1183
# 0.11829973
# Epoch 29/300 - Valid Loss: 0.4570 - MER: 0.1305
# 0.13054463
# Epoch 30/300 - Training Loss: 0.4990 - MER: 0.1136
# 0.113582864
# Epoch 30/300 - Valid Loss: 0.4644 - MER: 0.1228
# 0.12280994
# Epoch 31/300 - Training Loss: 0.4915 - MER: 0.1131
# 0.11306946
# Epoch 31/300 - Valid Loss: 0.4419 - MER: 0.1206
# 0.120553784
# Epoch 32/300 - Training Loss: 0.4861 - MER: 0.1116
# 0.1115904
# Epoch 32/300 - Valid Loss: 0.4713 - MER: 0.1204
# 0.120432116
# Epoch 33/300 - Training Loss: 0.4902 - MER: 0.1260
# 0.12604696
# Epoch 33/300 - Valid Loss: 0.5460 - MER: 0.1401
# 0.14009635
# Epoch 34/300 - Training Loss: 0.4906 - MER: 0.1138
# 0.113829784
# Epoch 34/300 - Valid Loss: 0.4332 - MER: 0.1239
# 0.12394437
# Epoch 35/300 - Training Loss: 0.4955 - MER: 0.1097
# 0.10965598
# Epoch 35/300 - Valid Loss: 0.4312 - MER: 0.1235
# 0.12351681
# Epoch 36/300 - Training Loss: 0.4916 - MER: 0.1095
# 0.109505236
# Epoch 36/300 - Valid Loss: 0.4346 - MER: 0.1137
# 0.11366911
# Epoch 37/300 - Training Loss: 0.4707 - MER: 0.1106
# 0.11055519
# Epoch 37/300 - Valid Loss: 0.4355 - MER: 0.1200
# 0.120014764
# Epoch 38/300 - Training Loss: 0.4760 - MER: 0.1107
# 0.1107153
# Epoch 38/300 - Valid Loss: 0.4699 - MER: 0.1218
# 0.121783905
# Epoch 39/300 - Training Loss: 0.4800 - MER: 0.1087
# 0.10866447
# Epoch 39/300 - Valid Loss: 0.4277 - MER: 0.1170
# 0.1170063
# Epoch 40/300 - Training Loss: 0.4699 - MER: 0.1125
# 0.11246446
# Epoch 40/300 - Valid Loss: 0.4672 - MER: 0.1202
# 0.120215006
# Epoch 41/300 - Training Loss: 0.4643 - MER: 0.1072
# 0.10717795
# Epoch 41/300 - Valid Loss: 0.4290 - MER: 0.1204
# 0.120407484
# Epoch 42/300 - Training Loss: 0.4593 - MER: 0.1086
# 0.1086132
# Epoch 42/300 - Valid Loss: 0.4175 - MER: 0.1172
# 0.1171977
# Epoch 43/300 - Training Loss: 0.4782 - MER: 0.1087
# 0.10874397
# Epoch 43/300 - Valid Loss: 0.4173 - MER: 0.1186
# 0.11858448
# Epoch 44/300 - Training Loss: 0.4727 - MER: 0.1058
# 0.105823696
# Epoch 44/300 - Valid Loss: 0.4233 - MER: 0.1175
# 0.117471375
# Epoch 45/300 - Training Loss: 0.4642 - MER: 0.1040
# 0.104024015
# Epoch 45/300 - Valid Loss: 0.4315 - MER: 0.1166
# 0.11655591
# Epoch 46/300 - Training Loss: 0.4565 - MER: 0.1072
# 0.107154086
# Epoch 46/300 - Valid Loss: 0.4356 - MER: 0.1206
# 0.12064086
# Epoch 47/300 - Training Loss: 0.4637 - MER: 0.1080
# 0.10803663
# Epoch 47/300 - Valid Loss: 0.4396 - MER: 0.1244
# 0.12441197
# Epoch 48/300 - Training Loss: 0.4660 - MER: 0.1083
# 0.10828063
# Epoch 48/300 - Valid Loss: 0.4234 - MER: 0.1194
# 0.1193573
# Epoch 49/300 - Training Loss: 0.4590 - MER: 0.1039
# 0.103918225
# Epoch 49/300 - Valid Loss: 0.4120 - MER: 0.1146
# 0.11459976
# Epoch 50/300 - Training Loss: 0.4652 - MER: 0.1052
# 0.10521771
# Epoch 50/300 - Valid Loss: 0.4363 - MER: 0.1181
# 0.11813734
# Epoch 51/300 - Training Loss: 0.4686 - MER: 0.1070
# 0.10703332
# Epoch 51/300 - Valid Loss: 0.4469 - MER: 0.1204
# 0.12036174
# Epoch 52/300 - Training Loss: 0.4539 - MER: 0.1073
# 0.10729858
# Epoch 52/300 - Valid Loss: 0.4242 - MER: 0.1180
# 0.11804601
# Epoch 53/300 - Training Loss: 0.4655 - MER: 0.1042
# 0.104152426
# Epoch 53/300 - Valid Loss: 0.4389 - MER: 0.1190
# 0.1189563
# Epoch 54/300 - Training Loss: 0.4450 - MER: 0.1049
# 0.10494192
# Epoch 54/300 - Valid Loss: 0.4223 - MER: 0.1243
# 0.124294415
# Epoch 55/300 - Training Loss: 0.4468 - MER: 0.1063
# 0.10630584
# Epoch 55/300 - Valid Loss: 0.4553 - MER: 0.1259
# 0.12586524
# Epoch 56/300 - Training Loss: 0.4534 - MER: 0.1093
# 0.10933286
# Epoch 56/300 - Valid Loss: 0.4401 - MER: 0.1208
# 0.12080976
# Epoch 57/300 - Training Loss: 0.4458 - MER: 0.1036
# 0.10357535
# Epoch 57/300 - Valid Loss: 0.4242 - MER: 0.1142
# 0.11423929
# Epoch 58/300 - Training Loss: 0.4321 - MER: 0.1004
# 0.10042379
# Epoch 58/300 - Valid Loss: 0.4126 - MER: 0.1132
# 0.113151185
# Epoch 59/300 - Training Loss: 0.4347 - MER: 0.1046
# 0.10461675
# Epoch 59/300 - Valid Loss: 0.4192 - MER: 0.1167
# 0.11674963
# Epoch 60/300 - Training Loss: 0.4379 - MER: 0.1141
# 0.11408708
# Epoch 60/300 - Valid Loss: 0.4404 - MER: 0.1263
# 0.12626179
# Epoch 61/300 - Training Loss: 0.4389 - MER: 0.1000
# 0.09995197
# Epoch 61/300 - Valid Loss: 0.4372 - MER: 0.1124
# 0.11239131
# Epoch 62/300 - Training Loss: 0.4455 - MER: 0.1031
# 0.1030554
# Epoch 62/300 - Valid Loss: 0.4251 - MER: 0.1126
# 0.11262313
# Epoch 63/300 - Training Loss: 0.4354 - MER: 0.1070
# 0.10699175
# Epoch 63/300 - Valid Loss: 0.4494 - MER: 0.1171
# 0.11706943
# Epoch 64/300 - Training Loss: 0.4308 - MER: 0.1021
# 0.10205126
# Epoch 64/300 - Valid Loss: 0.4131 - MER: 0.1174
# 0.11737278
# Epoch 65/300 - Training Loss: 0.4265 - MER: 0.0985
# 0.098518044
# Epoch 65/300 - Valid Loss: 0.4007 - MER: 0.1125
# 0.11254967
# Epoch 66/300 - Training Loss: 0.4354 - MER: 0.1034
# 0.1033793
# Epoch 66/300 - Valid Loss: 0.4179 - MER: 0.1153
# 0.11532626
# Epoch 67/300 - Training Loss: 0.4225 - MER: 0.1018
# 0.10175423
# Epoch 67/300 - Valid Loss: 0.4493 - MER: 0.1175
# 0.11754876
# Epoch 68/300 - Training Loss: 0.4360 - MER: 0.1046
# 0.104621544
# Epoch 68/300 - Valid Loss: 0.4391 - MER: 0.1159
# 0.11590317
# Epoch 69/300 - Training Loss: 0.4308 - MER: 0.1022
# 0.1021979
# Epoch 69/300 - Valid Loss: 0.4276 - MER: 0.1134
# 0.11338279
# Epoch 70/300 - Training Loss: 0.4297 - MER: 0.1046
# 0.10455617
# Epoch 70/300 - Valid Loss: 0.4127 - MER: 0.1197
# 0.119727
# Epoch 71/300 - Training Loss: 0.4299 - MER: 0.1030
# 0.103030354
# Epoch 71/300 - Valid Loss: 0.4329 - MER: 0.1268
# 0.12677108
# Epoch 72/300 - Training Loss: 0.4200 - MER: 0.1008
# 0.100849524
# Epoch 72/300 - Valid Loss: 0.4218 - MER: 0.1173
# 0.11730614
# Epoch 73/300 - Training Loss: 0.4252 - MER: 0.1087
# 0.10871568
# Epoch 73/300 - Valid Loss: 0.4667 - MER: 0.1215
# 0.121458605
# Epoch 74/300 - Training Loss: 0.4342 - MER: 0.1147
# 0.11467908
# Epoch 74/300 - Valid Loss: 0.4586 - MER: 0.1235
# 0.12345682
# Epoch 75/300 - Training Loss: 0.4290 - MER: 0.1004
# 0.100395374
# Epoch 75/300 - Valid Loss: 0.4278 - MER: 0.1108
# 0.11078345
# Epoch 76/300 - Training Loss: 0.4122 - MER: 0.1004
# 0.100352585
# Epoch 76/300 - Valid Loss: 0.4304 - MER: 0.1127
# 0.11273636
# Epoch 77/300 - Training Loss: 0.4163 - MER: 0.0972
# 0.09719492
# Epoch 77/300 - Valid Loss: 0.4186 - MER: 0.1143
# 0.11433657
# Epoch 78/300 - Training Loss: 0.4221 - MER: 0.1011
# 0.10108173
# Epoch 78/300 - Valid Loss: 0.4137 - MER: 0.1129
# 0.112938486
# Epoch 79/300 - Training Loss: 0.4165 - MER: 0.0967
# 0.09665805
# Epoch 79/300 - Valid Loss: 0.4292 - MER: 0.1084
# 0.10836265
# Epoch 80/300 - Training Loss: 0.4257 - MER: 0.1000
# 0.09998094
# Epoch 80/300 - Valid Loss: 0.4169 - MER: 0.1140
# 0.113989934
# Epoch 81/300 - Training Loss: 0.4068 - MER: 0.0984
# 0.09841806
# Epoch 81/300 - Valid Loss: 0.4182 - MER: 0.1155
# 0.11552669
# Epoch 82/300 - Training Loss: 0.4142 - MER: 0.1011
# 0.101093076
# Epoch 82/300 - Valid Loss: 0.4196 - MER: 0.1194
# 0.1193961
# Epoch 83/300 - Training Loss: 0.4153 - MER: 0.0979
# 0.097946316
# Epoch 83/300 - Valid Loss: 0.4583 - MER: 0.1158
# 0.11578124
# Epoch 84/300 - Training Loss: 0.4221 - MER: 0.0986
# 0.098647624
# Epoch 84/300 - Valid Loss: 0.4313 - MER: 0.1111
# 0.11112051
# Epoch 85/300 - Training Loss: 0.4057 - MER: 0.0975
# 0.09748471
# Epoch 85/300 - Valid Loss: 0.4165 - MER: 0.1125
# 0.11251011
# Epoch 86/300 - Training Loss: 0.4079 - MER: 0.0975
# 0.09754799
# Epoch 86/300 - Valid Loss: 0.4129 - MER: 0.1139
# 0.11394095
# Epoch 87/300 - Training Loss: 0.4079 - MER: 0.0988
# 0.09883703
# Epoch 87/300 - Valid Loss: 0.4403 - MER: 0.1181
# 0.11805153
# Epoch 88/300 - Training Loss: 0.4116 - MER: 0.0975
# 0.09753786
# Epoch 88/300 - Valid Loss: 0.4188 - MER: 0.1096
# 0.10956627
# Epoch 89/300 - Training Loss: 0.4087 - MER: 0.1101
# 0.11008158
# Epoch 89/300 - Valid Loss: 0.4784 - MER: 0.1236
# 0.12363508
# Epoch 90/300 - Training Loss: 0.4326 - MER: 0.1008
# 0.100779995
# Epoch 90/300 - Valid Loss: 0.4403 - MER: 0.1190
# 0.11895324
# Epoch 91/300 - Training Loss: 0.3978 - MER: 0.0943
# 0.09425967
# Epoch 91/300 - Valid Loss: 0.4057 - MER: 0.1119
# 0.11193298
# Epoch 92/300 - Training Loss: 0.3960 - MER: 0.0967
# 0.096670195
# Epoch 92/300 - Valid Loss: 0.4181 - MER: 0.1156
# 0.11556662
# Epoch 93/300 - Training Loss: 0.3967 - MER: 0.0954
# 0.095398106
# Epoch 93/300 - Valid Loss: 0.4293 - MER: 0.1170
# 0.116979
# Epoch 94/300 - Training Loss: 0.4079 - MER: 0.1002
# 0.100191996
# Epoch 94/300 - Valid Loss: 0.4556 - MER: 0.1171
# 0.1170606
# Epoch 95/300 - Training Loss: 0.3952 - MER: 0.0999
# 0.09987603
# Epoch 95/300 - Valid Loss: 0.4324 - MER: 0.1144
# 0.11442172
# Epoch 96/300 - Training Loss: 0.4011 - MER: 0.0972
# 0.097201556
# Epoch 96/300 - Valid Loss: 0.4241 - MER: 0.1122
# 0.11219564
# Epoch 97/300 - Training Loss: 0.4012 - MER: 0.0950
# 0.09500052
# Epoch 97/300 - Valid Loss: 0.4187 - MER: 0.1094
# 0.10940844
# Epoch 98/300 - Training Loss: 0.4015 - MER: 0.0945
# 0.09445736
# Epoch 98/300 - Valid Loss: 0.4170 - MER: 0.1098
# 0.10977863
# Epoch 99/300 - Training Loss: 0.3903 - MER: 0.0986
# 0.09860396
# Epoch 99/300 - Valid Loss: 0.4245 - MER: 0.1153
# 0.115287334
# Epoch 100/300 - Training Loss: 0.3963 - MER: 0.1041
# 0.10413074
# Epoch 100/300 - Valid Loss: 0.5145 - MER: 0.1148
# 0.114824094
# Epoch 101/300 - Training Loss: 0.4152 - MER: 0.0933
# 0.093273446
# Epoch 101/300 - Valid Loss: 0.4101 - MER: 0.1115
# 0.1115372
# Epoch 102/300 - Training Loss: 0.3904 - MER: 0.0996
# 0.099648714
# Epoch 102/300 - Valid Loss: 0.4390 - MER: 0.1162
# 0.11617049
# Epoch 103/300 - Training Loss: 0.3958 - MER: 0.0940
# 0.09398438
# Epoch 103/300 - Valid Loss: 0.4448 - MER: 0.1140
# 0.11395393
# Epoch 104/300 - Training Loss: 0.4004 - MER: 0.1001
# 0.10007075
# Epoch 104/300 - Valid Loss: 0.4322 - MER: 0.1142
# 0.114186235
# Epoch 105/300 - Training Loss: 0.3856 - MER: 0.0966
# 0.0965724
# Epoch 105/300 - Valid Loss: 0.4296 - MER: 0.1115
# 0.11149461
# Epoch 106/300 - Training Loss: 0.3963 - MER: 0.0941
# 0.094147526
# Epoch 106/300 - Valid Loss: 0.4203 - MER: 0.1161
# 0.11608759
# Epoch 107/300 - Training Loss: 0.3942 - MER: 0.0929
# 0.092907086
# Epoch 107/300 - Valid Loss: 0.4172 - MER: 0.1108
# 0.11082136
# Epoch 108/300 - Training Loss: 0.3921 - MER: 0.0939
# 0.09393387
# Epoch 108/300 - Valid Loss: 0.4211 - MER: 0.1083
# 0.10834544
# Epoch 109/300 - Training Loss: 0.3794 - MER: 0.0932
# 0.093225986
# Epoch 109/300 - Valid Loss: 0.4049 - MER: 0.1121
# 0.112082176
# Epoch 110/300 - Training Loss: 0.3720 - MER: 0.0921
# 0.09211129
# Epoch 110/300 - Valid Loss: 0.4253 - MER: 0.1083
# 0.10827308
# Epoch 111/300 - Training Loss: 0.3817 - MER: 0.0930
# 0.09298363
# Epoch 111/300 - Valid Loss: 0.4511 - MER: 0.1091
# 0.10907314
# Epoch 112/300 - Training Loss: 0.3805 - MER: 0.0971
# 0.097114354
# Epoch 112/300 - Valid Loss: 0.4366 - MER: 0.1163
# 0.1162701
# Epoch 113/300 - Training Loss: 0.3868 - MER: 0.0941
# 0.09407641
# Epoch 113/300 - Valid Loss: 0.4222 - MER: 0.1132
# 0.11324733
# Epoch 114/300 - Training Loss: 0.3914 - MER: 0.0931
# 0.09309916
# Epoch 114/300 - Valid Loss: 0.4391 - MER: 0.1115
# 0.11154127
# Epoch 115/300 - Training Loss: 0.3956 - MER: 0.0917
# 0.09166837
# Epoch 115/300 - Valid Loss: 0.4162 - MER: 0.1130
# 0.112971604
# Epoch 116/300 - Training Loss: 0.3940 - MER: 0.0949
# 0.094893396
# Epoch 116/300 - Valid Loss: 0.4231 - MER: 0.1122
# 0.11215817
# Epoch 117/300 - Training Loss: 0.3851 - MER: 0.0929
# 0.092935964
# Epoch 117/300 - Valid Loss: 0.4299 - MER: 0.1088
# 0.10879596
# Epoch 118/300 - Training Loss: 0.3933 - MER: 0.0926
# 0.09262195
# Epoch 118/300 - Valid Loss: 0.4237 - MER: 0.1126
# 0.112616956
# Epoch 119/300 - Training Loss: 0.3915 - MER: 0.0927
# 0.092688695
# Epoch 119/300 - Valid Loss: 0.4058 - MER: 0.1121
# 0.11206999
# Epoch 120/300 - Training Loss: 0.3867 - MER: 0.0910
# 0.09099993
# Epoch 120/300 - Valid Loss: 0.4173 - MER: 0.1106
# 0.11060023
# Epoch 121/300 - Training Loss: 0.3791 - MER: 0.0947
# 0.09466518
# Epoch 121/300 - Valid Loss: 0.4359 - MER: 0.1123
# 0.11230043
# Epoch 122/300 - Training Loss: 0.3798 - MER: 0.0909
# 0.090893134
# Epoch 122/300 - Valid Loss: 0.4249 - MER: 0.1096
# 0.109643154
# Epoch 123/300 - Training Loss: 0.3692 - MER: 0.0964
# 0.09642734
# Epoch 123/300 - Valid Loss: 0.4187 - MER: 0.1166
# 0.1166095
# Epoch 124/300 - Training Loss: 0.3762 - MER: 0.0922
# 0.09219028
# Epoch 124/300 - Valid Loss: 0.4271 - MER: 0.1125
# 0.11254582
# Epoch 125/300 - Training Loss: 0.3765 - MER: 0.0941
# 0.09414339
# Epoch 125/300 - Valid Loss: 0.4273 - MER: 0.1114
# 0.1114257
# Epoch 126/300 - Training Loss: 0.3956 - MER: 0.1005
# 0.1005407
# Epoch 126/300 - Valid Loss: 0.4487 - MER: 0.1174
# 0.11737856
# Epoch 127/300 - Training Loss: 0.3723 - MER: 0.0969
# 0.09685874
# Epoch 127/300 - Valid Loss: 0.4217 - MER: 0.1147
# 0.114702344
# Epoch 128/300 - Training Loss: 0.3785 - MER: 0.0905
# 0.09048808
# Epoch 128/300 - Valid Loss: 0.4099 - MER: 0.1083
# 0.108254045
# Epoch 129/300 - Training Loss: 0.3788 - MER: 0.0899
# 0.0898561
# Epoch 129/300 - Valid Loss: 0.4088 - MER: 0.1058
# 0.10577203
# Epoch 130/300 - Training Loss: 0.3736 - MER: 0.0940
# 0.09397726
# Epoch 130/300 - Valid Loss: 0.4792 - MER: 0.1132
# 0.11316926
# Epoch 131/300 - Training Loss: 0.3830 - MER: 0.0917
# 0.09173912
# Epoch 131/300 - Valid Loss: 0.4333 - MER: 0.1064
# 0.106440805
# Epoch 132/300 - Training Loss: 0.3949 - MER: 0.0925
# 0.09253285
# Epoch 132/300 - Valid Loss: 0.4210 - MER: 0.1053
# 0.10526406
# Epoch 133/300 - Training Loss: 0.3899 - MER: 0.0982
# 0.098216936
# Epoch 133/300 - Valid Loss: 0.4485 - MER: 0.1118
# 0.11183413
# Epoch 134/300 - Training Loss: 0.3784 - MER: 0.0899
# 0.08994576
# Epoch 134/300 - Valid Loss: 0.4194 - MER: 0.1105
# 0.110504694
# Epoch 135/300 - Training Loss: 0.3744 - MER: 0.0923
# 0.09226014
# Epoch 135/300 - Valid Loss: 0.4174 - MER: 0.1155
# 0.11549347
# Epoch 136/300 - Training Loss: 0.3731 - MER: 0.1093
# 0.109340906
# Epoch 136/300 - Valid Loss: 0.4840 - MER: 0.1231
# 0.12305135
# Epoch 137/300 - Training Loss: 0.3809 - MER: 0.0879
# 0.08789019
# Epoch 137/300 - Valid Loss: 0.4158 - MER: 0.1093
# 0.10927986
# Epoch 138/300 - Training Loss: 0.3832 - MER: 0.0936
# 0.09355977
# Epoch 138/300 - Valid Loss: 0.4057 - MER: 0.1094
# 0.10939529
# Epoch 139/300 - Training Loss: 0.3778 - MER: 0.0915
# 0.0914941
# Epoch 139/300 - Valid Loss: 0.4220 - MER: 0.1128
# 0.11277758
# Epoch 140/300 - Training Loss: 0.3761 - MER: 0.0931
# 0.09306718
# Epoch 140/300 - Valid Loss: 0.4279 - MER: 0.1173
# 0.11733512
# Epoch 141/300 - Training Loss: 0.3771 - MER: 0.0907
# 0.09070836
# Epoch 141/300 - Valid Loss: 0.4135 - MER: 0.1085
# 0.10852033
# Epoch 142/300 - Training Loss: 0.3642 - MER: 0.0940
# 0.093995616
# Epoch 142/300 - Valid Loss: 0.4187 - MER: 0.1114
# 0.1114403
# Epoch 143/300 - Training Loss: 0.3724 - MER: 0.0940
# 0.09399821
# Epoch 143/300 - Valid Loss: 0.4176 - MER: 0.1129
# 0.112856135
# Epoch 144/300 - Training Loss: 0.3654 - MER: 0.0901
# 0.09013604
# Epoch 144/300 - Valid Loss: 0.4395 - MER: 0.1105
# 0.11049866
# Epoch 145/300 - Training Loss: 0.3696 - MER: 0.0891
# 0.0891279
# Epoch 145/300 - Valid Loss: 0.4158 - MER: 0.1090
# 0.10903338
# Epoch 146/300 - Training Loss: 0.3668 - MER: 0.0885
# 0.08847411
# Epoch 146/300 - Valid Loss: 0.4089 - MER: 0.1115
# 0.11146267
# Epoch 147/300 - Training Loss: 0.3662 - MER: 0.0922
# 0.092233196
# Epoch 147/300 - Valid Loss: 0.4196 - MER: 0.1113
# 0.111287944
# Epoch 148/300 - Training Loss: 0.3597 - MER: 0.0927
# 0.09267424
# Epoch 148/300 - Valid Loss: 0.4171 - MER: 0.1153
# 0.11534243
# Epoch 149/300 - Training Loss: 0.3648 - MER: 0.0908
# 0.09082964
# Epoch 149/300 - Valid Loss: 0.4550 - MER: 0.1081
# 0.10808678
# Epoch 150/300 - Training Loss: 0.3639 - MER: 0.0904
# 0.09043592
# Epoch 150/300 - Valid Loss: 0.4123 - MER: 0.1072
# 0.10720616
# Epoch 151/300 - Training Loss: 0.3638 - MER: 0.0912
# 0.0911932
# Epoch 151/300 - Valid Loss: 0.4284 - MER: 0.1101
# 0.110092476
# Epoch 152/300 - Training Loss: 0.3710 - MER: 0.0861
# 0.08610423
# Epoch 152/300 - Valid Loss: 0.4261 - MER: 0.1096
# 0.1095552
# Epoch 153/300 - Training Loss: 0.3600 - MER: 0.0893
# 0.08925693
# Epoch 153/300 - Valid Loss: 0.4181 - MER: 0.1118
# 0.111843355
# Epoch 154/300 - Training Loss: 0.3648 - MER: 0.0955
# 0.09548695
# Epoch 154/300 - Valid Loss: 0.4305 - MER: 0.1107
# 0.1107332
# Epoch 155/300 - Training Loss: 0.3625 - MER: 0.0897
# 0.089661434
# Epoch 155/300 - Valid Loss: 0.4121 - MER: 0.1080
# 0.108009525
# Epoch 156/300 - Training Loss: 0.3581 - MER: 0.0918
# 0.09182669
# Epoch 156/300 - Valid Loss: 0.4066 - MER: 0.1110
# 0.110991426
# Epoch 157/300 - Training Loss: 0.3647 - MER: 0.0893
# 0.08927312
# Epoch 157/300 - Valid Loss: 0.4174 - MER: 0.1097
# 0.109712586
# Epoch 158/300 - Training Loss: 0.3745 - MER: 0.0896
# 0.08959892
# Epoch 158/300 - Valid Loss: 0.4214 - MER: 0.1074
# 0.10737074
# Epoch 159/300 - Training Loss: 0.3673 - MER: 0.0975
# 0.09747422
# Epoch 159/300 - Valid Loss: 0.4488 - MER: 0.1150
# 0.11500497
# Epoch 160/300 - Training Loss: 0.3596 - MER: 0.0886
# 0.08864424
# Epoch 160/300 - Valid Loss: 0.4063 - MER: 0.1090
# 0.10901157
# Epoch 161/300 - Training Loss: 0.3512 - MER: 0.0930
# 0.093003586
# Epoch 161/300 - Valid Loss: 0.4394 - MER: 0.1109
# 0.11087076
# Epoch 162/300 - Training Loss: 0.3555 - MER: 0.0957
# 0.09574997
# Epoch 162/300 - Valid Loss: 0.4316 - MER: 0.1171
# 0.117145784
# Epoch 163/300 - Training Loss: 0.3702 - MER: 0.0884
# 0.088358775
# Epoch 163/300 - Valid Loss: 0.4134 - MER: 0.1075
# 0.10753542
# Epoch 164/300 - Training Loss: 0.3666 - MER: 0.0888
# 0.0887789
# Epoch 164/300 - Valid Loss: 0.4153 - MER: 0.1122
# 0.11218533
# Epoch 165/300 - Training Loss: 0.3553 - MER: 0.0897
# 0.08965486
# Epoch 165/300 - Valid Loss: 0.4048 - MER: 0.1099
# 0.10988276
# Epoch 166/300 - Training Loss: 0.3511 - MER: 0.0886
# 0.08857776
# Epoch 166/300 - Valid Loss: 0.4369 - MER: 0.1076
# 0.10757383
# Epoch 167/300 - Training Loss: 0.3565 - MER: 0.0854
# 0.08542093
# Epoch 167/300 - Valid Loss: 0.4130 - MER: 0.1104
# 0.11040889
# Epoch 168/300 - Training Loss: 0.3601 - MER: 0.0869
# 0.08690878
# Epoch 168/300 - Valid Loss: 0.4092 - MER: 0.1084
# 0.108444884
# Epoch 169/300 - Training Loss: 0.3633 - MER: 0.0878
# 0.08781274
# Epoch 169/300 - Valid Loss: 0.4098 - MER: 0.1054
# 0.10538733
# Epoch 170/300 - Training Loss: 0.3570 - MER: 0.0867
# 0.08666237
# Epoch 170/300 - Valid Loss: 0.4156 - MER: 0.1039
# 0.10386052
# Epoch 171/300 - Training Loss: 0.3670 - MER: 0.0926
# 0.09260774
# Epoch 171/300 - Valid Loss: 0.4264 - MER: 0.1125
# 0.11252403
# Epoch 172/300 - Training Loss: 0.3566 - MER: 0.0859
# 0.08589601
# Epoch 172/300 - Valid Loss: 0.4238 - MER: 0.1030
# 0.103018455
# Epoch 173/300 - Training Loss: 0.3532 - MER: 0.0870
# 0.08697286
# Epoch 173/300 - Valid Loss: 0.4076 - MER: 0.1062
# 0.106200084
# Epoch 174/300 - Training Loss: 0.3630 - MER: 0.0859
# 0.08587898
# Epoch 174/300 - Valid Loss: 0.4060 - MER: 0.1138
# 0.113837264
# Epoch 175/300 - Training Loss: 0.3615 - MER: 0.0869
# 0.086889535
# Epoch 175/300 - Valid Loss: 0.4572 - MER: 0.1080
# 0.10802296
# Epoch 176/300 - Training Loss: 0.3513 - MER: 0.0906
# 0.09058704
# Epoch 176/300 - Valid Loss: 0.4095 - MER: 0.1104
# 0.110422075
# Epoch 177/300 - Training Loss: 0.3554 - MER: 0.0890
# 0.08898387
# Epoch 177/300 - Valid Loss: 0.4306 - MER: 0.1089
# 0.1088863
# Epoch 178/300 - Training Loss: 0.3650 - MER: 0.0912
# 0.09119711
# Epoch 178/300 - Valid Loss: 0.4185 - MER: 0.1092
# 0.109152764
# Epoch 179/300 - Training Loss: 0.3500 - MER: 0.0851
# 0.085082486
# Epoch 179/300 - Valid Loss: 0.4003 - MER: 0.1090
# 0.10896216
# Epoch 180/300 - Training Loss: 0.3519 - MER: 0.0885
# 0.08853194
# Epoch 180/300 - Valid Loss: 0.4204 - MER: 0.1087
# 0.10865919
# Epoch 181/300 - Training Loss: 0.3522 - MER: 0.0896
# 0.08962349
# Epoch 181/300 - Valid Loss: 0.4515 - MER: 0.1059
# 0.105889
# Epoch 182/300 - Training Loss: 0.3481 - MER: 0.0880
# 0.08796518
# Epoch 182/300 - Valid Loss: 0.4261 - MER: 0.1070
# 0.10695978
# Epoch 183/300 - Training Loss: 0.3594 - MER: 0.0860
# 0.08600902
# Epoch 183/300 - Valid Loss: 0.4177 - MER: 0.1060
# 0.1060222
# Epoch 184/300 - Training Loss: 0.3525 - MER: 0.0850
# 0.084982246
# Epoch 184/300 - Valid Loss: 0.3981 - MER: 0.1091
# 0.10912151
# Epoch 185/300 - Training Loss: 0.3537 - MER: 0.0851
# 0.08507019
# Epoch 185/300 - Valid Loss: 0.4047 - MER: 0.1026
# 0.10261053
# Epoch 186/300 - Training Loss: 0.3436 - MER: 0.0879
# 0.08791314
# Epoch 186/300 - Valid Loss: 0.3952 - MER: 0.1125
# 0.1125088
# Epoch 187/300 - Training Loss: 0.3537 - MER: 0.0856
# 0.0855928
# Epoch 187/300 - Valid Loss: 0.4018 - MER: 0.1070
# 0.10704814
# Epoch 188/300 - Training Loss: 0.3580 - MER: 0.0880
# 0.0879782
# Epoch 188/300 - Valid Loss: 0.3919 - MER: 0.1083
# 0.108334675
# Epoch 189/300 - Training Loss: 0.3608 - MER: 0.0880
# 0.0879634
# Epoch 189/300 - Valid Loss: 0.4152 - MER: 0.1097
# 0.10968822
# Epoch 190/300 - Training Loss: 0.3482 - MER: 0.0869
# 0.08688248
# Epoch 190/300 - Valid Loss: 0.4186 - MER: 0.1047
# 0.10472542
# Epoch 191/300 - Training Loss: 0.3472 - MER: 0.0851
# 0.08514919
# Epoch 191/300 - Valid Loss: 0.3975 - MER: 0.1131
# 0.11307669
# Epoch 192/300 - Training Loss: 0.3399 - MER: 0.0896
# 0.08955549
# Epoch 192/300 - Valid Loss: 0.4167 - MER: 0.1160
# 0.116032235
# Epoch 193/300 - Training Loss: 0.3445 - MER: 0.0850
# 0.084983505
# Epoch 193/300 - Valid Loss: 0.3966 - MER: 0.1047
# 0.104704276
# Epoch 194/300 - Training Loss: 0.3560 - MER: 0.0876
# 0.08758419
# Epoch 194/300 - Valid Loss: 0.4449 - MER: 0.1082
# 0.108202204
# Epoch 195/300 - Training Loss: 0.3534 - MER: 0.0860
# 0.08604252
# Epoch 195/300 - Valid Loss: 0.4061 - MER: 0.1074
# 0.107361324
# Epoch 196/300 - Training Loss: 0.3391 - MER: 0.0856
# 0.08555488
# Epoch 196/300 - Valid Loss: 0.3963 - MER: 0.1072
# 0.107201494
# Epoch 197/300 - Training Loss: 0.3394 - MER: 0.0873
# 0.08729659
# Epoch 197/300 - Valid Loss: 0.4102 - MER: 0.1102
# 0.110230565
# Epoch 198/300 - Training Loss: 0.3488 - MER: 0.0847
# 0.084724516
# Epoch 198/300 - Valid Loss: 0.4058 - MER: 0.1052
# 0.10521647
# Epoch 199/300 - Training Loss: 0.3520 - MER: 0.0917
# 0.09169014
# Epoch 199/300 - Valid Loss: 0.4047 - MER: 0.1114
# 0.11143222
# Epoch 200/300 - Training Loss: 0.3417 - MER: 0.0853
# 0.08525114
# Epoch 200/300 - Valid Loss: 0.4172 - MER: 0.1046
# 0.10460174
# Epoch 201/300 - Training Loss: 0.3510 - MER: 0.0868
# 0.08681384
# Epoch 201/300 - Valid Loss: 0.4185 - MER: 0.1084
# 0.10841638
# Epoch 202/300 - Training Loss: 0.3482 - MER: 0.0851
# 0.08509745
# Epoch 202/300 - Valid Loss: 0.4088 - MER: 0.1078
# 0.1078001
# Epoch 203/300 - Training Loss: 0.3348 - MER: 0.0843
# 0.08434965
# Epoch 203/300 - Valid Loss: 0.4111 - MER: 0.1049
# 0.104867265
# Epoch 204/300 - Training Loss: 0.3468 - MER: 0.0841
# 0.08406414
# Epoch 204/300 - Valid Loss: 0.3969 - MER: 0.1050
# 0.10497514
# Epoch 205/300 - Training Loss: 0.3438 - MER: 0.0852
# 0.085184716
# Epoch 205/300 - Valid Loss: 0.4171 - MER: 0.1099
# 0.10991467
# Epoch 206/300 - Training Loss: 0.3305 - MER: 0.0841
# 0.08411722
# Epoch 206/300 - Valid Loss: 0.4041 - MER: 0.1073
# 0.10731834
# Epoch 207/300 - Training Loss: 0.3367 - MER: 0.0836
# 0.08361155
# Epoch 207/300 - Valid Loss: 0.4041 - MER: 0.1046
# 0.10460195
# Epoch 208/300 - Training Loss: 0.3461 - MER: 0.0871
# 0.08706671
# Epoch 208/300 - Valid Loss: 0.4067 - MER: 0.1065
# 0.10647449
# Epoch 209/300 - Training Loss: 0.3332 - MER: 0.0849
# 0.08490792
# Epoch 209/300 - Valid Loss: 0.4139 - MER: 0.1153
# 0.115332335
# Epoch 210/300 - Training Loss: 0.3511 - MER: 0.0851
# 0.085074104
# Epoch 210/300 - Valid Loss: 0.4057 - MER: 0.1133
# 0.11327689
# Epoch 211/300 - Training Loss: 0.3411 - MER: 0.0870
# 0.086990714
# Epoch 211/300 - Valid Loss: 0.4078 - MER: 0.1060
# 0.10603486
# Epoch 212/300 - Training Loss: 0.3350 - MER: 0.0891
# 0.08907731
# Epoch 212/300 - Valid Loss: 0.4618 - MER: 0.1095
# 0.109528325
# Epoch 213/300 - Training Loss: 0.3375 - MER: 0.0849
# 0.0848561
# Epoch 213/300 - Valid Loss: 0.4035 - MER: 0.1124
# 0.1123754
# Epoch 214/300 - Training Loss: 0.3416 - MER: 0.0858
# 0.08582053
# Epoch 214/300 - Valid Loss: 0.4051 - MER: 0.1046
# 0.10459815
# Epoch 215/300 - Training Loss: 0.3379 - MER: 0.0827
# 0.08265587
# Epoch 215/300 - Valid Loss: 0.4265 - MER: 0.1088
# 0.108768746
# Epoch 216/300 - Training Loss: 0.3355 - MER: 0.0815
# 0.081519656
# Epoch 216/300 - Valid Loss: 0.4024 - MER: 0.1113
# 0.11131484
# Epoch 217/300 - Training Loss: 0.3390 - MER: 0.0834
# 0.08336055
# Epoch 217/300 - Valid Loss: 0.4055 - MER: 0.1042
# 0.10423301
# Epoch 218/300 - Training Loss: 0.3288 - MER: 0.0809
# 0.080859706
# Epoch 218/300 - Valid Loss: 0.4276 - MER: 0.1059
# 0.105949424
# Epoch 219/300 - Training Loss: 0.3328 - MER: 0.0827
# 0.082678966
# Epoch 219/300 - Valid Loss: 0.4119 - MER: 0.1057
# 0.10571419
# Epoch 220/300 - Training Loss: 0.3401 - MER: 0.0823
# 0.08225232
# Epoch 220/300 - Valid Loss: 0.4082 - MER: 0.1036
# 0.1036114
# Epoch 221/300 - Training Loss: 0.3440 - MER: 0.0856
# 0.08564779
# Epoch 221/300 - Valid Loss: 0.4030 - MER: 0.1021
# 0.10214242
# Epoch 222/300 - Training Loss: 0.3354 - MER: 0.0842
# 0.08418992
# Epoch 222/300 - Valid Loss: 0.4045 - MER: 0.1052
# 0.10522246
# Epoch 223/300 - Training Loss: 0.3483 - MER: 0.0839
# 0.08392558
# Epoch 223/300 - Valid Loss: 0.4081 - MER: 0.1078
# 0.107832365
# Epoch 224/300 - Training Loss: 0.3245 - MER: 0.0847
# 0.084690206
# Epoch 224/300 - Valid Loss: 0.4045 - MER: 0.1042
# 0.10418517
# Epoch 225/300 - Training Loss: 0.3343 - MER: 0.0859
# 0.08593926
# Epoch 225/300 - Valid Loss: 0.4088 - MER: 0.1088
# 0.10884227
# Epoch 226/300 - Training Loss: 0.3578 - MER: 0.0873
# 0.08728738
# Epoch 226/300 - Valid Loss: 0.4026 - MER: 0.1126
# 0.112639435
# Epoch 227/300 - Training Loss: 0.3309 - MER: 0.0818
# 0.08176224
# Epoch 227/300 - Valid Loss: 0.3990 - MER: 0.1077
# 0.107741386
# Epoch 228/300 - Training Loss: 0.3315 - MER: 0.0857
# 0.0856983
# Epoch 228/300 - Valid Loss: 0.4047 - MER: 0.1102
# 0.110241145
# Epoch 229/300 - Training Loss: 0.3429 - MER: 0.0889
# 0.08888775
# Epoch 229/300 - Valid Loss: 0.4315 - MER: 0.1115
# 0.11145028
# Epoch 230/300 - Training Loss: 0.3286 - MER: 0.0853
# 0.0853063
# Epoch 230/300 - Valid Loss: 0.4446 - MER: 0.1066
# 0.10663117
# Epoch 231/300 - Training Loss: 0.3346 - MER: 0.0826
# 0.08258213
# Epoch 231/300 - Valid Loss: 0.4155 - MER: 0.1032
# 0.103215076
# Epoch 232/300 - Training Loss: 0.3493 - MER: 0.0832
# 0.08320171
# Epoch 232/300 - Valid Loss: 0.3965 - MER: 0.1058
# 0.10576555
# Epoch 233/300 - Training Loss: 0.3327 - MER: 0.0872
# 0.08722994
# Epoch 233/300 - Valid Loss: 0.4075 - MER: 0.1102
# 0.11017996
# Epoch 234/300 - Training Loss: 0.3515 - MER: 0.0815
# 0.0814837
# Epoch 234/300 - Valid Loss: 0.3971 - MER: 0.0986
# 0.09855859
# Epoch 235/300 - Training Loss: 0.3293 - MER: 0.0809
# 0.08088426
# Epoch 235/300 - Valid Loss: 0.4405 - MER: 0.1065
# 0.10651999
# Epoch 236/300 - Training Loss: 0.3344 - MER: 0.0824
# 0.08235207
# Epoch 236/300 - Valid Loss: 0.3982 - MER: 0.1049
# 0.104898855
# Epoch 237/300 - Training Loss: 0.3140 - MER: 0.0834
# 0.08340622
# Epoch 237/300 - Valid Loss: 0.3984 - MER: 0.1047
# 0.10473046
# Epoch 238/300 - Training Loss: 0.3338 - MER: 0.0875
# 0.08746509
# Epoch 238/300 - Valid Loss: 0.4373 - MER: 0.1080
# 0.10803066
# Epoch 239/300 - Training Loss: 0.3256 - MER: 0.0824
# 0.08235836
# Epoch 239/300 - Valid Loss: 0.3938 - MER: 0.1077
# 0.10774205
# Epoch 240/300 - Training Loss: 0.3182 - MER: 0.0836
# 0.08364537
# Epoch 240/300 - Valid Loss: 0.4082 - MER: 0.1069
# 0.10693085
# Epoch 241/300 - Training Loss: 0.3305 - MER: 0.0833
# 0.08334084
# Epoch 241/300 - Valid Loss: 0.4047 - MER: 0.1079
# 0.107906565
# Epoch 242/300 - Training Loss: 0.3409 - MER: 0.0864
# 0.08638486
# Epoch 242/300 - Valid Loss: 0.4007 - MER: 0.1122
# 0.11215429
# Epoch 243/300 - Training Loss: 0.3322 - MER: 0.0848
# 0.08479364
# Epoch 243/300 - Valid Loss: 0.4024 - MER: 0.1132
# 0.11318278
# Epoch 244/300 - Training Loss: 0.3353 - MER: 0.0822
# 0.082154736
# Epoch 244/300 - Valid Loss: 0.4056 - MER: 0.1044
# 0.10436123
# Epoch 245/300 - Training Loss: 0.3236 - MER: 0.0811
# 0.081064336
# Epoch 245/300 - Valid Loss: 0.3957 - MER: 0.1057
# 0.10566295
# Epoch 246/300 - Training Loss: 0.3284 - MER: 0.0815
# 0.08145305
# Epoch 246/300 - Valid Loss: 0.4106 - MER: 0.1016
# 0.10161516
# Epoch 247/300 - Training Loss: 0.3279 - MER: 0.0878
# 0.08775338
# Epoch 247/300 - Valid Loss: 0.4210 - MER: 0.1066
# 0.10663415
# Epoch 248/300 - Training Loss: 0.3316 - MER: 0.0849
# 0.084933974
# Epoch 248/300 - Valid Loss: 0.4208 - MER: 0.1057
# 0.105702035
# Epoch 249/300 - Training Loss: 0.3538 - MER: 0.0861
# 0.08612163
# Epoch 249/300 - Valid Loss: 0.4102 - MER: 0.1100
# 0.10996293
# Epoch 250/300 - Training Loss: 0.3299 - MER: 0.0806
# 0.08056238
# Epoch 250/300 - Valid Loss: 0.4025 - MER: 0.1023
# 0.102328345
# Epoch 251/300 - Training Loss: 0.3294 - MER: 0.0832
# 0.083188824
# Epoch 251/300 - Valid Loss: 0.3922 - MER: 0.1070
# 0.10695054
# Epoch 252/300 - Training Loss: 0.3197 - MER: 0.0809
# 0.08088906
# Epoch 252/300 - Valid Loss: 0.3978 - MER: 0.1052
# 0.10519453
# Epoch 253/300 - Training Loss: 0.3301 - MER: 0.0820
# 0.081983134
# Epoch 253/300 - Valid Loss: 0.3857 - MER: 0.1023
# 0.10231839
# Epoch 254/300 - Training Loss: 0.3231 - MER: 0.0820
# 0.08198736
# Epoch 254/300 - Valid Loss: 0.4112 - MER: 0.1073
# 0.107305184
# Epoch 255/300 - Training Loss: 0.3276 - MER: 0.0854
# 0.08542901
# Epoch 255/300 - Valid Loss: 0.3908 - MER: 0.1062
# 0.10617367
# Epoch 256/300 - Training Loss: 0.3313 - MER: 0.0820
# 0.08200309
# Epoch 256/300 - Valid Loss: 0.4031 - MER: 0.1029
# 0.102907866
# Epoch 257/300 - Training Loss: 0.3320 - MER: 0.0813
# 0.08131574
# Epoch 257/300 - Valid Loss: 0.4010 - MER: 0.1046
# 0.104636505
# Epoch 258/300 - Training Loss: 0.3234 - MER: 0.0864
# 0.086377025
# Epoch 258/300 - Valid Loss: 0.4336 - MER: 0.1125
# 0.11253168
# Epoch 259/300 - Training Loss: 0.3280 - MER: 0.0880
# 0.08799139
# Epoch 259/300 - Valid Loss: 0.4480 - MER: 0.1074
# 0.107354276
# Epoch 260/300 - Training Loss: 0.3397 - MER: 0.0814
# 0.081354916
# Epoch 260/300 - Valid Loss: 0.4128 - MER: 0.1073
# 0.10728031
# Epoch 261/300 - Training Loss: 0.3285 - MER: 0.0838
# 0.08382334
# Epoch 261/300 - Valid Loss: 0.4249 - MER: 0.1037
# 0.10368111
# Epoch 262/300 - Training Loss: 0.3298 - MER: 0.0826
# 0.08260663
# Epoch 262/300 - Valid Loss: 0.3988 - MER: 0.1073
# 0.10725116
# Epoch 263/300 - Training Loss: 0.3239 - MER: 0.0797
# 0.07968114
# Epoch 263/300 - Valid Loss: 0.3973 - MER: 0.1074
# 0.10736523
# Epoch 264/300 - Training Loss: 0.3226 - MER: 0.0810
# 0.0810394
# Epoch 264/300 - Valid Loss: 0.4028 - MER: 0.1075
# 0.10754901
# Epoch 265/300 - Training Loss: 0.3216 - MER: 0.0844
# 0.08444576
# Epoch 265/300 - Valid Loss: 0.4029 - MER: 0.1071
# 0.10713349
# Epoch 266/300 - Training Loss: 0.3372 - MER: 0.0847
# 0.08466743
# Epoch 266/300 - Valid Loss: 0.4326 - MER: 0.1119
# 0.11191591
# Epoch 267/300 - Training Loss: 0.3308 - MER: 0.0855
# 0.08547762
# Epoch 267/300 - Valid Loss: 0.4499 - MER: 0.1077
# 0.107662156
# Epoch 268/300 - Training Loss: 0.3184 - MER: 0.0796
# 0.07958989
# Epoch 268/300 - Valid Loss: 0.3889 - MER: 0.1078
# 0.10783549
# Epoch 269/300 - Training Loss: 0.3211 - MER: 0.0844
# 0.08444496
# Epoch 269/300 - Valid Loss: 0.4121 - MER: 0.1064
# 0.106368706
# Epoch 270/300 - Training Loss: 0.3245 - MER: 0.0809
# 0.08088116
# Epoch 270/300 - Valid Loss: 0.4001 - MER: 0.1067
# 0.1067402
# Epoch 271/300 - Training Loss: 0.3202 - MER: 0.0889
# 0.08892624
# Epoch 271/300 - Valid Loss: 0.4089 - MER: 0.1135
# 0.11346681
# Epoch 272/300 - Training Loss: 0.3273 - MER: 0.0809
# 0.08086187
# Epoch 272/300 - Valid Loss: 0.3918 - MER: 0.1045
# 0.10450485
# Epoch 273/300 - Training Loss: 0.3200 - MER: 0.0850
# 0.08504784
# Epoch 273/300 - Valid Loss: 0.4468 - MER: 0.1063
# 0.10634435
# Epoch 274/300 - Training Loss: 0.3264 - MER: 0.0824
# 0.082378045
# Epoch 274/300 - Valid Loss: 0.3986 - MER: 0.1078
# 0.107758485
# Epoch 275/300 - Training Loss: 0.3255 - MER: 0.0818
# 0.08175297
# Epoch 275/300 - Valid Loss: 0.4041 - MER: 0.1103
# 0.11033939
# Epoch 276/300 - Training Loss: 0.3263 - MER: 0.0821
# 0.0821013
# Epoch 276/300 - Valid Loss: 0.3913 - MER: 0.1065
# 0.106487736
# Epoch 277/300 - Training Loss: 0.3197 - MER: 0.0805
# 0.08054912
# Epoch 277/300 - Valid Loss: 0.3969 - MER: 0.1036
# 0.10362848
# Epoch 278/300 - Training Loss: 0.3266 - MER: 0.0813
# 0.081279784
# Epoch 278/300 - Valid Loss: 0.4018 - MER: 0.1098
# 0.10982116
# Epoch 279/300 - Training Loss: 0.3194 - MER: 0.0853
# 0.0852717
# Epoch 279/300 - Valid Loss: 0.4168 - MER: 0.1087
# 0.10871037
# Epoch 280/300 - Training Loss: 0.3334 - MER: 0.0903
# 0.09025114
# Epoch 280/300 - Valid Loss: 0.4372 - MER: 0.1132
# 0.11319197
# Epoch 281/300 - Training Loss: 0.3325 - MER: 0.0819
# 0.08191738
# Epoch 281/300 - Valid Loss: 0.4045 - MER: 0.1039
# 0.103878394
# Epoch 282/300 - Training Loss: 0.3211 - MER: 0.0831
# 0.08307733
# Epoch 282/300 - Valid Loss: 0.4024 - MER: 0.1048
# 0.10475509
# Epoch 283/300 - Training Loss: 0.3309 - MER: 0.0835
# 0.08348933
# Epoch 283/300 - Valid Loss: 0.3946 - MER: 0.1067
# 0.10668383
# Epoch 284/300 - Training Loss: 0.3307 - MER: 0.0833
# 0.08329472
# Epoch 284/300 - Valid Loss: 0.4208 - MER: 0.1046
# 0.10456666
# Epoch 285/300 - Training Loss: 0.3344 - MER: 0.0825
# 0.08252866
# Epoch 285/300 - Valid Loss: 0.4028 - MER: 0.1095
# 0.1094592
# Epoch 286/300 - Training Loss: 0.3288 - MER: 0.0826
# 0.08259338
# Epoch 286/300 - Valid Loss: 0.4225 - MER: 0.1059
# 0.10588347
# Epoch 287/300 - Training Loss: 0.3275 - MER: 0.0842
# 0.08420916
# Epoch 287/300 - Valid Loss: 0.4155 - MER: 0.1069
# 0.106881335
# Epoch 288/300 - Training Loss: 0.3142 - MER: 0.0807
# 0.08073357
# Epoch 288/300 - Valid Loss: 0.3944 - MER: 0.1069
# 0.10686613
# Epoch 289/300 - Training Loss: 0.3141 - MER: 0.0825
# 0.08249997
# Epoch 289/300 - Valid Loss: 0.4262 - MER: 0.1078
# 0.10776987
# Epoch 290/300 - Training Loss: 0.3179 - MER: 0.0809
# 0.08086846
# Epoch 290/300 - Valid Loss: 0.3910 - MER: 0.1068
# 0.10679634
# Epoch 291/300 - Training Loss: 0.3331 - MER: 0.0869
# 0.08686612
# Epoch 291/300 - Valid Loss: 0.4790 - MER: 0.1106
# 0.11063883
# Epoch 292/300 - Training Loss: 0.3255 - MER: 0.0799
# 0.07990979
# Epoch 292/300 - Valid Loss: 0.3873 - MER: 0.1061
# 0.106069125
# Epoch 293/300 - Training Loss: 0.3277 - MER: 0.0872
# 0.087211534
# Epoch 293/300 - Valid Loss: 0.4369 - MER: 0.1127
# 0.11268753
# Epoch 294/300 - Training Loss: 0.3233 - MER: 0.0815
# 0.08152263
# Epoch 294/300 - Valid Loss: 0.4135 - MER: 0.1079
# 0.10794006
# Epoch 295/300 - Training Loss: 0.3180 - MER: 0.0830
# 0.08297077
# Epoch 295/300 - Valid Loss: 0.3970 - MER: 0.1023
# 0.10228696
# Epoch 296/300 - Training Loss: 0.3090 - MER: 0.0832
# 0.083207905
# Epoch 296/300 - Valid Loss: 0.3968 - MER: 0.1049
# 0.10490099
# Epoch 297/300 - Training Loss: 0.3157 - MER: 0.0829
# 0.082884006
# Epoch 297/300 - Valid Loss: 0.4015 - MER: 0.1066
# 0.10660837
# Epoch 298/300 - Training Loss: 0.3141 - MER: 0.0795
# 0.07954499
# Epoch 298/300 - Valid Loss: 0.4009 - MER: 0.1069
# 0.10692823
# Epoch 299/300 - Training Loss: 0.3185 - MER: 0.0810
# 0.08097932
# Epoch 299/300 - Valid Loss: 0.4108 - MER: 0.1058
# 0.10584814
# Epoch 300/300 - Training Loss: 0.3140 - MER: 0.0794
# 0.079402134
# Epoch 300/300 - Valid Loss: 0.3974 - MER: 0.1042
# 0.104203224

# %% [markdown]
# ---
# ## Save Model
#
# Save a `checkpoint.pth` file containing all the necessary information to retrieve your best model and predictions. Remember submitting this file to Canvas siste.
#
# Hint: Check out the `Lecture 4 - Saving and Loading Models.ipynb` on Canvas if you do not know how to save model.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms

import helper
import fc_model

# %%
torch.save(model_5.state_dict(), 'checkpoint.pth')

# %%
def load_checkpoint(filepath):

    model = nn.Sequential(
    nn.Linear(train_features.shape[1], 64),
    nn.ReLU(),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 1)
)
    model.load_state_dict(torch.load(filepath))
    model.to(device)

    return model

# %%
model = load_checkpoint('checkpoint.pth')

# %% [markdown]
# ---
# ## Inference on test data
#
# After the model is trained, we can use it for inference.

# %%
#TODO: write the code to generate predicted sale prices for test data
test_features = test_features.to(device)
with torch.no_grad():
    predictions = final_model(test_features).cpu().detach().numpy()
predictions=predictions*100000
predictions
# Out:
# array([[583680.82046509],
#        [470289.51644897],
#        [451141.78657532],
#        ...,
#        [298627.40039825],
#        [340578.34148407],
#        [317992.56801605]])

# %%
#TODO: save the predicted sale prices into submission_csv
import pandas as pd
submission_df = pd.DataFrame(np.column_stack((test_ID, predictions)), columns=['ID', 'SALE_PRICE'])
submission_df.to_csv('submission_csv.csv',index=False)

# %% [markdown]
# Now, we can submit our predictions on Kaggle and see how they compare with the actual house prices (labels) on the test set.
#
# - Log in to the Kaggle website and visit the house price prediction competition page.
#
# - Click the “Submit Predictions”.
#
# - Click the “Browse Files” button in the dashed box at the bottom of the page and select the prediction file you wish to upload.
#
# - Click the “Submit” button at the bottom of the page to view your results.

# %% [markdown]
#  **Include your best test error shown on Kaggle in your case report!**

# %% [markdown]
# ---
# ## Evaluate the profit of iBuyer business model
#
#
# In class, we have dicussed the iBuyer business model and its opportunities and risks. In the following analysis, imagine you work in a consulting firm and would like to investigate the profitability of the iBuyer business model.
#
# You have taken the Mordern Analytics course and remembered that Prof. X advocated the data-driven approach in business decision making. Thus, you would like to perform analysis based on model and data.
#
# Note that since we do not know the true sale prices in the future (like test data), we need to conduct the analysis based on the historical data (train or validation data). Previously, you have already trained a multilayer perceptron model using the train data. Now, let's evaluate the profit of iBuyer business model based on the predicted prices on the **validation data**.

# %% [markdown]
# Let's first compute the predicted prices on the valid data.

# %%
## TODO: Load your best model from your saved checkpoint.pth file.
model = load_checkpoint('checkpoint.pth')

# %%
## TODO: compute the predicted prices on valid data using your best model
valid_features = valid_features.to(device)
with torch.no_grad():
    predictions = model(valid_features).cpu().detach().numpy()
predictions=predictions*100000
predictions
# Out:
# array([[579803.08532715],
#        [615390.58685303],
#        [315665.57884216],
#        ...,
#        [664435.19592285],
#        [523937.03460693],
#        [273415.04096985]])

# %% [markdown]
# Compute the signed error rates (without taking the absolute value sign), that is
#
# $$
# \text{Signed Error Rate} = \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}}
# $$
# We will call signed error rate as prediction error henceafter.

# %%
## TODO: compute the signed error rates (henceafter called prediction errors)
ser = (torch.from_numpy(predictions/100000).to(device) - valid_labels)/valid_labels

# %%
ser
# Out:
# tensor([[ 0.0229],
#         [ 0.0430],
#         [ 0.2379],
#         ...,
#         [ 0.0547],
#         [-0.1165],
#         [-0.0266]], device='cuda:0', dtype=torch.float64)

# %% [markdown]
# ### Analysis and visualization of valid errors

# %% [markdown]
# Let's plot the histogram of prediction errors.
#
# **Question 1**: what is the bias of the prediction errors? Include the histogram of prediction errors and the bias in your report.

# %%
import matplotlib.pyplot as plt

ser_np = ser.cpu().numpy()
plt.plot(ser_np, label='Signed Error Rate')
plt.legend(frameon=False)
plt.show()

# %%
ser_cpu = ser if not ser.is_cuda else ser.cpu()
bias = ser_cpu.mean().item()
print(f"The bias of the series is: {bias}")
# Out:
# The bias of the series is: 0.04248883451161696

# %% [markdown]
# ### Profit Analysis
#
# In the following profit analysis, we assume the iBuyer will make an offer to every property in the valid data based on their predicted price $PP$. We assume the iBuyer decides the offer price $OP$ according to
# $$
# OP = \frac{PP}{1+\alpha},
# $$
# where $\alpha$ is the (targted) profit margin of the iBuyer.
# Here we assume the profit margin has already taken into consideration the commission fee charged by the iBuyer
# and various costs associated such as transaction cost, administration cost, and holding cost. Note that the commission fee charged by Zillow is often around $7.5\%$ and Zillow may charge additional repair costs after home inspection. Thus we take $\alpha=12\%$ in this case study.
#
# We further assume that the iBuyer can resell the property at the same
# price as the broker in the future once the property is bought. In other words, the resell price is equal to the sale price in the valid data. This assumption may not be exactly true in practice and the iBuyer may sell the house at either a higher or lower price depending on the market trend. But our conclusion will not change too much.
#
# Based on the above two assumptions, we can now determine the percentage profit
# for a property bought by the iBuyer as
# $$
# \frac{SP- OP}{OP}.
# $$
# We use the percentage profit instead of the absolute profit because the iBuyer cannot hope to purchase all houses in the market. Therefore, the percentage profit is a better measure of the profitability of the iBuyer business model.
#  The aim of the iBuyer in this simplified setting is to purchase properties for less money than they are sold for, to generate a profit.

# %%
profit_margin = 0.12

# %% [markdown]
# **Question 2**: Consider the hypothetical scenario where the offers are all accepted regardless of their values,
# what is the average percentage profit? Do you see a big difference compared to the profit margin $\alpha$? Include your answers in the report.

# %%
op = predictions/(1+profit_margin)
perc_profit = valid_labels / torch.from_numpy(op/100000).to(device) - 1
perc_profit.mean()
# Out:
# tensor(0.1259, device='cuda:0', dtype=torch.float64)

# %% [markdown]
# **Offer Acceptance Rule**
#
#
# However, not every offer will be accepted by the home owner. Given an offer price, whether the homeowner accepts it
# depends on the homeowner's perceived valuation. For the current dataset, we lack enough data to determine the homeowner's perceived valuation of the property. However, the actual sale price in the valid data serves as a reasonable proxy of the homeowner's perceived valuation. Therefore, we assume that the home owner will accept the offer, if
# $$
# OP> (1-\beta) SP,
# $$
# where $\beta$ is a discounting factor. Here the discounting factor captures the commission fee charged
# by the conventional realtors which is around 6%, as well as the convenience factor that models
# how much the homeowner values the quick transaction services of the iBuyer over the conventional
# relator. We assume $\beta = 10\%$ in this case.

# %% [markdown]
# **Question 3**: Based on the sale price in the valid data and the acceptance rule, what is the mean percentage profit among all accepted offers? Do you see a big difference compared to the targeted profit margin $\alpha$?  Include your answers in your report.

# %%
valid_labels = valid_labels.cpu().numpy().T.flatten()
op = op.T.flatten()
predictions = predictions.T.flatten()
ser = ser.cpu().numpy().T.flatten()

# %%
df = pd.DataFrame({
    'op': op/100000,
    'valid_labels': valid_labels,
    'predictions': predictions/100000,
    'ser':ser
})

# %%
discount_factor = 0.1
df['offer'] = df.op>(1-discount_factor)*df.valid_labels
df_accept = df[df['offer'] == True]
perc_profit2 = df_accept.valid_labels / df_accept.op - 1
perc_profit2.mean()
# Out:
# -0.03409839516971715

# %% [markdown]
# Let's plot the histogram of the prediction errors for those properties whose home owners accepted the offer.
#
# **Question 4**: What is the bias of the prediction errors when restricting to those properties whose owners accepted the offer? Based on the histogram and bias, can you explain your answers to Question 3?

# %%
plt.plot(df_accept.ser, label='Signed Error Rate')
plt.legend(frameon=False)
plt.show()

# %%
#ser_cpu = ser if not ser.is_cuda else ser.cpu()
bias = df_accept.ser.mean().item()
print(f"The bias of the series is: {bias}")
# Out:
# The bias of the series is: 0.20504443919585763
